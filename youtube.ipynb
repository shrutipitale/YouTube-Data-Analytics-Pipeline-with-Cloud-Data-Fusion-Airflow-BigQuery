# %%
from googleapiclient.discovery import build
import pandas as pd
import numpy as np

# %%
api_key='AIzaSyDOOhUkCcLsQvWKX9KUTXIc4GZbLFr2i-Y'

# %%
channel_ids=['UCnz-ZXXER4jOvuED5trXfEA',  # tech TFQ
              'UC7cs8q-gJRlGwj4A8OmCmXg', #alex the analist
              'UCCWi3hpnq_Pe03nGxuS7isg', # campus X
              'UC8uU_wruBMHeeRma49dtZKA', # chando
              'UCh9nVJoWXmFb7sLApWGcLPQ', # code basics
              'UCcIXc5mJsHVYTZR1maL5l9w', # deeplearning
              'UCkndrGoNpUDV-uia6a9jwVg', # excelfun
              'UCFp1vaKzpfvoGai0vE5VJ0w', # guy in a cube
              'UCq6XkhO5SZ66N04IcPbqNcw', #keith galli
              'UCiT9RITQ9PW6BhXK0y2jaeg', #ken lee
              'UCfJT_eYDTmDE-ovKaxVE1ig', # kevin startvert
              'UCNU_lfiiWBdtULKOw6X0Dig', # krish naik
              'UCJtUOos_MwJa_Ewii-R3cJA', # Leila Gharani
              'UCLLw7jmFsvfIVaUFsLs8mlQ', # luke barousse
              'UC3rY5HOgbBvGmq7RnDfwF7A', # rishab mishra
              'UCxladMszXan-jfgzyeIMyvw', # rob mulla
              'UCfzlCWGWYyIQ0aLC5w48gBQ', # sentdex
              'UCW6TXMZ5Pq6yL6_k5NZ2e0Q', # Socratica
              'UCtYLUTtgS3k1Fg4y5tAhLbw', #StatQuest with Josh Starmer
              'UC7HYxRWmaNlJux-X7rNLZyw', # Tableau Tim
              'UCJQJAI7IjbLcpsjWdSzYz0Q', # Thu Vu data analytics
              'UC2UXDak6o7rBm23k3Vv5dww', # Tina Huang
              'UC0T6MVd3wQDB5ICAe45OxaQ', # wscube
              'UCXUPKJO5MZQN11PqgIvyuvQ', # Andrej Karpathy
              'UCChmJrVa8kDg05JfCmxpLRw', # Darshil Parmar
              'UC_lePY0Lm0E2-_IkYUWpI5A', # Dataquest
              'UC8butISFwT-Wl7EV0hUK0BQ', # freeCodeCamp.org
              'UCSNeZleDn9c74yQc-EKnVTA', # Kaggle
              'UCHXa4OpASJEwrHrLeIzw7Yg', # Nicholas Renotte
              'UCKq-lHnyradGRmFClX_ACMw', # Ryan Nolan Data
              'UCtYLUTtgS3k1Fg4y5tAhLbw', # StatQuest with Josh Starmer
              'UCD7FERT7OXNgLYkvEyy3qGQ', # ZERO Analyst
              'UCrzeNkbo0mEoANAHlxYP22A', # Xamasco
              'UCuNrwdpvF1LBGJ2cNL5b68w', # Vincent Codes Finance
              'UCi5CmpgqgeEzqVDumyEc9og', # ThePerfectBA
              'UCoIfDjbbP3zpKtFm43nh1sQ', # The data tech
              'UCMNZFAhQSB314E_MG3IbTXQ', # TechTrapture
              'UCe0TgrSOmVNu7vrwC4ZFWdg', # Siddhardhan
              'UC3LD42rjj-Owtxsa6PwGU5Q',# Streamlit
              'UC_MWk7GdVDJcMexHiP4UTjw',# Stacey Samoe
              'UCAhplpsDYvq0W1F4hcSrqnw',# Sujay Nadkarni
              'UCFp1vaKzpfvoGai0vE5VJ0w',# Analytics with Nags
              'UCSQvwTdavISOusGhJW6H0Vg',# absent data
              'UCz7iLJYRhzoSVIXZ2dESzuw',# Programming Live with Larry
              'UCf9T51_FmMlfhiGpoes0yFA',# Piyush Garg
              'UCzv_k6lxolY4rzndB71AfUw',# Murtaza's Workshop - Robotics and AI
              'UCSQnHL-F4wnMbg4BT-9pVSQ',# NitMan Talks
              'UCIB_kEcgT-lkTi14cqq4XqA',# Mansi G.
              'UCOwaE3fVOZSRujo2OPDKCHg',# M Prashant
              'UCDnJ7pVeZXFn7gcbcwcjUkA',# Loves Data
              'UCdY9luYzi6V1-_pl2uezIHg', # Learn Data Analytics
              'UCLXbBOFMlbD7l7ynTd80Ohw',# E-Learning Bridge
              'UCKKpMJSgeZzyfKjyNtHtSsA', # DevOps Directive
              'UCUlCfM_fqQedxqGPqLVPuGw',# Deep Charts
              'UCAEgip72UcvYwjcqzcJ1I2g',# DataScience RoadMap
              'UCBOs6624oqScw8PaU-Jzw9A',# Data Tutorials
              'UCwk47V1XafOrw83d_vwwGhg',# Data Science Lovers
              'UC2S0k7NeLcEm5_IhHUwpN0g',# Data Factory
              'UCnfZSN7A09wNwYiUoincXZg',# Data Engineering Simplified
              'UCS0ZTW6ynY34OZodixxwb7w',# Coupler․io Academy
              'UCHoLIMtg_OigNlJmjHX9J8Q',# coder2j
              'UCBQGd1sTurl5fZ5foDZtN5A',# Beyond Numberz
              ]

# %%
youtube=build('youtube','v3',developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []

    # Batch size: max 50 IDs
    for i in range(0, len(channel_ids), 50):
        batch_ids = channel_ids[i:i + 50]
        request = youtube.channels().list(
            part='snippet,contentDetails,statistics',
            id=','.join(batch_ids)
        )
        response = request.execute()

        for item in response.get('items', []):
            data = {
                'Channel_Name': item['snippet']['title'],
                'Subscribers': item['statistics'].get('subscriberCount'),
                'Views': item['statistics'].get('viewCount'),
                'Total_videos': item['statistics'].get('videoCount'),
                'Playlist_id': item['contentDetails']['relatedPlaylists']['uploads']
            }
            all_data.append(data)

    return all_data

# %%
channel_info = get_channel_stats(youtube, channel_ids)
channel_info
# Out:
# [{'Channel_Name': 'Absent Data',
#   'Subscribers': '60000',
#   'Views': '4642498',
#   'Total_videos': '223',
#   'Playlist_id': 'UUSQvwTdavISOusGhJW6H0Vg'},
#  {'Channel_Name': 'Loves Data',
#   'Subscribers': '137000',
#   'Views': '10054402',
#   'Total_videos': '403',
#   'Playlist_id': 'UUDnJ7pVeZXFn7gcbcwcjUkA'},
#  {'Channel_Name': 'Ken Jee',
#   'Subscribers': '271000',
#   'Views': '9431673',
#   'Total_videos': '288',
#   'Playlist_id': 'UUiT9RITQ9PW6BhXK0y2jaeg'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Subscribers': '2320',
#   'Views': '162628',
#   'Total_videos': '28',
#   'Playlist_id': 'UUuNrwdpvF1LBGJ2cNL5b68w'},
#  {'Channel_Name': 'Tina Huang',
#   'Subscribers': '881000',
#   'Views': '39019961',
#   'Total_videos': '252',
#   'Playlist_id': 'UU2UXDak6o7rBm23k3Vv5dww'},
#  {'Channel_Name': 'Stacey Samoe',
#   'Subscribers': '2180',
#   'Views': '89380',
#   'Total_videos': '48',
#   'Playlist_id': 'UU_MWk7GdVDJcMexHiP4UTjw'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Subscribers': '1420000',
#   'Views': '79886265',
#   'Total_videos': '291',
#   'Playlist_id': 'UUtYLUTtgS3k1Fg4y5tAhLbw'},
#  {'Channel_Name': 'The Code Tech',
#   'Subscribers': '1100',
#   'Views': '4168',
#   'Total_videos': '5',
#   'Playlist_id': 'UUoIfDjbbP3zpKtFm43nh1sQ'},
#  {'Channel_Name': 'Donut Gaming',
#   'Subscribers': '475',
#   'Views': '140809',
#   'Total_videos': '534',
#   'Playlist_id': 'UUe0TgrSOmVNu7vrwC4ZFWdg'},
#  {'Channel_Name': 'Piyush Garg',
#   'Subscribers': '260000',
#   'Views': '20380929',
#   'Total_videos': '429',
#   'Playlist_id': 'UUf9T51_FmMlfhiGpoes0yFA'},
#  {'Channel_Name': 'Luke Barousse',
#   'Subscribers': '527000',
#   'Views': '26329639',
#   'Total_videos': '164',
#   'Playlist_id': 'UULLw7jmFsvfIVaUFsLs8mlQ'},
#  {'Channel_Name': 'Darshil Parmar',
#   'Subscribers': '182000',
#   'Views': '9199877',
#   'Total_videos': '162',
#   'Playlist_id': 'UUChmJrVa8kDg05JfCmxpLRw'},
#  {'Channel_Name': 'Thu Vu',
#   'Subscribers': '309000',
#   'Views': '10968168',
#   'Total_videos': '96',
#   'Playlist_id': 'UUJQJAI7IjbLcpsjWdSzYz0Q'},
#  {'Channel_Name': 'Alex The Analyst',
#   'Subscribers': '1070000',
#   'Views': '50384620',
#   'Total_videos': '364',
#   'Playlist_id': 'UU7cs8q-gJRlGwj4A8OmCmXg'},
#  {'Channel_Name': 'Guy in a Cube',
#   'Subscribers': '498000',
#   'Views': '41575624',
#   'Total_videos': '1118',
#   'Playlist_id': 'UUFp1vaKzpfvoGai0vE5VJ0w'},
#  {'Channel_Name': 'Rob Mulla',
#   'Subscribers': '205000',
#   'Views': '14259924',
#   'Total_videos': '162',
#   'Playlist_id': 'UUxladMszXan-jfgzyeIMyvw'},
#  {'Channel_Name': 'NitMan Talks',
#   'Subscribers': '48500',
#   'Views': '6542338',
#   'Total_videos': '313',
#   'Playlist_id': 'UUSQnHL-F4wnMbg4BT-9pVSQ'},
#  {'Channel_Name': 'techTFQ',
#   'Subscribers': '370000',
#   'Views': '21365056',
#   'Total_videos': '140',
#   'Playlist_id': 'UUnz-ZXXER4jOvuED5trXfEA'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Subscribers': '422000',
#   'Views': '31483408',
#   'Total_videos': '127',
#   'Playlist_id': 'UU3rY5HOgbBvGmq7RnDfwF7A'},
#  {'Channel_Name': 'Xamasco',
#   'Subscribers': '4590',
#   'Views': '789881',
#   'Total_videos': '262',
#   'Playlist_id': 'UUrzeNkbo0mEoANAHlxYP22A'},
#  {'Channel_Name': 'Leila Gharani',
#   'Subscribers': '2860000',
#   'Views': '285715208',
#   'Total_videos': '601',
#   'Playlist_id': 'UUJtUOos_MwJa_Ewii-R3cJA'},
#  {'Channel_Name': 'Streamlit',
#   'Subscribers': '24300',
#   'Views': '1148685',
#   'Total_videos': '100',
#   'Playlist_id': 'UU3LD42rjj-Owtxsa6PwGU5Q'},
#  {'Channel_Name': 'Chandoo',
#   'Subscribers': '764000',
#   'Views': '57713204',
#   'Total_videos': '524',
#   'Playlist_id': 'UU8uU_wruBMHeeRma49dtZKA'},
#  {'Channel_Name': 'The Live Coders',
#   'Subscribers': '527',
#   'Views': '22303',
#   'Total_videos': '48',
#   'Playlist_id': 'UUz7iLJYRhzoSVIXZ2dESzuw'},
#  {'Channel_Name': 'Dataquest',
#   'Subscribers': '68000',
#   'Views': '2695846',
#   'Total_videos': '74',
#   'Playlist_id': 'UU_lePY0Lm0E2-_IkYUWpI5A'},
#  {'Channel_Name': 'Ryan & Matt Data Science',
#   'Subscribers': '23900',
#   'Views': '1117307',
#   'Total_videos': '295',
#   'Playlist_id': 'UUKq-lHnyradGRmFClX_ACMw'},
#  {'Channel_Name': 'CampusX',
#   'Subscribers': '335000',
#   'Views': '40474689',
#   'Total_videos': '1249',
#   'Playlist_id': 'UUCWi3hpnq_Pe03nGxuS7isg'},
#  {'Channel_Name': 'Tableau Tim',
#   'Subscribers': '238000',
#   'Views': '5063163',
#   'Total_videos': '586',
#   'Playlist_id': 'UU7HYxRWmaNlJux-X7rNLZyw'},
#  {'Channel_Name': 'Mansi G.',
#   'Subscribers': '13600',
#   'Views': '601623',
#   'Total_videos': '32',
#   'Playlist_id': 'UUIB_kEcgT-lkTi14cqq4XqA'},
#  {'Channel_Name': 'TechTrapture',
#   'Subscribers': '12800',
#   'Views': '1382352',
#   'Total_videos': '351',
#   'Playlist_id': 'UUMNZFAhQSB314E_MG3IbTXQ'},
#  {'Channel_Name': 'Kaggle',
#   'Subscribers': '198000',
#   'Views': '5146925',
#   'Total_videos': '506',
#   'Playlist_id': 'UUSNeZleDn9c74yQc-EKnVTA'},
#  {'Channel_Name': 'MPrashant TECH',
#   'Subscribers': '23200',
#   'Views': '1521657',
#   'Total_videos': '94',
#   'Playlist_id': 'UUOwaE3fVOZSRujo2OPDKCHg'},
#  {'Channel_Name': 'Andrej Karpathy',
#   'Subscribers': '868000',
#   'Views': '19182437',
#   'Total_videos': '17',
#   'Playlist_id': 'UUXUPKJO5MZQN11PqgIvyuvQ'},
#  {'Channel_Name': 'excelisfun',
#   'Subscribers': '1210000',
#   'Views': '159969989',
#   'Total_videos': '3832',
#   'Playlist_id': 'UUkndrGoNpUDV-uia6a9jwVg'},
#  {'Channel_Name': 'Keith Galli',
#   'Subscribers': '244000',
#   'Views': '16986960',
#   'Total_videos': '106',
#   'Playlist_id': 'UUq6XkhO5SZ66N04IcPbqNcw'},
#  {'Channel_Name': 'Zero Analyst',
#   'Subscribers': '27500',
#   'Views': '959934',
#   'Total_videos': '299',
#   'Playlist_id': 'UUD7FERT7OXNgLYkvEyy3qGQ'},
#  {'Channel_Name': 'sentdex',
#   'Subscribers': '1410000',
#   'Views': '117980863',
#   'Total_videos': '1262',
#   'Playlist_id': 'UUfzlCWGWYyIQ0aLC5w48gBQ'},
#  {'Channel_Name': 'Socratica',
#   'Subscribers': '932000',
#   'Views': '63829532',
#   'Total_videos': '676',
#   'Playlist_id': 'UUW6TXMZ5Pq6yL6_k5NZ2e0Q'},
#  {'Channel_Name': 'Sujay Nadkarni',
#   'Subscribers': '10500',
#   'Views': '638543',
#   'Total_videos': '226',
#   'Playlist_id': 'UUAhplpsDYvq0W1F4hcSrqnw'},
#  {'Channel_Name': 'freeCodeCamp.org',
#   'Subscribers': '10800000',
#   'Views': '868730295',
#   'Total_videos': '1864',
#   'Playlist_id': 'UU8butISFwT-Wl7EV0hUK0BQ'},
#  {'Channel_Name': 'codebasics',
#   'Subscribers': '1290000',
#   'Views': '131942278',
#   'Total_videos': '1060',
#   'Playlist_id': 'UUh9nVJoWXmFb7sLApWGcLPQ'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Subscribers': '407000',
#   'Views': '22292578',
#   'Total_videos': '497',
#   'Playlist_id': 'UUcIXc5mJsHVYTZR1maL5l9w'},
#  {'Channel_Name': 'WsCube Tech',
#   'Subscribers': '3970000',
#   'Views': '367259650',
#   'Total_videos': '5662',
#   'Playlist_id': 'UU0T6MVd3wQDB5ICAe45OxaQ'},
#  {'Channel_Name': 'Nicholas Renotte',
#   'Subscribers': '308000',
#   'Views': '21870821',
#   'Total_videos': '311',
#   'Playlist_id': 'UUHXa4OpASJEwrHrLeIzw7Yg'},
#  {'Channel_Name': 'Murtaza Hassan',
#   'Subscribers': '5520',
#   'Views': '81490',
#   'Total_videos': '62',
#   'Playlist_id': 'UUzv_k6lxolY4rzndB71AfUw'},
#  {'Channel_Name': 'Krish Naik',
#   'Subscribers': '1190000',
#   'Views': '117989147',
#   'Total_videos': '2020',
#   'Playlist_id': 'UUNU_lfiiWBdtULKOw6X0Dig'},
#  {'Channel_Name': 'Kevin Stratvert',
#   'Subscribers': '3650000',
#   'Views': '541063929',
#   'Total_videos': '1044',
#   'Playlist_id': 'UUfJT_eYDTmDE-ovKaxVE1ig'},
#  {'Channel_Name': 'ThePrefectPM',
#   'Subscribers': '369',
#   'Views': '1647',
#   'Total_videos': '11',
#   'Playlist_id': 'UUi5CmpgqgeEzqVDumyEc9og'},
#  {'Channel_Name': 'DATA SCIENCE LOVERS',
#   'Subscribers': '29100',
#   'Views': '1532432',
#   'Total_videos': '173',
#   'Playlist_id': 'UUwk47V1XafOrw83d_vwwGhg'},
#  {'Channel_Name': 'DataScience RoadMap',
#   'Subscribers': '22300',
#   'Views': '1561062',
#   'Total_videos': '219',
#   'Playlist_id': 'UUAEgip72UcvYwjcqzcJ1I2g'},
#  {'Channel_Name': 'Deep Charts',
#   'Subscribers': '10200',
#   'Views': '329738',
#   'Total_videos': '61',
#   'Playlist_id': 'UUUlCfM_fqQedxqGPqLVPuGw'},
#  {'Channel_Name': 'Coupler․io Academy',
#   'Subscribers': '60000',
#   'Views': '5545774',
#   'Total_videos': '280',
#   'Playlist_id': 'UUS0ZTW6ynY34OZodixxwb7w'},
#  {'Channel_Name': 'Data Wale Bhaiya',
#   'Subscribers': '6070',
#   'Views': '150962',
#   'Total_videos': '20',
#   'Playlist_id': 'UULXbBOFMlbD7l7ynTd80Ohw'},
#  {'Channel_Name': 'Sid Palas',
#   'Subscribers': '683',
#   'Views': '22371',
#   'Total_videos': '9',
#   'Playlist_id': 'UUKKpMJSgeZzyfKjyNtHtSsA'},
#  {'Channel_Name': 'Beyond Numberz',
#   'Subscribers': '4620',
#   'Views': '164874',
#   'Total_videos': '61',
#   'Playlist_id': 'UUBQGd1sTurl5fZ5foDZtN5A'},
#  {'Channel_Name': 'Data Tutorials',
#   'Subscribers': '176000',
#   'Views': '10559603',
#   'Total_videos': '167',
#   'Playlist_id': 'UUBOs6624oqScw8PaU-Jzw9A'},
#  {'Channel_Name': 'Data Engineering Simplified',
#   'Subscribers': '55400',
#   'Views': '3794260',
#   'Total_videos': '200',
#   'Playlist_id': 'UUnfZSN7A09wNwYiUoincXZg'},
#  {'Channel_Name': 'Learn Data Analytics',
#   'Subscribers': '2050',
#   'Views': '212020',
#   'Total_videos': '163',
#   'Playlist_id': 'UUdY9luYzi6V1-_pl2uezIHg'},
#  {'Channel_Name': 'coder2j',
#   'Subscribers': '15600',
#   'Views': '1519345',
#   'Total_videos': '50',
#   'Playlist_id': 'UUHoLIMtg_OigNlJmjHX9J8Q'},
#  {'Channel_Name': 'Data Factory',
#   'Subscribers': '17500',
#   'Views': '1419436',
#   'Total_videos': '198',
#   'Playlist_id': 'UU2S0k7NeLcEm5_IhHUwpN0g'}]

# %%
channel_data=pd.DataFrame(channel_info)
channel_data
# Out:
#                    Channel_Name Subscribers      Views Total_videos  \
# 0                   Absent Data       60000    4642498          223
# 1                    Loves Data      137000   10054402          403
# 2                       Ken Jee      271000    9431673          288
# 3         Vincent Codes Finance        2320     162628           28
# 4                    Tina Huang      881000   39019961          252
# 5                  Stacey Samoe        2180      89380           48
# 6   StatQuest with Josh Starmer     1420000   79886265          291
# 7                 The Code Tech        1100       4168            5
# 8                  Donut Gaming         475     140809          534
# 9                   Piyush Garg      260000   20380929          429
# 10                Luke Barousse      527000   26329639          164
# 11               Darshil Parmar      182000    9199877          162
# 12                       Thu Vu      309000   10968168           96
# 13             Alex The Analyst     1070000   50384620          364
# 14                Guy in a Cube      498000   41575624         1118
# 15                    Rob Mulla      205000   14259924          162
# 16                 NitMan Talks       48500    6542338          313
# 17                      techTFQ      370000   21365056          140
# 18               Rishabh Mishra      422000   31483408          127
# 19                      Xamasco        4590     789881          262
# 20                Leila Gharani     2860000  285715208          601
# 21                    Streamlit       24300    1148685          100
# 22                      Chandoo      764000   57713204          524
# 23              The Live Coders         527      22303           48
# 24                    Dataquest       68000    2695846           74
# 25     Ryan & Matt Data Science       23900    1117307          295
# 26                      CampusX      335000   40474689         1249
# 27                  Tableau Tim      238000    5063163          586
# 28                     Mansi G.       13600     601623           32
# 29                 TechTrapture       12800    1382352          351
# 30                       Kaggle      198000    5146925          506
# 31               MPrashant TECH       23200    1521657           94
# 32              Andrej Karpathy      868000   19182437           17
# 33                   excelisfun     1210000  159969989         3832
# 34                  Keith Galli      244000   16986960          106
# 35                 Zero Analyst       27500     959934          299
# 36                      sentdex     1410000  117980863         1262
# 37                    Socratica      932000   63829532          676
# 38               Sujay Nadkarni       10500     638543          226
# 39             freeCodeCamp.org    10800000  868730295         1864
# 40                   codebasics     1290000  131942278         1060
# 41               DeepLearningAI      407000   22292578          497
# 42                  WsCube Tech     3970000  367259650         5662
# 43             Nicholas Renotte      308000   21870821          311
# 44               Murtaza Hassan        5520      81490           62
# 45                   Krish Naik     1190000  117989147         2020
# 46              Kevin Stratvert     3650000  541063929         1044
# 47                 ThePrefectPM         369       1647           11
# 48          DATA SCIENCE LOVERS       29100    1532432          173
# 49          DataScience RoadMap       22300    1561062          219
# 50                  Deep Charts       10200     329738           61
# 51           Coupler․io Academy       60000    5545774          280
# 52             Data Wale Bhaiya        6070     150962           20
# 53                    Sid Palas         683      22371            9
# 54               Beyond Numberz        4620     164874           61
# 55               Data Tutorials      176000   10559603          167
# 56  Data Engineering Simplified       55400    3794260          200
# 57         Learn Data Analytics        2050     212020          163
# 58                      coder2j       15600    1519345           50
# 59                 Data Factory       17500    1419436          198
#
#                  Playlist_id
# 0   UUSQvwTdavISOusGhJW6H0Vg
# 1   UUDnJ7pVeZXFn7gcbcwcjUkA
# 2   UUiT9RITQ9PW6BhXK0y2jaeg
# 3   UUuNrwdpvF1LBGJ2cNL5b68w
# 4   UU2UXDak6o7rBm23k3Vv5dww
# 5   UU_MWk7GdVDJcMexHiP4UTjw
# 6   UUtYLUTtgS3k1Fg4y5tAhLbw
# 7   UUoIfDjbbP3zpKtFm43nh1sQ
# 8   UUe0TgrSOmVNu7vrwC4ZFWdg
# 9   UUf9T51_FmMlfhiGpoes0yFA
# 10  UULLw7jmFsvfIVaUFsLs8mlQ
# 11  UUChmJrVa8kDg05JfCmxpLRw
# 12  UUJQJAI7IjbLcpsjWdSzYz0Q
# 13  UU7cs8q-gJRlGwj4A8OmCmXg
# 14  UUFp1vaKzpfvoGai0vE5VJ0w
# 15  UUxladMszXan-jfgzyeIMyvw
# 16  UUSQnHL-F4wnMbg4BT-9pVSQ
# 17  UUnz-ZXXER4jOvuED5trXfEA
# 18  UU3rY5HOgbBvGmq7RnDfwF7A
# 19  UUrzeNkbo0mEoANAHlxYP22A
# 20  UUJtUOos_MwJa_Ewii-R3cJA
# 21  UU3LD42rjj-Owtxsa6PwGU5Q
# 22  UU8uU_wruBMHeeRma49dtZKA
# 23  UUz7iLJYRhzoSVIXZ2dESzuw
# 24  UU_lePY0Lm0E2-_IkYUWpI5A
# 25  UUKq-lHnyradGRmFClX_ACMw
# 26  UUCWi3hpnq_Pe03nGxuS7isg
# 27  UU7HYxRWmaNlJux-X7rNLZyw
# 28  UUIB_kEcgT-lkTi14cqq4XqA
# 29  UUMNZFAhQSB314E_MG3IbTXQ
# 30  UUSNeZleDn9c74yQc-EKnVTA
# 31  UUOwaE3fVOZSRujo2OPDKCHg
# 32  UUXUPKJO5MZQN11PqgIvyuvQ
# 33  UUkndrGoNpUDV-uia6a9jwVg
# 34  UUq6XkhO5SZ66N04IcPbqNcw
# 35  UUD7FERT7OXNgLYkvEyy3qGQ
# 36  UUfzlCWGWYyIQ0aLC5w48gBQ
# 37  UUW6TXMZ5Pq6yL6_k5NZ2e0Q
# 38  UUAhplpsDYvq0W1F4hcSrqnw
# 39  UU8butISFwT-Wl7EV0hUK0BQ
# 40  UUh9nVJoWXmFb7sLApWGcLPQ
# 41  UUcIXc5mJsHVYTZR1maL5l9w
# 42  UU0T6MVd3wQDB5ICAe45OxaQ
# 43  UUHXa4OpASJEwrHrLeIzw7Yg
# 44  UUzv_k6lxolY4rzndB71AfUw
# 45  UUNU_lfiiWBdtULKOw6X0Dig
# 46  UUfJT_eYDTmDE-ovKaxVE1ig
# 47  UUi5CmpgqgeEzqVDumyEc9og
# 48  UUwk47V1XafOrw83d_vwwGhg
# 49  UUAEgip72UcvYwjcqzcJ1I2g
# 50  UUUlCfM_fqQedxqGPqLVPuGw
# 51  UUS0ZTW6ynY34OZodixxwb7w
# 52  UULXbBOFMlbD7l7ynTd80Ohw
# 53  UUKKpMJSgeZzyfKjyNtHtSsA
# 54  UUBQGd1sTurl5fZ5foDZtN5A
# 55  UUBOs6624oqScw8PaU-Jzw9A
# 56  UUnfZSN7A09wNwYiUoincXZg
# 57  UUdY9luYzi6V1-_pl2uezIHg
# 58  UUHoLIMtg_OigNlJmjHX9J8Q
# 59  UU2S0k7NeLcEm5_IhHUwpN0g

# %%
Channel_Name = channel_data['Channel_Name']
Channel_Name
# Out:
# 0                     Absent Data
# 1                      Loves Data
# 2                         Ken Jee
# 3           Vincent Codes Finance
# 4                      Tina Huang
# 5                    Stacey Samoe
# 6     StatQuest with Josh Starmer
# 7                   The Code Tech
# 8                    Donut Gaming
# 9                     Piyush Garg
# 10                  Luke Barousse
# 11                 Darshil Parmar
# 12                         Thu Vu
# 13               Alex The Analyst
# 14                  Guy in a Cube
# 15                      Rob Mulla
# 16                   NitMan Talks
# 17                        techTFQ
# 18                 Rishabh Mishra
# 19                        Xamasco
# 20                  Leila Gharani
# 21                      Streamlit
# 22                        Chandoo
# 23                The Live Coders
# 24                      Dataquest
# 25       Ryan & Matt Data Science
# 26                        CampusX
# 27                    Tableau Tim
# 28                       Mansi G.
# 29                   TechTrapture
# 30                         Kaggle
# 31                 MPrashant TECH
# 32                Andrej Karpathy
# 33                     excelisfun
# 34                    Keith Galli
# 35                   Zero Analyst
# 36                        sentdex
# 37                      Socratica
# 38                 Sujay Nadkarni
# 39               freeCodeCamp.org
# 40                     codebasics
# 41                 DeepLearningAI
# 42                    WsCube Tech
# 43               Nicholas Renotte
# 44                 Murtaza Hassan
# 45                     Krish Naik
# 46                Kevin Stratvert
# 47                   ThePrefectPM
# 48            DATA SCIENCE LOVERS
# 49            DataScience RoadMap
# 50                    Deep Charts
# 51             Coupler․io Academy
# 52               Data Wale Bhaiya
# 53                      Sid Palas
# 54                 Beyond Numberz
# 55                 Data Tutorials
# 56    Data Engineering Simplified
# 57           Learn Data Analytics
# 58                        coder2j
# 59                   Data Factory
# Name: Channel_Name, dtype: object

# %%
channel_data.dtypes
# Out:
# Channel_Name    object
# Subscribers     object
# Views           object
# Total_videos    object
# Playlist_id     object
# dtype: object

# %%
channel_data['Subscribers']=pd.to_numeric(channel_data['Subscribers'])
channel_data['Views']=pd.to_numeric(channel_data['Views'])
channel_data['Total_videos']=pd.to_numeric(channel_data['Total_videos'])

# %%
channel_data.dtypes
# Out:
# Channel_Name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# Playlist_id     object
# dtype: object

# %%
Playlist_id = channel_data['Playlist_id'].tolist()
Playlist_id
# Out:
# ['UUSQvwTdavISOusGhJW6H0Vg',
#  'UUDnJ7pVeZXFn7gcbcwcjUkA',
#  'UUiT9RITQ9PW6BhXK0y2jaeg',
#  'UUuNrwdpvF1LBGJ2cNL5b68w',
#  'UU2UXDak6o7rBm23k3Vv5dww',
#  'UU_MWk7GdVDJcMexHiP4UTjw',
#  'UUtYLUTtgS3k1Fg4y5tAhLbw',
#  'UUoIfDjbbP3zpKtFm43nh1sQ',
#  'UUe0TgrSOmVNu7vrwC4ZFWdg',
#  'UUf9T51_FmMlfhiGpoes0yFA',
#  'UULLw7jmFsvfIVaUFsLs8mlQ',
#  'UUChmJrVa8kDg05JfCmxpLRw',
#  'UUJQJAI7IjbLcpsjWdSzYz0Q',
#  'UU7cs8q-gJRlGwj4A8OmCmXg',
#  'UUFp1vaKzpfvoGai0vE5VJ0w',
#  'UUxladMszXan-jfgzyeIMyvw',
#  'UUSQnHL-F4wnMbg4BT-9pVSQ',
#  'UUnz-ZXXER4jOvuED5trXfEA',
#  'UU3rY5HOgbBvGmq7RnDfwF7A',
#  'UUrzeNkbo0mEoANAHlxYP22A',
#  'UUJtUOos_MwJa_Ewii-R3cJA',
#  'UU3LD42rjj-Owtxsa6PwGU5Q',
#  'UU8uU_wruBMHeeRma49dtZKA',
#  'UUz7iLJYRhzoSVIXZ2dESzuw',
#  'UU_lePY0Lm0E2-_IkYUWpI5A',
#  'UUKq-lHnyradGRmFClX_ACMw',
#  'UUCWi3hpnq_Pe03nGxuS7isg',
#  'UU7HYxRWmaNlJux-X7rNLZyw',
#  'UUIB_kEcgT-lkTi14cqq4XqA',
#  'UUMNZFAhQSB314E_MG3IbTXQ',
#  'UUSNeZleDn9c74yQc-EKnVTA',
#  'UUOwaE3fVOZSRujo2OPDKCHg',
#  'UUXUPKJO5MZQN11PqgIvyuvQ',
#  'UUkndrGoNpUDV-uia6a9jwVg',
#  'UUq6XkhO5SZ66N04IcPbqNcw',
#  'UUD7FERT7OXNgLYkvEyy3qGQ',
#  'UUfzlCWGWYyIQ0aLC5w48gBQ',
#  'UUW6TXMZ5Pq6yL6_k5NZ2e0Q',
#  'UUAhplpsDYvq0W1F4hcSrqnw',
#  'UU8butISFwT-Wl7EV0hUK0BQ',
#  'UUh9nVJoWXmFb7sLApWGcLPQ',
#  'UUcIXc5mJsHVYTZR1maL5l9w',
#  'UU0T6MVd3wQDB5ICAe45OxaQ',
#  'UUHXa4OpASJEwrHrLeIzw7Yg',
#  'UUzv_k6lxolY4rzndB71AfUw',
#  'UUNU_lfiiWBdtULKOw6X0Dig',
#  'UUfJT_eYDTmDE-ovKaxVE1ig',
#  'UUi5CmpgqgeEzqVDumyEc9og',
#  'UUwk47V1XafOrw83d_vwwGhg',
#  'UUAEgip72UcvYwjcqzcJ1I2g',
#  'UUUlCfM_fqQedxqGPqLVPuGw',
#  'UUS0ZTW6ynY34OZodixxwb7w',
#  'UULXbBOFMlbD7l7ynTd80Ohw',
#  'UUKKpMJSgeZzyfKjyNtHtSsA',
#  'UUBQGd1sTurl5fZ5foDZtN5A',
#  'UUBOs6624oqScw8PaU-Jzw9A',
#  'UUnfZSN7A09wNwYiUoincXZg',
#  'UUdY9luYzi6V1-_pl2uezIHg',
#  'UUHoLIMtg_OigNlJmjHX9J8Q',
#  'UU2S0k7NeLcEm5_IhHUwpN0g']

# %%
def get_video_ids(youtube, playlist_ids):
    all_video_ids = []

    for playlist_id in playlist_ids:
        video_ids = []
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=playlist_id,
                    maxResults=50)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        more_pages = True

        while more_pages:
            if next_page_token is None:
                more_pages = False
            else:
                request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=playlist_id,
                    maxResults=50,
                    pageToken=next_page_token)
                response = request.execute()
                for item in response['items']:
                    video_ids.append(item['contentDetails']['videoId'])
                next_page_token = response.get('nextPageToken')

        all_video_ids.extend(video_ids)

    return all_video_ids

# %%
video_ids = get_video_ids(youtube, Playlist_id)

# %%
video_ids
# Out:
# ['7MxtVw8sBUs',
#  '_JS2S-05-60',
#  'QPh8Eas1W6Q',
#  '6MOyrQLCi3w',
#  'OuZHcBGH4js',
#  'ICAvOrofRj8',
#  '9REq8SAmZr4',
#  'QBc2QJIWg1o',
#  'X23ojGkIMLk',
#  'sHwoZ654xtk',
#  'Mj4qEGeMUIQ',
#  'vh4mcu1khj8',
#  'u4TOdBrGuE4',
#  'ywlEwMYIKu4',
#  'jdGJWloo-OU',
#  '4R950Ofg51Y',
#  'F7hVSVdR5B4',
#  'voRBOiit5uc',
#  '-5pA13odrIg',
#  'rBC9x18wKX4',
#  'v5v7GKBphiU',
#  'obegcD_VkLk',
#  'LxNyagCF0VI',
#  'ftFSXYOllHI',
#  'SH7TPbT6zqE',
#  '-QTFt7J2-Qc',
#  '_mW20F5TuXU',
#  'QXz6YMR_Gvs',
#  'tjC2JBiD3lU',
#  'H02RT3zGepc',
#  'jkNc8GYx3Kw',
#  'Kguq2k--jKw',
#  'PDmbFnI5KtY',
#  'CEuWGVJyCtQ',
#  'j7mUIyLI-oY',
#  '2A1MkNJ8XaE',
#  '3bXQj5gVcVw',
#  'UN7liVMbPAA',
#  'M6apz0AqN0o',
#  'yPn9Qblr63U',
#  'w3jQyl8ojJA',
#  'N3hQYiXppIs',
#  'OClJJ-Ask8o',
#  'PoOCscm5hTU',
#  '1LaSCxx3xhA',
#  'KqdMp7CAvOM',
#  'qa_0Qx41qQI',
#  'cT43rrgUrUY',
#  'gqGaESjaEDY',
#  '60T-uoy5oCo',
#  '80hwNQNcsHs',
#  '3dR3-S4wyBw',
#  '-aP4CY1_Px0',
#  'PBPax6GIb1A',
#  'm0FQSFZG76s',
#  'IQeL1EtrTrU',
#  'ct3fuxF_NuA',
#  'oQSX_y2wfhc',
#  's6VqgcBTnso',
#  'jJ9BV81SDCE',
#  'JAOfx5wbIfI',
#  'KN9nGtpTjL8',
#  'v_LIcVyg5dk',
#  'lzvCn8Tt5_U',
#  'VIYEJXhvw6M',
#  'caVfmiAJkG8',
#  'pr1cAfvCPh0',
#  'nhD7yC9JpiA',
#  'jyj8gCt1Qn0',
#  'fNHELaKeGus',
#  'RRUBMA6vbbU',
#  'jrX1d2u0reI',
#  'wySxTZdvk7A',
#  'D-B3WFW3ofw',
#  'IQysk15LIBM',
#  'PoIixN0sHMs',
#  'EtQWXg-XofI',
#  'TOb-jPbqKME',
#  'Ed0vEkdOTew',
#  'bu6Fow0ojpU',
#  '3h6bTTJn_dw',
#  'MEXLFMQKIE0',
#  'hPUN5i24Ifk',
#  'shYpEeDUJWw',
#  'k0ZzOfUeYBI',
#  'oWP00-NNpYE',
#  'LnGz20B3nTU',
#  'GHxOtLtZqWU',
#  'zZxsDnncA5g',
#  '4_Np7GSZHQA',
#  'LqM48no-Rsk',
#  '34cvSgkuaqc',
#  'NEuU1gaUyww',
#  '-kpPNWKv3Qw',
#  '5OSzlmpSOZY',
#  'Y0M4J8MtDaQ',
#  'T8uGSuL_-dM',
#  'PD7ZdXfKbq0',
#  'MLC9Wv4owGM',
#  '5Ey1Fd-t4lY',
#  'WskJOx_ZQys',
#  'WRy6jTEMWKI',
#  'MvLF9v6wqTo',
#  'hx88yKCCHRo',
#  '1TrX_771sA4',
#  'WWUG7T9ixTs',
#  'qi_xnE8KlCk',
#  '5Uxlg8jQ7dY',
#  'F3XosaZTTfc',
#  'qzHn6_keDTM',
#  'WWTf5J5NDfQ',
#  'oVE2Nb3faVc',
#  '5-zWaAY68XQ',
#  'iwUli5gIcU0',
#  'S2zBHmkRbhY',
#  'Z6wkKjndiPc',
#  'Kx8hpvhFm30',
#  'GDEWaMIBIE0',
#  'VkoJNUCXAN0',
#  '1CoAcszuX3o',
#  '_cl8UAPofsA',
#  'AYxgZT3SgcA',
#  '8gaLT_g4AC0',
#  'GJSJQC7J1dc',
#  'fZqzdbKrg2I',
#  'FAJHD-uKPJI',
#  'iA-ssRpJh2E',
#  'nPRTM54sWX4',
#  'dLkj1wKj6KU',
#  'p6QCCUhYT88',
#  'KMxNyS6KRag',
#  '-PLZW56ACMI',
#  'rIZh6RTXsf0',
#  '5spsj45-SwM',
#  'RLtmQ954ECo',
#  '_8E7x0xB9Ew',
#  'adikYLNoHIE',
#  'oyo8OwTMM38',
#  'Lx779LOZTFA',
#  'iDV0Zh6HDGc',
#  '_2VDsKU-7SU',
#  'pPKtYEm4hts',
#  'FhpJLLfrx4c',
#  'J3cyjmuN9vA',
#  'IP76UJ4nZ70',
#  '4wbBk-T5QHk',
#  'proZkvEICXU',
#  'CwGdp2YgaiI',
#  'amA0VRkP7r0',
#  'hCd6m-GUjKI',
#  'Xsp81lvOZIA',
#  'lbS6eVyYWX4',
#  'DEWMOBRWXeY',
#  'rY_21kkVeiU',
#  'obSQuZe87Ac',
#  'DFkhUhrh_XE',
#  'jkmGgYjwrNg',
#  '7JgbyhlhfyY',
#  '8gQA2FqB0OM',
#  'ctT0UKMeTbs',
#  'iKZEtEn-Inc',
#  'n-yO6WXE880',
#  'qiLjmKoP9ag',
#  '9Hoo_qdjSio',
#  'kNxXr20tz9c',
#  'OsNCY66fgT0',
#  'zf-sOpLcR5Q',
#  'Wl8DVfIhmcg',
#  'IY3yvGfCvj4',
#  'dUHboiHE7JI',
#  'UQgyQeMGvTc',
#  'gfdEUSMJHS4',
#  'RuomXisQKWc',
#  '0pG6k3QEXl8',
#  'I6ZBJo_xt2I',
#  'FJFlgIm26og',
#  'ZPDpIceAi8M',
#  'XjNF7SMYhYk',
#  'x8e3czhaTU4',
#  'ci5-CptHC84',
#  'sQ7tObH5CGY',
#  'OBpDmfxcKeQ',
#  'GPm9Yzvt25c',
#  '0zveIwThlfE',
#  '3fHOGKMJxNc',
#  'YJgLw0LxD6Y',
#  'wk-q-BMKkrQ',
#  'P-DEkDANmjs',
#  '6S0bAv_ff_0',
#  'f5XFbWnS77Y',
#  'jjIro-dV8M0',
#  'Q-H5DT_c6KU',
#  '4SyIB4u8-1o',
#  'hhsAdo7UUXc',
#  'zdOgm-QuKgw',
#  'mMd2rKK7dWc',
#  'xrid95vgoJM',
#  'smo-eqlWSt4',
#  '80i8rLQtO3o',
#  'B6w0IeLMZok',
#  '11OuH8TcJLU',
#  'ZqCybBeLSKI',
#  'CW-Er8slv9k',
#  'mhe9Vs3jQes',
#  'l-83AtuHqM0',
#  'ZbRkGbkJVI0',
#  'K9BOYP03f_A',
#  'XaSZgrgv1PA',
#  'r6hEuY1l1Qc',
#  'ZSwXRn50lnA',
#  'DapX6sp_cVU',
#  'FAk4xjmj3UI',
#  'nkmm5cXhcL0',
#  'qSUEqVEhUAc',
#  'HWIHVQMCMGo',
#  '3FMCFzmnVS0',
#  'dt1MQmMaf4E',
#  'qtIGBpXD1hI',
#  'qummiNwSsqA',
#  'ykI1yk0FzfY',
#  'f4PzewUT8Dw',
#  'Em0wU0Ac3f0',
#  'jDrGnySQzIM',
#  'PmqSSBmDQk0',
#  'Un9ndLTfjus',
#  'z5z3bWHFUkk',
#  '1CXgd4pm1dA',
#  'obKGqCeB3Vs',
#  'TBg9eFHZ_2A',
#  '-w5ymDd7w_Q',
#  'sOv6MS67P88',
#  'oxIV73D5MyM',
#  'TDlahsQt-Dk',
#  '36cmZIN_u20',
#  '_ahKozEk7OM',
#  'klkHi7AY-0A',
#  'DK5qR841RGs',
#  'aYzO5HJl80s',
#  'xmaE9rUX1Cg',
#  'yKb5YVw-CR0',
#  'hsIP4iH25Wg',
#  'JVmxa9Lcr3c',
#  '4GKWcBohbY8',
#  '0RLB9U_WOKM',
#  'yzV90Mircys',
#  '2DY4UlPu-fk',
#  'QLQ5XIx1ixs',
#  'JEnGjrY80yc',
#  'fn2MojTTGMk',
#  'oJQ0bLYGWIw',
#  'eyv7SSKnlgU',
#  'AsYrvxfl-D4',
#  'sewifdXqrQ8',
#  'edcTHQ_oObY',
#  'T8W1VIQRkp8',
#  'KADffdg8DvE',
#  'Tqq_4f-hThs',
#  'BCxyJrXkKOc',
#  '1dQxnxRRdos',
#  'mdrTRzwb4J8',
#  'SnnXNUdy0T4',
#  '1huZVtR2mQg',
#  'xmJSupyWsTY',
#  'YahJhAXyuPY',
#  'tQIdlcOZrIU',
#  'e7WbzjsicLE',
#  '5hC0vF7LIKI',
#  'HoCVzkyiXe0',
#  '-lXMJ95KocI',
#  'OIVhhgNQjak',
#  'ejSmCgERaZw',
#  'yTlwG4cdasw',
#  '5PcvzcQMrtg',
#  'Qxg_0oc522g',
#  'RKgJLjSzdYE',
#  'Bc8iAKBB9-Y',
#  'XxCUVqhovEA',
#  'jqpmeTStCZ4',
#  'BJCf7qZpljI',
#  'tEHO546a9o0',
#  'krFHfkiANjc',
#  'puVkxXMymg8',
#  'eeLd6cZfLks',
#  'WhHn9emIKHI',
#  'kl-th7gl0HQ',
#  'YjIdV-FLjgE',
#  'j9qS-BP4Vi4',
#  '1Ia7eReQRdA',
#  'j747Xb-ik5A',
#  'FGlqxkpYVMs',
#  'bNggG3odL50',
#  'VJWIsdyu6-g',
#  'zWftt3gGhEA',
#  '7MUp2lR17BM',
#  'lvDX9ynVeYI',
#  'cK1WRaW1j5U',
#  'Coe_f79Xc2o',
#  'jTReVUMB4co',
#  'pRKpaZJJRxk',
#  'QBk-ADiaN9w',
#  'n_3YgsWx8zA',
#  'BrBL5LKR7uk',
#  'bMQzLdtGw8M',
#  '5Oayd3Djqok',
#  'ZuPv-XJpPUI',
#  'yfbgyhnfZhk',
#  '4ueFRtXd5Ak',
#  'yiBX0U8nHYQ',
#  'pz3pEyfRlOY',
#  'D6dmBHgWIiM',
#  'uWTxQ01FFvo',
#  'qL_DKoBOLVc',
#  'WTWpLWC7m1Y',
#  'PM4wkJ3PBFA',
#  'fkGTn8q6qRY',
#  'KsJsmi7vPbw',
#  '5X9gZNxh-Dw',
#  '-LhFz1PfOQI',
#  'W6CUkbHL7HI',
#  'qgI_AIiJRXI',
#  'NlsKX_Ge9N0',
#  '9EywgO2e8W8',
#  'tQDdv_WqCgg',
#  '8NwN_mKxGsg',
#  'YmvteHKlSNI',
#  '5rbmdPUvpWE',
#  'u-HgQdxFMXo',
#  'FnN0ZMuhkFo',
#  'MlRhv3epywM',
#  'OMPa8tXcbxA',
#  'vrr28goRXiA',
#  'TrhFbLTezVA',
#  'ewf9g2LyZK0',
#  'ptMDiJVaE-0',
#  'PSEUKOtYowc',
#  '-HrWSXGvZek',
#  'pg1kT3zmSCc',
#  'jjhe3hTFE0M',
#  'Biow-Qkst68',
#  'sLT_URKPwMw',
#  'i7zZZKLZNV0',
#  'Ik4nqdQMYjE',
#  '6fR-qVvmNSo',
#  'L4GUXFsNEFA',
#  'g7ETj7vbKPk',
#  'b0y4UmJwLQc',
#  'LVNYnjlL6JE',
#  '27XWLLDBhwo',
#  'uuP0YcOaBPM',
#  '-pAdzlOj7Ig',
#  'dB3TaDRnyGw',
#  'll88h9cI7aM',
#  'hKSMQKKKeQk',
#  'UqprG6a08vc',
#  'ed_QgFeWsZw',
#  'tytTEwEUmgY',
#  'mlXyqb4-VzI',
#  'D8Cria0ojTU',
#  'EnoyUVpPmsw',
#  'mR4xZ2QkgTM',
#  'qUYCeBJVrik',
#  'dtFot_JL0EM',
#  'wiYs_f6uX3U',
#  'xPsphL9OCSM',
#  't3bjUUO9T0s',
#  'FqUzXRD2u5k',
#  '0Muk7Fi8p08',
#  'qQfUwClQBPk',
#  '-FWszJyX8JM',
#  'wRztRXIs4uI',
#  'HRWHvrrlEYM',
#  'keugNQCVREI',
#  'Cua6T-FvcEA',
#  '_h20vPn2tLs',
#  'cM0gRwDKfgw',
#  '33uXQRjCuPs',
#  'aISC4VG6jeg',
#  'WFDSV6fxOp4',
#  'NfpzsiCczXc',
#  'ClSLdoNKZMI',
#  'f2t9I6GL_aY',
#  'Y4TUaowBVCA',
#  'TViSG2cs4EA',
#  'uJ0MOixTums',
#  'I3J4HLF0dO0',
#  'nr7Bkxa3awM',
#  'DkCbp4cUHic',
#  'QX5CDZxEvXY',
#  '4dxT1PRq1GU',
#  'EyJKNmO22uM',
#  'sHKb4GBqam4',
#  'e9nRdQFNXsU',
#  'BnbaEr8i_y4',
#  'h_YX-42H-dE',
#  'wpT9C3HsIBA',
#  '_D5nd5SZ4s8',
#  '3t0NRuK4Du0',
#  '018vb5hDtE8',
#  'd8aFKwg-_Ds',
#  'tPLVozTPXbw',
#  'dJmiFgOohOU',
#  '58c8JV_s_-U',
#  'jAjPVfINqHc',
#  'BeyOsmTTYW4',
#  'Xzvn_kBmIRw',
#  'WGIe_HgIdBg',
#  'mzdp4Qp7kqs',
#  'CZBtampVxCQ',
#  'LhZKbdool3s',
#  'KH1JbblXpGk',
#  'wip8T__eTBw',
#  'oK1c73aDw9E',
#  'sCQXelvnjGE',
#  'I3Gt851p__o',
#  'NyiiwpdZlBg',
#  'Gwq95xRoIvg',
#  '4Rin_pHj7Wk',
#  'zpC0EwXzFyw',
#  'gW4Ob-NmSug',
#  'Jku6nkiNY-c',
#  'me7mEXA1F80',
#  '1IGk8ZBo2qI',
#  'En1v0Ide31o',
#  'GeAEC15Gr8U',
#  'KJr1sM8TVTA',
#  'FJC_-UUJ0PE',
#  '4WBpEHMWc9g',
#  'GYJ9QSOKPtk',
#  '8AIQD0Uhxn8',
#  'hOncXW7achc',
#  'VvNgPpkm5yE',
#  'xLxOLg5e7bA',
#  'kiQFs5mTemk',
#  'fdhG1KNtkbQ',
#  'QjRs70Vjgig',
#  'XFMHS62MnjE',
#  'zMzLeO380sE',
#  'Rp8CaO5U2_I',
#  '8G_Qu6cL0mE',
#  'ERFSCsnwwWs',
#  'yZFTUIazesc',
#  'H_QKrO-3W1k',
#  'M2QN18McpEo',
#  'KG7lDoMqx60',
#  'yn4wvoLpLGU',
#  'ED6oG3k8Gkg',
#  'Y0VdFdNPPfI',
#  '4H0Io885GKE',
#  'w-sxUFaBGJU',
#  'utkikcNE0es',
#  'G2xtClOCB2c',
#  'oVK8Xxe4yYQ',
#  'KouK1INq7Gg',
#  'w6ILosd4me0',
#  'LY6X1RoIMAw',
#  'tNlPbvDDUj0',
#  'N5mGXJLrtrs',
#  'QPNstEMGCCU',
#  '-syQ0__fAEg',
#  'T6x6gwLezNQ',
#  'qc_XAIG2oMA',
#  'TBsup9WEvZA',
#  'yM0LGcN1taw',
#  'KAKdtGH0hPs',
#  'Ek371YWbBQQ',
#  'CeNHMz3_diw',
#  'CTcNhRfXRHk',
#  'ZRCAfFKtbg0',
#  'zhaA68PKX_s',
#  'gn5aEaD_P9k',
#  'UZ2umlnPBjk',
#  '5c-oHym_Lpg',
#  'nv6ImxytHbc',
#  'NVf_PxI_5jo',
#  'FRTHAg8pGVo',
#  'WYSCgN3auLc',
#  'fIp3QXzR5Xs',
#  'PrnlFDs3h2o',
#  'XWY7fTTig5Y',
#  'WUkzkhi5z_4',
#  '4nXYvFXzxV4',
#  'DAttxtN_8Ko',
#  's95US0HeRJ4',
#  'bvG8YXpKqvc',
#  'Cp22fC3v6o4',
#  'DmyhreJS37Y',
#  'jRmb0jMNUKU',
#  '11aNvvj2r_E',
#  '2mNZQV7wFFo',
#  'ikd3qlE2Oeo',
#  'stbBjQYIP7A',
#  'EhLhcQb9-AQ',
#  'OD6kj7awY9s',
#  'tfKCxwERjz8',
#  'iJyGEuiIjOk',
#  'KDglvy6_zbc',
#  'FgfVve3SI0k',
#  '4RRSUJQUrCM',
#  'TmcvTHFDEbg',
#  'MG1wtNXLu4w',
#  'p6Yy9KCPTGA',
#  'y_tjni-h9HA',
#  'CYdbniiYE-M',
#  'zA44Kz1XHxw',
#  'Aj-dVGYBK7k',
#  'LLTixDNZXwU',
#  'PdzqiGtNh1g',
#  'IFX9e9SqGlw',
#  '8cExLG1eIRI',
#  'VoRo3Z74gAo',
#  'eyi3sO8SOhU',
#  '7YakUIE6ifU',
#  'IuHdR3qg-Dw',
#  'ZqmRr8wGmlc',
#  'hHDU4IenP9g',
#  'p2H5N3snrHE',
#  '7dKO6PeVTKQ',
#  '6RMpCNrc7Ds',
#  'zLcmOK_xu9E',
#  'riLIjxU25m0',
#  'nOnekh2hp68',
#  'mIM7YFt5eXo',
#  'xlZnnHEjV48',
#  'jK8jYaMP-QY',
#  'JdtH9A_FCv8',
#  'cVLXkMC8-x8',
#  '3r_yg-FTi5w',
#  'Ux6rz9K0RvQ',
#  'Dp6HfX4qC7A',
#  'FkxaBRiXlVc',
#  '3TFb8oQs7S4',
#  'RvRiU-CZNWM',
#  'X-L1YtdBal0',
#  'vypOcYIHWvI',
#  'RgEj6cfIap8',
#  'vowatddb-dM',
#  'IFAmuLg43Jw',
#  'HgtsfqQMFnw',
#  'gkeB-XDPa-w',
#  'd11vwgx2pWU',
#  'FMIcvF7CWOc',
#  'VxFJcfqsbFE',
#  'qWS3pYNtYCY',
#  'VcnanUQVAn0',
#  'Qg5Wh-8KyiA',
#  'VnoGWByeODc',
#  'JrrES2mLIF4',
#  'ngoT0Ua5EUg',
#  'Pn8ZIM0My9I',
#  'NfUsshftlg8',
#  'r8uUzzj0doE',
#  'DLp9lwgrWGU',
#  'vcDq3RlBAqg',
#  '7aPnoGXq9Is',
#  '054kE8MyxiU',
#  'BQQJxEa-0kY',
#  'ozWNNNxLW8E',
#  '7o28s7byamE',
#  'hu--qdGvEz8',
#  'bNlYOxckdJA',
#  'P1_a0GxX0QM',
#  '9z-ILKbs3-I',
#  'iIb8U7-Zddk',
#  'WxdDiWExfEg',
#  'RnVoZinz1YY',
#  'UDH2qjZqTrU',
#  'NouPWHYsqa8',
#  'G9v5bxMuK2k',
#  '-2ETF_kedUQ',
#  'm2PTskXupnM',
#  '7DWnoSV2BCk',
#  'vus2df3aKtY',
#  'FgexaHwqyeM',
#  'Jj0_Ekz8cbE',
#  'OiWVJed3bvQ',
#  'ca8DXnY3Gws',
#  'lguyRCOToF8',
#  'QzmfMUqSXzA',
#  'JaGpcdKTG_0',
#  'nDkSu4xF1ME',
#  'PcAZlP6XEkk',
#  'SRYmZ-OSkVs',
#  'IH_iExPV1no',
#  '-PWlPQIk9Mg',
#  'FfcwYazQqV0',
#  'XGxbhu9-FWc',
#  'D_vLHRB4kOw',
#  'X4yjPwI1zLg',
#  'SSqp1tVFj4A',
#  'PmgxQUi4sF0',
#  'R5iAvF8sHpQ',
#  '28CdRrL4VHk',
#  'Q-XQrehoBv4',
#  'kshBPb-qUTw',
#  'GpEu23DkpwA',
#  '_OAgw3S4DPs',
#  '3eylkPgxiBc',
#  '6Wl8YaXigXg',
#  '1Fr9pLFGwig',
#  'P8ERbAdZgRI',
#  'IrBdEPeRWYc',
#  'vVAy9KcoHpk',
#  'jnBKzCcA6YQ',
#  'IzTLxFOETgc',
#  'c90bm3m0Q7Y',
#  'EZOl0J5vcDg',
#  '2smorAoEh88',
#  'hPBPixqFvxY',
#  'u8G14C4PgVU',
#  'kU6O05TcWaM',
#  '4S0i638YJ34',
#  'TpU0EkAYbz8',
#  'HnUdvJudneo',
#  'JfoIPcEupVk',
#  'YR4Rw5Wy59A',
#  'O4sIwhahak0',
#  'si4029HsIl0',
#  'zrI0FlNSSA0',
#  '2An7x1zbijM',
#  '1ujfIvJnB9I',
#  'XAvTbSAHpxA',
#  'y6B2wkEMedY',
#  'A2Z3_jt6rhk',
#  '2So8bRg6cSs',
#  'zHpxMIiJrTA',
#  'YwuvnwhGKNc',
#  'lqOrULJvYXg',
#  'QEDZaBMozIo',
#  'Hyhfa7z0jTk',
#  'L5Cis5bOwgw',
#  'M1I5HlzQges',
#  'T_-0l0ORi5I',
#  'w13zJB_jyBI',
#  'oZ9rMrqyTbI',
#  '6BrYKdqq4uA',
#  '1dAvbIMrLos',
#  'lqYxmYMkfK8',
#  '-JTU734oMfk',
#  'HVpbmu7rFYE',
#  'NQQ3DRdXAXE',
#  'xpi-M2j3NmE',
#  'X07w7QFoLpc',
#  'RRnThAtKuq0',
#  'r3zOpjEOkgE',
#  's-XYFEzy9Wc',
#  'iBh1wl4o6V4',
#  'L6lXKdP4Qbg',
#  'xGDl6rlBygU',
#  'SY6y6Y8C594',
#  '1RUj2aLQx8I',
#  'MkzZXSw1Glk',
#  '9neDFXTxKxA',
#  'UaNNVukM27g',
#  '3lN0-S3symM',
#  'M-AN8eWLxms',
#  'MXFZhbvQqM8',
#  '54n61XjKifI',
#  'pyWYIRR8rrE',
#  'onwRfbt--cw',
#  'u6P23ouSYhA',
#  'RMMVuvS7S_g',
#  '5AwbPAV8FS0',
#  'A2OQgU0IRNo',
#  'x5Q_nrIqFik',
#  '7ja2ELBVMlU',
#  'Z2MyLQa_vVw',
#  'JTlB9fwYRk0',
#  'OJDf_fTENJ4',
#  'nqCkdqhV-JY',
#  'b8t8lDL13sg',
#  't6CD1EwU5kc',
#  'eIxHe45hzhQ',
#  '3NJOWWvNK3I',
#  '4_VtMWJSo1o',
#  'OybXWl3IWvI',
#  'nRHPQ5ZeB5Y',
#  '0JWC4M0Qhqc',
#  'oNvyvYGw5n4',
#  'GaZRuchRCyw',
#  'EBjYqC3aNTA',
#  'QMP858aZcow',
#  '0ItYIoOrrUs',
#  'KzTFoUbThvM',
#  'bBJd0oPdNak',
#  'Yk-unX4KnV4',
#  'z0_xrtFdFj8',
#  'vVpkXEIn-q0',
#  'aipz4p7GDL4',
#  'iPdO9MwdcLE',
#  'YPph59-rTxA',
#  '-2U2CMYom00',
#  'KEeUR8UDy-s',
#  '0jTtHYie3CU',
#  '2RWwN5ZT4tA',
#  'rEWPqw6rMGI',
#  'o-wsyxWbPOw',
#  'xpIFS6jZbe8',
#  '-zbLpoJVBMI',
#  'scSc6YSanQ0',
#  'FqNpDNmpcEo',
#  'vwvdtXMcNzI',
#  '2qVWurPFwfc',
#  '35g8fCi-kbw',
#  'n6MiRgxN5iA',
#  'ammCGdzSoag',
#  '15c7WD-lKUY',
#  'TjGFBQC27ng',
#  'qUK5Vk4NvBw',
#  'cnqTU6eJwH0',
#  'k8YxyrcAXJs',
#  'VvnOXDCVm8k',
#  '68GGPK3WaqI',
#  'S4Lei5mOppc',
#  'tG_UW_p0UqE',
#  '143WWA5Sy9k',
#  's1gD35Z4eUc',
#  'nrEJGGxcoTc',
#  'KfpOuSH9gDc',
#  'sICJ6a2wX5g',
#  'iiSZqsQKNX8',
#  'IoUWD1h6xUs',
#  '7JCterBrcvk',
#  'KU__lDJj5iU',
#  '8nTmuKI2oyA',
#  'SaWxVk7rDp4',
#  'n7kjelw9s2w',
#  '8Pi36Nj6P9A',
#  'hOUrxTeBJQc',
#  '-ONQ628CXKQ',
#  'sHRq-LshG3U',
#  'EMq4PH7PCeA',
#  'BlSrorP32WM',
#  'pPfw2fzwNiM',
#  'hcHSSyHbgMQ',
#  'ITAxTid_1YU',
#  'fU3DOXjwufg',
#  'tJI-1mHeXoA',
#  'SVtRsDhHlDk',
#  'OtqQYqRNDGI',
#  'uic34RTaI-w',
#  'GO420aMtHfk',
#  'KQ80oD_boBM',
#  'r-DR9HBaipU',
#  'qV_AlRwhI3I',
#  '41Clrh6nv1s',
#  'YR9Faf1uZDg',
#  'myhoWUrSP7o',
#  'ji7DtgUeKCI',
#  '4039x4r-hGE',
#  '78LjdAAw0wA',
#  'yUrrf3Pm33s',
#  'domVw8isGOI',
#  '_0rHU6qAQe0',
#  'tnpV1etgcxs',
#  'Uf0dO-pgOrk',
#  'N97MhZEp2UQ',
#  '1Ir1NgCuI0Y',
#  'd6FeV8WXPWY',
#  'WRF_dKZ_i24',
#  'UpaEjBOMNqs',
#  'UKuK2fXu_dU',
#  'Ft4GVkQQtgk',
#  'BBDiadC8BvE',
#  '7VcdvSyoxnc',
#  '8Vxjp2KVHqs',
#  'Kq9dkZu0bpg',
#  'omdhf8d53FM',
#  'apf6A3Nstm8',
#  'jf3j0lWmFPU',
#  'g7on3Rw0Ovg',
#  'rLawTH--l2Y',
#  '-pdXWmj9xxU',
#  'vfV4nm004VQ',
#  'oHUD2T_VXfI',
#  'uXLnbdHMf8w',
#  '5v_ulmGv-gc',
#  'q6Lf2yhvluw',
#  'iGUiLWFDWfk',
#  'SsGKZe4dVyk',
#  'RAMxzqSMDKE',
#  'YbTMIxjk4hI',
#  'S_CuB__nsmI',
#  'KEBVcVwFzaI',
#  'vQGJvmhpq_s',
#  'Xgg7dIKys9E',
#  'UuR3nomI5AE',
#  '6tQtwqthUMI',
#  'QN3wXPZSjpE',
#  'rdo8YBasqqA',
#  '_rbrdNTpZGo',
#  'ELFGsNqZrlM',
#  'PWmxLYTixAM',
#  'I3FBJdiExcg',
#  'hO_YKK_0Qck',
#  '2KkrtG5IsHo',
#  'QQLToUlgN7A',
#  '6aaIbd-GpZs',
#  'lsXWVPzwZPk',
#  'AqPquogHwq0',
#  '742LQ38OioU',
#  'B1g_yMKpdwo',
#  'zGlJ-QndG8E',
#  '6fwyyRgZlD0',
#  '-3d1NctSv0c',
#  'WnB1jsDu900',
#  'XjC3FPL-S78',
#  'txR8_jGi0Ls',
#  '4qZINLzwYyk',
#  'mR2NCRgtLPE',
#  'mEZ1Hj5yQ-8',
#  'HJH0gfY6EUg',
#  'BZFfNwj7JhE',
#  '_K6cNdgN3CI',
#  '1aXk2RViq3c',
#  'UcilY6HDuL8',
#  'jam0xApfC-U',
#  '4OZip0cgOho',
#  'QBIe4nbmZfA',
#  'KHAuuOQui2U',
#  'DW55gaQ_Egk',
#  'lUUqrRgerd8',
#  'ei1m5lDQyBg',
#  '9D7GzskcyUk',
#  'agHKuUoMwvY',
#  'nUOh_lDMHOU',
#  '7O4dpR9QMIM',
#  'QWgg4w1SpJ8',
#  'fhi4dOhmW-g',
#  'GmW4F6MHqqs',
#  'MpF9HENQjDo',
#  '9ZwVqXUHf6o',
#  'a3VWq9smqhM',
#  'oMdVg6GPODA',
#  'vy-R4oUZaC8',
#  'XGBigjVy2Eo',
#  'hpMc6TgT34I',
#  'Fs_LG5Y8GIU',
#  'Ip50cXvpWY4',
#  'imMPnCHvbkY',
#  '3bes4U4MHPg',
#  'qP0hRF-lGqg',
#  'aaAZXeuPIXk',
#  'C4OPn58BLaU',
#  '8igH8qZafpo',
#  'xjhW1rSQeik',
#  'DM1eE_Coh6g',
#  'f6NPw582FFc',
#  'dlZWB2D-NaQ',
#  'foggudmDDvY',
#  'n3vw0M5RrPU',
#  '2OnXytYziF0',
#  'Q9FjwzKFPuM',
#  'VN12ZPFsApM',
#  'WKXtTo7lqmA',
#  '9-2OKLZfvbE',
#  '3TrAYmrmA8o',
#  '5SjK6YCs4o4',
#  'iqG59TqfFdY',
#  'NCyPY-jfb3I',
#  'DopikusDfk0',
#  'm5pwx3hgtzM',
#  '74Z3F7i4qcI',
#  'zSwM5uVeylU',
#  'BXmEmIK5aqI',
#  'SLC5sPZSLY4',
#  'EAezvs0eL1s',
#  'k4r_NtB4JVQ',
#  'ZWdyBbgGZBQ',
#  '1FrY7ARSf10',
#  'LGEuDWjWQes',
#  'fjVVtvp5X0w',
#  '-kX2b6TF_9k',
#  '3ysXGYjvbSU',
#  'akbU9KOo_Qc',
#  '3BEtGaz70rQ',
#  'RRXWJVX0fE8',
#  'k-gin1qfzi0',
#  'Zz_Mx1UPswI',
#  '3Mm1U1CbzNw',
#  '4yI3vVe0Jos',
#  'pWVQ0vN5uig',
#  'a-Syoa9mPhM',
#  'yukdXV9LR48',
#  'XWetgrNas-k',
#  'yIJrCFXs0rU',
#  'Z9dGmL2G-4k',
#  'T7BQJJIGrmc',
#  'T77uVbLhroQ',
#  '1Cf7SdnBncg',
#  '3cDM9Z-fdz4',
#  'Yr5T3T4tq-g',
#  'KMOA5arCi8g',
#  'Z_KFh-HqaBA',
#  '5jntoZX-Tc8',
#  'AxP1CL0yaFQ',
#  'zF_Q2v_9zKY',
#  '4CpmB4TR2C4',
#  '6sJEnzDjJqI',
#  '1UjMBw_7Gi8',
#  'q8cEt8gj3zY',
#  '_CS4u9cORwA',
#  'XTrlMQXYqts',
#  'smeFkHwnM_k',
#  'sq5TnVJWv6A',
#  'XoUyK3XHZHs',
#  'tv1e22u2COk',
#  'j-Z-je6K4Yg',
#  'sCOX5yShmFA',
#  'FBgs-BSTIJE',
#  'irjTWNV0eAY',
#  'RRSRKf9eQxc',
#  'IFceyuL6GZY',
#  'Y_SMU701qlA',
#  'qfRhKHV8-t4',
#  '2K9Ow0jti_4',
#  'oWmWFGP9lOg',
#  'uxgkWssqkAU',
#  '0wj8F_oBYEE',
#  'FXBiCSPY9ts',
#  '5x51tEELwZI',
#  'biFzRHk4xpY',
#  't4cNPZRJRds',
#  'Ik7VxjYD1zQ',
#  'tSY7wXv5W-Q',
#  '5avXm1Vp_io',
#  'AZ7tzjjtE6Q',
#  'REEYqYEtqAc',
#  '0ujRg04fDW4',
#  'FRDKeNEeNAQ',
#  'mI6KDerAGOA',
#  'Tnu_ykn1HmI',
#  'Q5cloPHV3bw',
#  'Ehutnn1AqbE',
#  'HfRG0-Lbl04',
#  'UmUDpxnmLW4',
#  'LUsoHYyOTCw',
#  'IH_TJnT3_es',
#  'vIImoKpKWIo',
#  'B1oqOkyGZGQ',
#  'Rq3lEPKvKKo',
#  'TYTvLgi4mVc',
#  'XPRk6T0JNxU',
#  'cF7BLbsDEkY',
#  'iLCDSY2XX7E',
#  'Rd6F5wHIysM',
#  '_Udb5NC6vTI',
#  '8QQjOSB0ERo',
#  'r2TUTOHoYGA',
#  'l1mdtMiJd1c',
#  't1eHNDB2LOM',
#  'UOMXCDwYzAY',
#  '13EPujO40iE',
#  'NUPjbWsSe7s',
#  '2X4EKHL5g1Y',
#  'qU3fmidNbJE',
#  'VkryCO8uNwc',
#  'Jkf5pTLTTFY',
#  'IrZLjZjqNkk',
#  'lxd65uDf2q8',
#  'wXHJEFJOUTI',
#  'ouvbeb2wSGA',
#  'p09yRj47kNM',
#  'EhhUIrLvX34',
#  'TT-w0-obo44',
#  '0Kr1eh1wwb8',
#  'qpWqrIsaKwo',
#  'xspOEnpz0uw',
#  'SDIrnL6nUkE',
#  'QqLEfZXPdU4',
#  'YOjFnmizIU4',
#  'SDhwMSGFrcI',
#  'dyT_3fRcTRM',
#  'xNQyw1iDTGg',
#  'ZdktXRIj0Tc',
#  'utPBI1qitJU',
#  'NkS__W7SU4U',
#  'A9yKMdCT2vo',
#  'tkuzSfIgehE',
#  'GhxSQpzhXZ4',
#  '639-c_OVUkw',
#  '54ojPbRb9S4',
#  'EghpdIk3pLU',
#  'FmFs_narvZQ',
#  'a-xiUiKIxBA',
#  'ypn7-I6-9A0',
#  'ElUtkHy3-zk',
#  'XZvG0hI0dpA',
#  'OLTgI6DAQ_A',
#  'eV7t1G5noig',
#  'qEL7wVKsV-M',
#  '8BlRT7Ktw1c',
#  'Bk6fob_Fuf0',
#  'huuCpUodF_I',
#  'Kbzr7p2cIbk',
#  'OQMtJbM90h0',
#  '2qfAH_p5DQw',
#  'VJ00hiZtEUw',
#  'dqfkT8hMKFA',
#  '2Rb4e9TQvBw',
#  'v9zOpJIBci8',
#  ...]

# %%
len(video_ids)
# Out:
# 30134

# %%
def get_videos_details(youtube, video_ids):
    all_video_stats = []
    for i in range(0, len(video_ids), 50):
        batch_ids = video_ids[i:i+50]
        request = youtube.videos().list(
            part="snippet,statistics",
            id=','.join(batch_ids)
        )
        response = request.execute()
        for video in response['items']:
            video_stats = dict(
                Channel_Name=video['snippet']['channelTitle'],
                Title=video['snippet']['title'],
                Published_date=video['snippet']['publishedAt'],
                Views=video['statistics'].get('viewCount', 'N/A'),
                Like_count=video['statistics'].get('likeCount', 'N/A'),
                Comment_Count=video['statistics'].get('commentCount', 'N/A')
            )
            all_video_stats.append(video_stats)
    return all_video_stats

# %%
video_details = get_videos_details(youtube, video_ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'Absent Data',
#   'Title': 'Microsoft SQL Interview Question | CASE & SUB-QUERY',
#   'Published_date': '2025-04-27T20:10:19Z',
#   'Views': '7790',
#   'Like_count': '224',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Uber SQL  Interview Question | Pivot Table | CASE & FORMAT',
#   'Published_date': '2025-04-20T02:10:46Z',
#   'Views': '11656',
#   'Like_count': '386',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SQL Interview Question | Tinder | Subquery & Windows Function',
#   'Published_date': '2025-02-24T16:44:53Z',
#   'Views': '10371',
#   'Like_count': '544',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analysis End to End | Project Analytics | Beginner Friendly',
#   'Published_date': '2024-11-22T17:42:07Z',
#   'Views': '70296',
#   'Like_count': '2197',
#   'Comment_Count': '137'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'UBER SQL Interview Question | Late Delivery Percent | DATEDIFF,  CTE, & CASE',
#   'Published_date': '2024-10-27T16:12:42Z',
#   'Views': '18992',
#   'Like_count': '1080',
#   'Comment_Count': '27'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SQL Interview | Top 25% of Customer Sales | Visa | Percent Rank & CTE',
#   'Published_date': '2024-10-25T07:19:01Z',
#   'Views': '16444',
#   'Like_count': '907',
#   'Comment_Count': '22'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Amazon SQL Interview Question | Biggest Black Friday Discount | New 2024',
#   'Published_date': '2024-10-20T09:35:36Z',
#   'Views': '14390',
#   'Like_count': '778',
#   'Comment_Count': '17'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'End-to-End SQL & Power BI 2024 | Create a Database | Novice Friendly | Project Analysis',
#   'Published_date': '2024-09-14T15:58:35Z',
#   'Views': '29467',
#   'Like_count': '865',
#   'Comment_Count': '55'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Amazon SQL Interview Question | Subquery VS. CTE | 2 Solutions',
#   'Published_date': '2024-09-06T11:18:00Z',
#   'Views': '32855',
#   'Like_count': '1359',
#   'Comment_Count': '25'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Most Common SQL Interview Question | SELF JOIN | Manager Direct Reports',
#   'Published_date': '2024-09-05T09:27:27Z',
#   'Views': '13213',
#   'Like_count': '582',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SQL Interview Question | American Express | ROW NUMBER & CTE',
#   'Published_date': '2024-08-30T17:36:00Z',
#   'Views': '12467',
#   'Like_count': '759',
#   'Comment_Count': '24'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SQL Interview Question - SALESFORCE - RANK',
#   'Published_date': '2024-08-28T13:39:14Z',
#   'Views': '6585',
#   'Like_count': '378',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SQL Interview Question | Percent of Total Sales | SUBQUERY',
#   'Published_date': '2024-07-25T09:04:31Z',
#   'Views': '13814',
#   'Like_count': '711',
#   'Comment_Count': '17'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'ZILLOW SQL Interview Question | SUBQUERY + HAVING #sql #dataanalysis',
#   'Published_date': '2024-07-06T13:19:22Z',
#   'Views': '10780',
#   'Like_count': '627',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'End-to-End Data Analysis Project 2024 | SQL & Power BI | Beginner Friendly',
#   'Published_date': '2024-05-05T14:37:15Z',
#   'Views': '219011',
#   'Like_count': '7207',
#   'Comment_Count': '241'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Amazon SQL Interview | Percent Change | FORMAT & LAG Functions',
#   'Published_date': '2024-04-13T13:13:58Z',
#   'Views': '27618',
#   'Like_count': '1677',
#   'Comment_Count': '22'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'META | SQL Interview | Peak Period | CONCAT and Subquery',
#   'Published_date': '2024-04-05T09:04:26Z',
#   'Views': '7960',
#   'Like_count': '363',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analysis Case Study | Product Recommendation | Fortune 100 Company',
#   'Published_date': '2024-03-26T10:28:29Z',
#   'Views': '8278',
#   'Like_count': '302',
#   'Comment_Count': '26'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Amazon SQL Interview Questions | Top 2 Busiest Times | DATEPART',
#   'Published_date': '2024-03-17T10:49:31Z',
#   'Views': '13323',
#   'Like_count': '673',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Spotify SQL Interview Question for Data Analyst | CTE & RANK | Top 10 Artists',
#   'Published_date': '2024-03-15T06:15:39Z',
#   'Views': '11254',
#   'Like_count': '607',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Dynamically Highlight HIGH/LOW, MIN/MAX with DAX | Power BI',
#   'Published_date': '2024-03-13T10:06:19Z',
#   'Views': '2056',
#   'Like_count': '58',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Time Series Insights | Decomposition Function | Python',
#   'Published_date': '2024-03-10T05:46:46Z',
#   'Views': '3880',
#   'Like_count': '186',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Amazon SQL Interview Question | Shipments Per Month | CONCAT & DATE_PART',
#   'Published_date': '2024-03-07T10:42:22Z',
#   'Views': '46677',
#   'Like_count': '2113',
#   'Comment_Count': '38'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Deloitte SQL Interview | RANK DESC & RANK ASC | Population Density',
#   'Published_date': '2024-03-04T16:16:29Z',
#   'Views': '21026',
#   'Like_count': '1001',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Finding Outliers with Python is Easy',
#   'Published_date': '2024-03-01T15:55:43Z',
#   'Views': '11879',
#   'Like_count': '426',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'CASE: Categorizing Data Like a Pro in SQL',
#   'Published_date': '2024-02-28T16:24:59Z',
#   'Views': '9092',
#   'Like_count': '499',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python Web Scraping is Easy | Scrape Data with 2 Lines of Code!',
#   'Published_date': '2024-02-19T15:07:28Z',
#   'Views': '67041',
#   'Like_count': '3378',
#   'Comment_Count': '66'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Churn Rate | SQL Interview Question | Uber Data Analyst',
#   'Published_date': '2024-02-08T14:15:30Z',
#   'Views': '5625',
#   'Like_count': '215',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'New & Returning Users | SQL Interview Question #sql',
#   'Published_date': '2024-02-06T15:55:10Z',
#   'Views': '3108',
#   'Like_count': '134',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI & Machine Learning Dashboards | Full Course (2024)',
#   'Published_date': '2024-01-13T07:32:30Z',
#   'Views': '12775',
#   'Like_count': '419',
#   'Comment_Count': '31'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analysis End-to-End Project Looker Studio and Big Query Dashboard',
#   'Published_date': '2023-12-28T16:02:32Z',
#   'Views': '13264',
#   'Like_count': '480',
#   'Comment_Count': '41'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Weekend vs Weekday | SQL for Data Analsyst',
#   'Published_date': '2023-12-14T06:23:53Z',
#   'Views': '3570',
#   'Like_count': '260',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SURPRISE RESULTS: 1,400 Data Analyst Job Openings',
#   'Published_date': '2023-12-13T13:28:11Z',
#   'Views': '2383',
#   'Like_count': '105',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SQL Pivot Table | SQL For Data Analysts',
#   'Published_date': '2023-11-27T09:50:42Z',
#   'Views': '13843',
#   'Like_count': '617',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Clean Address Data with Pandas | Python for Data Analysts',
#   'Published_date': '2023-11-22T13:29:35Z',
#   'Views': '6432',
#   'Like_count': '446',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python Data Query | Python for Data Analyst',
#   'Published_date': '2023-11-18T01:40:49Z',
#   'Views': '6256',
#   'Like_count': '313',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Change Functions | Python for Data Analysts',
#   'Published_date': '2023-11-13T13:47:12Z',
#   'Views': '4275',
#   'Like_count': '308',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Excel to Python & Python to Excel',
#   'Published_date': '2023-11-10T05:55:15Z',
#   'Views': '21901',
#   'Like_count': '757',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Forecasting with Facebook Prophet Time Series Model',
#   'Published_date': '2023-11-07T13:43:26Z',
#   'Views': '11630',
#   'Like_count': '571',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Find the N-Largest and N-Smallest Values | Python for Data Analysts',
#   'Published_date': '2023-11-03T14:46:35Z',
#   'Views': '3294',
#   'Like_count': '243',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python for Data Analysts - Data Cleaning, Transformation, and Analysis',
#   'Published_date': '2023-10-24T07:43:33Z',
#   'Views': '7917',
#   'Like_count': '255',
#   'Comment_Count': '17'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Handling Missing Values | Python for Data Analysts',
#   'Published_date': '2023-10-16T10:10:51Z',
#   'Views': '11358',
#   'Like_count': '489',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Pattern Matching | Python STR Methods | Python for Data Analyst',
#   'Published_date': '2023-10-12T08:59:39Z',
#   'Views': '4580',
#   'Like_count': '286',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Step by Step Power BI Dashboard Build -- Part 2 of End-to-End Project',
#   'Published_date': '2023-10-10T16:03:00Z',
#   'Views': '3673',
#   'Like_count': '96',
#   'Comment_Count': '36'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python for Data Analysts | MERGE datasets | Inner, Right, Left, Outer Joins',
#   'Published_date': '2023-10-04T15:16:33Z',
#   'Views': '12968',
#   'Like_count': '728',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analysis SQL Interview | UNION | Compare Postive Rating Percenage',
#   'Published_date': '2023-09-29T16:27:12Z',
#   'Views': '11120',
#   'Like_count': '572',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analysis SQL Interview Questions | Running SUM | Who Hit the Sales Target First',
#   'Published_date': '2023-09-25T16:23:09Z',
#   'Views': '255827',
#   'Like_count': '9998',
#   'Comment_Count': '95'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analyst SQL Interview Questions | CONCAT function',
#   'Published_date': '2023-09-21T14:27:37Z',
#   'Views': '16766',
#   'Like_count': '992',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Find Outliers in SQL | Data Analyst SQL Interview Question',
#   'Published_date': '2023-09-15T08:47:10Z',
#   'Views': '9782',
#   'Like_count': '553',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Extract ZIP Codes | String Contains Substring | Data Analyst SQL Interview Questions',
#   'Published_date': '2023-09-09T13:03:10Z',
#   'Views': '32517',
#   'Like_count': '2238',
#   'Comment_Count': '36'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analyst SQL Interview Question  | PERCENTILE Function | Top 1% of Salaries',
#   'Published_date': '2023-09-08T07:09:41Z',
#   'Views': '17850',
#   'Like_count': '1117',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Create Column Sparklines in Excel for Quick Trend Insights! #excel #dataanalysis',
#   'Published_date': '2023-09-03T08:16:18Z',
#   'Views': '1466',
#   'Like_count': '45',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analyst SQL Interview Questions | RANK, DENSE RANK, ROW NUMBER | #sql',
#   'Published_date': '2023-08-31T14:48:04Z',
#   'Views': '28995',
#   'Like_count': '1400',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analyst SQL Interview Question | LAG Function | Previous Day Comparison #dataanalysis #sql',
#   'Published_date': '2023-08-28T14:34:26Z',
#   'Views': '9824',
#   'Like_count': '529',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analyst SQL Interview Question |Self-Joins Explained #dataanalysis #sql #sqlinterview',
#   'Published_date': '2023-08-25T09:46:44Z',
#   'Views': '67077',
#   'Like_count': '2578',
#   'Comment_Count': '20'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analyst SQL Interview Question | Window Functions | Moving Average #sqlinterview #dataanalysis',
#   'Published_date': '2023-08-20T05:44:23Z',
#   'Views': '63536',
#   'Like_count': '3270',
#   'Comment_Count': '31'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Tableau Beginner Tutorial | Full End to End Project (2024)',
#   'Published_date': '2023-08-16T13:09:31Z',
#   'Views': '4610',
#   'Like_count': '124',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analysis Portfolio Project # 3 | End-to-End SQL to Dashboard',
#   'Published_date': '2023-07-24T14:46:05Z',
#   'Views': '51542',
#   'Like_count': '1707',
#   'Comment_Count': '89'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'What Do Data Analysts REALLY Do?  - Data Analyst Myths Debunked',
#   'Published_date': '2023-07-16T11:00:05Z',
#   'Views': '2181',
#   'Like_count': '69',
#   'Comment_Count': '9'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Revenue Analysis: Geometric Mean, Growth Rate & Forecasting | Eps #4',
#   'Published_date': '2023-06-27T15:08:57Z',
#   'Views': '4975',
#   'Like_count': '200',
#   'Comment_Count': '21'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Easy AutoGPT with Python in Minutes!',
#   'Published_date': '2023-06-16T02:04:56Z',
#   'Views': '1169',
#   'Like_count': '25',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SQL Analysis Project: Identifying Outliers and Department Statistics',
#   'Published_date': '2023-06-02T13:15:10Z',
#   'Views': '4827',
#   'Like_count': '152',
#   'Comment_Count': '22'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'The Future of Data Analysis: Using A.I. Models in Data Analysis (LangChain)',
#   'Published_date': '2023-05-13T13:30:46Z',
#   'Views': '5000',
#   'Like_count': '114',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Why Most Data Analysis Projects Fail | Avoid These Common Pitfalls',
#   'Published_date': '2023-04-24T16:10:18Z',
#   'Views': '2842',
#   'Like_count': '95',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Maximizing Advertising ROI through Budget Optimization | Python Tutorial',
#   'Published_date': '2023-04-01T15:05:29Z',
#   'Views': '2503',
#   'Like_count': '82',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Analyze Data - A Step by Step Guide',
#   'Published_date': '2023-03-22T15:02:56Z',
#   'Views': '7471',
#   'Like_count': '214',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Marketing Campaign Analysis | Saturation, Distribution, and Probability',
#   'Published_date': '2023-02-20T00:27:08Z',
#   'Views': '4389',
#   'Like_count': '157',
#   'Comment_Count': '16'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Calculate Customer Lifetime Value | Python Tutorial',
#   'Published_date': '2023-01-24T02:53:51Z',
#   'Views': '6360',
#   'Like_count': '168',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Use Prophet Model for Easy Python Forecasting',
#   'Published_date': '2023-01-22T03:13:43Z',
#   'Views': '5019',
#   'Like_count': '78',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Do Data Analysts Need Communication Skills?',
#   'Published_date': '2023-01-10T15:07:18Z',
#   'Views': '1508',
#   'Like_count': '30',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Code a Model in Seconds! | ChatGPT & Python',
#   'Published_date': '2023-01-05T13:14:42Z',
#   'Views': '2306',
#   'Like_count': '61',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Tricky SQL Screening Question | Applicants Failing to Get the Query Correct',
#   'Published_date': '2022-12-29T13:49:35Z',
#   'Views': '2019',
#   'Like_count': '71',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python Project | Visualization | Analysis of Bike Sharing Shop',
#   'Published_date': '2022-12-19T23:18:58Z',
#   'Views': '2887',
#   'Like_count': '112',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Create Powerful Customer Segments for Marketing | Data Analysis for Beginners #4',
#   'Published_date': '2022-12-11T07:32:28Z',
#   'Views': '16751',
#   'Like_count': '420',
#   'Comment_Count': '51'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Amazing Voice To Text With Python In Minutes || How To Convert Voice To Text In 2022',
#   'Published_date': '2022-10-30T16:17:11Z',
#   'Views': '3534',
#   'Like_count': '55',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Forecasting in Excel | Seasonality & Confidence Intervals',
#   'Published_date': '2022-10-29T01:05:16Z',
#   'Views': '5555',
#   'Like_count': '60',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How To Avoid Python Errors In Power BI || Python Power BI Tutorial For Beginners',
#   'Published_date': '2022-10-24T07:54:13Z',
#   'Views': '4677',
#   'Like_count': '60',
#   'Comment_Count': '17'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Free Data Analysis Websites For Beginners',
#   'Published_date': '2022-10-23T06:37:32Z',
#   'Views': '3763',
#   'Like_count': '106',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python Visualization Project | Superhero Powers 💪',
#   'Published_date': '2022-10-14T23:00:04Z',
#   'Views': '993',
#   'Like_count': '24',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'VLOOKUP | The Easy Way 😎',
#   'Published_date': '2022-10-13T12:01:05Z',
#   'Views': '2536',
#   'Like_count': '23',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Absent Data',
#   'Title': '9 SQL "Must Know" Interview Questions & Answers.',
#   'Published_date': '2022-10-09T04:26:06Z',
#   'Views': '1948',
#   'Like_count': '67',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Make TREE MAPs in Python.',
#   'Published_date': '2022-10-03T08:32:10Z',
#   'Views': '1365',
#   'Like_count': '16',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Install MYSQL | CREATE a Data Base | UPLOAD Data',
#   'Published_date': '2022-09-23T08:05:41Z',
#   'Views': '1336',
#   'Like_count': '33',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Pandas Plotting Tips You Should Know (2022)🔥 | Python Visualization',
#   'Published_date': '2022-09-16T14:18:14Z',
#   'Views': '2141',
#   'Like_count': '94',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'What is a Graphical Database | Python Project (2022)',
#   'Published_date': '2022-09-08T08:39:35Z',
#   'Views': '1055',
#   'Like_count': '29',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Develop Insights and Ace Data Analysis Case Studies',
#   'Published_date': '2022-09-05T12:14:14Z',
#   'Views': '17213',
#   'Like_count': '565',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Visualize Data in Python Using Seaborn | Seaborn Tutorial.',
#   'Published_date': '2022-08-27T23:17:40Z',
#   'Views': '14866',
#   'Like_count': '420',
#   'Comment_Count': '25'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python Project - Optimize Marketing Campaigns | Regression and Correlation Analysis',
#   'Published_date': '2022-08-21T09:28:10Z',
#   'Views': '36153',
#   'Like_count': '858',
#   'Comment_Count': '36'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python Project | Web SCRAPE NEWS Articles | Translate | Sentiment',
#   'Published_date': '2022-08-13T03:09:27Z',
#   'Views': '6353',
#   'Like_count': '121',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Correlation VS Causation | Insurance Rates | Data Analysis for Beginners Episode #3',
#   'Published_date': '2022-08-03T01:00:03Z',
#   'Views': '3892',
#   'Like_count': '112',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analysis for Beginners | HR Analytics | Episode #2',
#   'Published_date': '2022-07-11T07:40:51Z',
#   'Views': '7560',
#   'Like_count': '198',
#   'Comment_Count': '31'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analysis for Beginners | Hospital Wait Times | Episode #1',
#   'Published_date': '2022-06-26T16:51:40Z',
#   'Views': '17281',
#   'Like_count': '480',
#   'Comment_Count': '53'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Find Outliers with Python- 4 Simple Ways',
#   'Published_date': '2022-06-18T07:41:44Z',
#   'Views': '9661',
#   'Like_count': '226',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SQL Tutorial - Compare Current Row and Previous Row',
#   'Published_date': '2022-06-10T12:52:34Z',
#   'Views': '12872',
#   'Like_count': '167',
#   'Comment_Count': '20'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Simple Web Scraping with Pandas -- Scrape, Clean, & Visualize.',
#   'Published_date': '2022-06-04T09:52:36Z',
#   'Views': '4458',
#   'Like_count': '97',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'Absent Data',
#   'Title': '7 + 1 Pandas GROUP BY Tips -- Great Tips & Tricks (Python Tutorial)',
#   'Published_date': '2022-06-02T08:17:06Z',
#   'Views': '1453',
#   'Like_count': '59',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Using Probability and the Normal Distribution Python [ Better Audio ]',
#   'Published_date': '2022-05-31T03:10:48Z',
#   'Views': '1478',
#   'Like_count': '50',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Find Outliers in SQL',
#   'Published_date': '2022-04-30T15:31:04Z',
#   'Views': '11972',
#   'Like_count': '299',
#   'Comment_Count': '24'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SQL Interview Questions - Nth Highest Salary by Department',
#   'Published_date': '2022-04-23T08:57:54Z',
#   'Views': '2652',
#   'Like_count': '79',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Decision Tree in Power BI',
#   'Published_date': '2022-04-20T08:23:40Z',
#   'Views': '4764',
#   'Like_count': '55',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analyst Assignment -  Real "Take Home"  Interview Task | Power Query',
#   'Published_date': '2022-04-15T14:58:43Z',
#   'Views': '15159',
#   'Like_count': '260',
#   'Comment_Count': '25'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analyst CV Review -- What Makes A Good Resume',
#   'Published_date': '2022-04-12T08:22:20Z',
#   'Views': '5187',
#   'Like_count': '137',
#   'Comment_Count': '14'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Google Trends in Python and Power BI',
#   'Published_date': '2022-04-02T16:59:25Z',
#   'Views': '5882',
#   'Like_count': '133',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Google Data Studio Complete Tutorial for Beginners 🔥',
#   'Published_date': '2022-03-26T23:28:28Z',
#   'Views': '47315',
#   'Like_count': '688',
#   'Comment_Count': '46'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Fill All Blank Cells in Seconds',
#   'Published_date': '2022-03-17T16:07:36Z',
#   'Views': '6449',
#   'Like_count': '45',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Cohort Analysis with Python from Scratch | Easy Code',
#   'Published_date': '2022-03-12T13:00:29Z',
#   'Views': '13508',
#   'Like_count': '392',
#   'Comment_Count': '33'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Choose a Good KPI | Data Analyst',
#   'Published_date': '2022-02-02T16:05:35Z',
#   'Views': '2391',
#   'Like_count': '62',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Advice on Switching Careers to Data Analytics',
#   'Published_date': '2022-01-29T14:31:06Z',
#   'Views': '1483',
#   'Like_count': '64',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Dual Learn | SQL & Python Part #2 |  Intermediate',
#   'Published_date': '2022-01-05T08:55:00Z',
#   'Views': '1253',
#   'Like_count': '49',
#   'Comment_Count': '9'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Dual Learn | SQL & Python Part #1 | Fundamental Actions',
#   'Published_date': '2021-12-30T02:30:15Z',
#   'Views': '4898',
#   'Like_count': '161',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python Statistics - Normal Distribution and Probability Functions',
#   'Published_date': '2021-12-27T12:29:03Z',
#   'Views': '5018',
#   'Like_count': '101',
#   'Comment_Count': '22'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Top 10 Pandas Functions for Data Analysis (READ CSV, MERGE, GROUPBY, FILLNA & MORE!)',
#   'Published_date': '2021-12-04T17:24:23Z',
#   'Views': '2935',
#   'Like_count': '99',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Get Python Sample Datasets in Power BI',
#   'Published_date': '2021-11-04T02:27:29Z',
#   'Views': '2359',
#   'Like_count': '46',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analyst Portfolio Project #2: Python Customer Segmentation & Clustering',
#   'Published_date': '2021-08-31T01:55:07Z',
#   'Views': '142211',
#   'Like_count': '3716',
#   'Comment_Count': '121'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analyst Portfolio Project #1 | Build a Database | Develop SQL | Create a Dashboard',
#   'Published_date': '2021-05-23T21:38:55Z',
#   'Views': '565381',
#   'Like_count': '14787',
#   'Comment_Count': '432'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Univariate Analysis with Excel: Distributions, Sampling, Descriptive Statistics, ECDF',
#   'Published_date': '2021-05-21T18:17:18Z',
#   'Views': '4757',
#   'Like_count': '49',
#   'Comment_Count': '9'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Multiple Criteria Decision Analysis Part II : Weighted Sum Model',
#   'Published_date': '2021-05-03T23:42:09Z',
#   'Views': '5695',
#   'Like_count': '64',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Multiple Criteria Decision Analysis |  Data Analysis Quick Wins #1',
#   'Published_date': '2021-05-02T23:00:15Z',
#   'Views': '8003',
#   'Like_count': '141',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Become a Data Analyst--Advice from a Senior Data Analyst',
#   'Published_date': '2021-04-12T01:46:26Z',
#   'Views': '8097',
#   'Like_count': '319',
#   'Comment_Count': '27'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI and Python Machine Learning A to Z Part 7: Deploy Model and Visualize Results',
#   'Published_date': '2021-04-05T16:27:31Z',
#   'Views': '16179',
#   'Like_count': '202',
#   'Comment_Count': '26'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI and Python Machine Learning A to Z Part 6: Prepare and Create the Model',
#   'Published_date': '2021-04-05T01:19:42Z',
#   'Views': '6697',
#   'Like_count': '55',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI and Python Machine Learning A to Z Part 5: Visual Analysis with Power BI and Python Visuals',
#   'Published_date': '2021-04-05T01:19:37Z',
#   'Views': '7861',
#   'Like_count': '74',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI and Python Machine Learning A to Z: Part 4: Power BI Script Editor and Editors',
#   'Published_date': '2021-04-05T01:19:30Z',
#   'Views': '9357',
#   'Like_count': '73',
#   'Comment_Count': '17'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI and Python Machine Learning A to Z: Part 3: Loading in Data into Python',
#   'Published_date': '2021-04-05T01:19:18Z',
#   'Views': '8880',
#   'Like_count': '52',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI and Python Machine Learning A to Z: Part 2: Create Environments and Install Packages',
#   'Published_date': '2021-04-05T01:19:07Z',
#   'Views': '10688',
#   'Like_count': '66',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI and Python Machine Learning A to Z Part 1: Installing Python',
#   'Published_date': '2021-04-05T01:18:51Z',
#   'Views': '16122',
#   'Like_count': '121',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Value Counts Analysis | Pandas Data Analysis Tutorial #4 | Percentage and Frequency',
#   'Published_date': '2021-03-31T03:47:45Z',
#   'Views': '2792',
#   'Like_count': '63',
#   'Comment_Count': '17'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Pandas Histogram Analysis | Pandas Data Analysis Tutorial #3 | Distributions, Relative Frequency',
#   'Published_date': '2021-03-26T22:06:38Z',
#   'Views': '2727',
#   'Like_count': '40',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Pandas Crosstab |  Pandas Data Analysis Tutorial #2 | Bivariate Analysis for Quick Insights',
#   'Published_date': '2021-03-23T10:45:00Z',
#   'Views': '1889',
#   'Like_count': '58',
#   'Comment_Count': '9'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Create Power BI Calendar Table with Python--Fast, Detailed, and Simple',
#   'Published_date': '2021-03-22T02:32:50Z',
#   'Views': '2595',
#   'Like_count': '29',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Group By Function | Pandas Data Analysis Tutorial #1 | Retail Example',
#   'Published_date': '2021-03-21T16:15:06Z',
#   'Views': '6631',
#   'Like_count': '140',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Create Cool Word Clouds with Python - Use Any Shape',
#   'Published_date': '2021-03-11T04:28:47Z',
#   'Views': '1801',
#   'Like_count': '41',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Word Frequency & Emoji Analysis of WallStreetBets',
#   'Published_date': '2021-03-09T11:55:37Z',
#   'Views': '3869',
#   'Like_count': '76',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'YoY and MoM Comparison Tutorial in Python',
#   'Published_date': '2021-02-25T03:09:39Z',
#   'Views': '3882',
#   'Like_count': '58',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python Interview Question #3 | Facebook Data Science | Interview Question Answered',
#   'Published_date': '2021-02-21T20:07:44Z',
#   'Views': '679',
#   'Like_count': '19',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python Interview Question #2 | Amazon Time Series | Data Science Interview Question',
#   'Published_date': '2021-02-13T22:48:02Z',
#   'Views': '1583',
#   'Like_count': '25',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Real World Python Interview Question #1 | Facebook Data Science Interview Question Answered',
#   'Published_date': '2021-02-13T02:03:20Z',
#   'Views': '1811',
#   'Like_count': '31',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Cumulative Distribution Plot in Power BI',
#   'Published_date': '2021-02-06T23:02:11Z',
#   'Views': '13115',
#   'Like_count': '96',
#   'Comment_Count': '25'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python Composite Score: Simplify Complex Metrics',
#   'Published_date': '2021-01-17T12:58:33Z',
#   'Views': '1200',
#   'Like_count': '24',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Frequently Bought Together Items with Python and Power BI',
#   'Published_date': '2021-01-12T12:52:29Z',
#   'Views': '5983',
#   'Like_count': '116',
#   'Comment_Count': '22'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'ECDF: An Alternative Plot to Histograms',
#   'Published_date': '2021-01-09T01:34:13Z',
#   'Views': '10773',
#   'Like_count': '155',
#   'Comment_Count': '20'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Build Matrix Visuals with Seaborn Facet Grid',
#   'Published_date': '2020-12-25T00:10:16Z',
#   'Views': '674',
#   'Like_count': '18',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Statistics and Correlation Tables in Power BI with Python',
#   'Published_date': '2020-11-22T17:59:57Z',
#   'Views': '12420',
#   'Like_count': '195',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Churn Classification Model Comparison with Power BI and Python',
#   'Published_date': '2020-11-11T01:15:59Z',
#   'Views': '7840',
#   'Like_count': '197',
#   'Comment_Count': '20'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Price Prediction with Python and Power BI',
#   'Published_date': '2020-10-24T19:34:13Z',
#   'Views': '31046',
#   'Like_count': '697',
#   'Comment_Count': '44'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'VLOOKUP in Python  - Quick and Easy Pandas Script',
#   'Published_date': '2020-10-22T02:55:14Z',
#   'Views': '24574',
#   'Like_count': '261',
#   'Comment_Count': '14'},
#  {'Channel_Name': 'Absent Data',
#   'Title': '5 Dashboard Design Tips - Important Concepts for Data Visualization',
#   'Published_date': '2020-10-16T17:31:09Z',
#   'Views': '6079',
#   'Like_count': '44',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Data Modelling Tutorial 1 - Star Schema?',
#   'Published_date': '2020-10-05T00:34:01Z',
#   'Views': '13922',
#   'Like_count': '181',
#   'Comment_Count': '24'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Create Bins and Buckets with Pandas',
#   'Published_date': '2020-09-26T02:52:16Z',
#   'Views': '11414',
#   'Like_count': '216',
#   'Comment_Count': '17'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Data Analysis Workflow--How to Answer Requests(Good and Bad)',
#   'Published_date': '2020-09-20T18:15:20Z',
#   'Views': '2586',
#   'Like_count': '71',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Matplotlib Tutorial - Subplots and InnerPlots',
#   'Published_date': '2020-09-12T22:27:01Z',
#   'Views': '10183',
#   'Like_count': '219',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Calculate Break Even Point with Excel Data Tables',
#   'Published_date': '2020-09-10T04:12:31Z',
#   'Views': '4228',
#   'Like_count': '45',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Real World Power BI Interview Questions & Answers',
#   'Published_date': '2020-09-06T19:23:37Z',
#   'Views': '33754',
#   'Like_count': '615',
#   'Comment_Count': '22'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Real World Data Science Analysis with Pandas: Read CSV, GROUP BY, SUBPLOTS',
#   'Published_date': '2020-09-01T02:41:22Z',
#   'Views': '4156',
#   'Like_count': '102',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Machine Learning Anomaly Detection with Python and Power BI',
#   'Published_date': '2020-08-25T12:33:52Z',
#   'Views': '10524',
#   'Like_count': '182',
#   'Comment_Count': '17'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Learn Power BI in One Video --2 hour Beginner Course',
#   'Published_date': '2020-08-23T16:23:11Z',
#   'Views': '4848',
#   'Like_count': '99',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Dynamic Outlier Detection and Visualization with DAX in Power BI',
#   'Published_date': '2020-08-21T01:01:03Z',
#   'Views': '13908',
#   'Like_count': '213',
#   'Comment_Count': '19'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'SUMX - Simplified. Finally Understand with EXCEL & POWER BI',
#   'Published_date': '2020-08-11T00:27:48Z',
#   'Views': '3468',
#   'Like_count': '35',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Awesome Forecasting Functions in Excel',
#   'Published_date': '2020-08-07T02:27:29Z',
#   'Views': '6744',
#   'Like_count': '90',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Create Dynamic Personal Greetings in DAX',
#   'Published_date': '2020-08-03T03:18:31Z',
#   'Views': '1050',
#   'Like_count': '26',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'DAX: SWITCH VS IF Functions -Which is Better?',
#   'Published_date': '2020-07-28T03:34:55Z',
#   'Views': '3727',
#   'Like_count': '35',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'DAX Table Functions: ALL, FILTER, & VALUES',
#   'Published_date': '2020-07-26T01:17:28Z',
#   'Views': '16911',
#   'Like_count': '238',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Calculate Totals for  MTD, QTD and YTD in DAX',
#   'Published_date': '2020-07-19T17:24:01Z',
#   'Views': '7943',
#   'Like_count': '55',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Use Facebook Prophet Model to Forecast',
#   'Published_date': '2020-07-18T17:31:24Z',
#   'Views': '3916',
#   'Like_count': '48',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Use Seaborn Plots for Data Analysis',
#   'Published_date': '2020-07-13T02:18:44Z',
#   'Views': '513',
#   'Like_count': '13',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Change The Font  Across All Visuals in a Power BI',
#   'Published_date': '2020-07-10T01:01:54Z',
#   'Views': '9435',
#   'Like_count': '25',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Get Round Corners on Visuals in Power BI',
#   'Published_date': '2020-07-03T20:16:46Z',
#   'Views': '31954',
#   'Like_count': '94',
#   'Comment_Count': '23'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Create a Dynamic Narrative with DAX',
#   'Published_date': '2020-06-13T14:49:10Z',
#   'Views': '1409',
#   'Like_count': '24',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Make a Machine Learning Pipeline',
#   'Published_date': '2020-05-31T19:19:10Z',
#   'Views': '2331',
#   'Like_count': '54',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Multiple Scenario Analysis in Power BI',
#   'Published_date': '2020-05-27T00:20:53Z',
#   'Views': '6623',
#   'Like_count': '67',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Visualize Time Series Data with Pandas',
#   'Published_date': '2020-05-22T19:30:43Z',
#   'Views': '1972',
#   'Like_count': '29',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Dynamic Rolling Average with DAX in Power BI',
#   'Published_date': '2020-05-03T19:47:30Z',
#   'Views': '15921',
#   'Like_count': '168',
#   'Comment_Count': '38'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Exponential Smoothing Forecast Python and Power BI',
#   'Published_date': '2020-04-17T04:18:07Z',
#   'Views': '13137',
#   'Like_count': '201',
#   'Comment_Count': '31'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Game of Thrones Episode Heatmap with Python',
#   'Published_date': '2020-04-10T00:30:42Z',
#   'Views': '674',
#   'Like_count': '11',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Create a Moving Average with Pandas in Python',
#   'Published_date': '2020-03-29T16:40:39Z',
#   'Views': '23935',
#   'Like_count': '314',
#   'Comment_Count': '28'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course For Beginners (Part 16 Updating Data)',
#   'Published_date': '2020-03-27T17:14:22Z',
#   'Views': '322',
#   'Like_count': '8',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 15 Drillthrough)',
#   'Published_date': '2020-03-26T02:03:27Z',
#   'Views': '338',
#   'Like_count': '8',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners ( Part 14 Backgrounds, Shapes and Wallpaper )',
#   'Published_date': '2020-03-25T20:35:12Z',
#   'Views': '1143',
#   'Like_count': '10',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 13 Customizing Visuals and Dashboard Structure)',
#   'Published_date': '2020-03-25T15:48:33Z',
#   'Views': '276',
#   'Like_count': '4',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 11 Conditional Formatting )',
#   'Published_date': '2020-03-24T20:37:11Z',
#   'Views': '250',
#   'Like_count': '4',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 12 Segments and Filters)',
#   'Published_date': '2020-03-22T17:37:58Z',
#   'Views': '369',
#   'Like_count': '5',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Rename Columns in Python Pandas DataFrame',
#   'Published_date': '2020-03-21T23:15:49Z',
#   'Views': '4862',
#   'Like_count': '57',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Global Movie Box Office Gross by Genre (Animated Bar Chart Race)',
#   'Published_date': '2020-01-13T02:30:58Z',
#   'Views': '1791',
#   'Like_count': '11',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Sales Prediction Model with Python and Power BI',
#   'Published_date': '2019-11-03T23:15:38Z',
#   'Views': '63660',
#   'Like_count': '1062',
#   'Comment_Count': '71'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners ( Part 10 Styling Maps)',
#   'Published_date': '2019-10-05T19:32:33Z',
#   'Views': '325',
#   'Like_count': '6',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 9 Calculated Measures and Profit)',
#   'Published_date': '2019-09-26T10:02:56Z',
#   'Views': '363',
#   'Like_count': '5',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners ( Part 7 Calculated Columns)',
#   'Published_date': '2019-09-21T03:06:03Z',
#   'Views': '383',
#   'Like_count': '6',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 8 Replacing Values)',
#   'Published_date': '2019-09-19T00:23:19Z',
#   'Views': '294',
#   'Like_count': '5',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 6 Styling Charts)',
#   'Published_date': '2019-09-15T23:41:29Z',
#   'Views': '341',
#   'Like_count': '8',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 5 Slicers and Filters)',
#   'Published_date': '2019-09-15T19:13:08Z',
#   'Views': '520',
#   'Like_count': '13',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 4 Custom Hierarchies)',
#   'Published_date': '2019-09-15T18:57:14Z',
#   'Views': '621',
#   'Like_count': '9',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 3 Hierarchies and Drilling)',
#   'Published_date': '2019-09-15T18:46:35Z',
#   'Views': '806',
#   'Like_count': '8',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 2 - Your First Graphs and Homework)',
#   'Published_date': '2019-09-15T18:26:27Z',
#   'Views': '1157',
#   'Like_count': '20',
#   'Comment_Count': '3'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Power BI Course for Beginners (Part 1-Getting to Know Power BI)',
#   'Published_date': '2019-09-15T18:05:14Z',
#   'Views': '3178',
#   'Like_count': '45',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Add Data Bars and Star Ratings to Excel Tables',
#   'Published_date': '2019-09-02T15:43:41Z',
#   'Views': '5474',
#   'Like_count': '19',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Forecasting in Power BI',
#   'Published_date': '2019-08-28T02:37:57Z',
#   'Views': '5955',
#   'Like_count': '44',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Python for Excel Users Part 1',
#   'Published_date': '2019-08-25T23:22:24Z',
#   'Views': '2350',
#   'Like_count': '35',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Highlight Positve and Negative Values in Power BI',
#   'Published_date': '2019-08-25T02:21:03Z',
#   'Views': '23140',
#   'Like_count': '88',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Year over Year and Month over Month Calculations in Power BI',
#   'Published_date': '2019-08-12T02:01:48Z',
#   'Views': '76462',
#   'Like_count': '443',
#   'Comment_Count': '57'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Use CALCULATE in Power BI',
#   'Published_date': '2019-08-10T13:34:28Z',
#   'Views': '11189',
#   'Like_count': '86',
#   'Comment_Count': '16'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Conditional Columns in Power BI',
#   'Published_date': '2019-08-01T03:38:43Z',
#   'Views': '2141',
#   'Like_count': '19',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Split and Merge Columns in Power BI',
#   'Published_date': '2019-07-30T01:05:03Z',
#   'Views': '2359',
#   'Like_count': '17',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Append and Merge Tables in Power BI',
#   'Published_date': '2019-07-28T20:10:42Z',
#   'Views': '87698',
#   'Like_count': '501',
#   'Comment_Count': '33'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Sentiment Analysis in Power BI',
#   'Published_date': '2019-07-16T02:36:34Z',
#   'Views': '15676',
#   'Like_count': '216',
#   'Comment_Count': '30'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Machine Learning in Power BI',
#   'Published_date': '2019-07-01T00:51:51Z',
#   'Views': '55240',
#   'Like_count': '920',
#   'Comment_Count': '39'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Pivot Tables in Python using Pandas',
#   'Published_date': '2019-05-25T20:26:42Z',
#   'Views': '15286',
#   'Like_count': '225',
#   'Comment_Count': '16'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Create an Excel Step Chart',
#   'Published_date': '2019-05-23T03:16:46Z',
#   'Views': '527',
#   'Like_count': '4',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Add Data Entry Form in Excel 2016',
#   'Published_date': '2019-05-18T11:08:29Z',
#   'Views': '1648',
#   'Like_count': '10',
#   'Comment_Count': '1'},
#  {'Channel_Name': 'Absent Data',
#   'Title': '3 Ways to Find Duplicate Values in Excel 2016',
#   'Published_date': '2019-05-05T18:32:44Z',
#   'Views': '69339',
#   'Like_count': '323',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Create a Heatmap using Seaborn',
#   'Published_date': '2018-11-08T11:45:28Z',
#   'Views': '13082',
#   'Like_count': '175',
#   'Comment_Count': '19'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Load Excel Sheet into Power BI',
#   'Published_date': '2018-11-01T10:50:31Z',
#   'Views': '192',
#   'Like_count': '1',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Random Number Generator in Excel',
#   'Published_date': '2018-10-21T18:41:38Z',
#   'Views': '27049',
#   'Like_count': '79',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Calculate Time Between Two Dates in Excel',
#   'Published_date': '2018-09-23T13:36:49Z',
#   'Views': '46197',
#   'Like_count': '98',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Create a Power BI Dashboard in 10 Minutes!',
#   'Published_date': '2018-08-12T19:57:47Z',
#   'Views': '30253',
#   'Like_count': '155',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Change Horizontal Axis Values in Excel 2016',
#   'Published_date': '2018-07-16T01:36:34Z',
#   'Views': '664409',
#   'Like_count': '1130',
#   'Comment_Count': '83'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Delete Blank Rows in Excel',
#   'Published_date': '2018-03-20T03:16:56Z',
#   'Views': '23957',
#   'Like_count': '35',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'How to Find Outliers with Excel',
#   'Published_date': '2017-12-04T04:58:14Z',
#   'Views': '325400',
#   'Like_count': '2586',
#   'Comment_Count': '134'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Install Facebook Pixel  with Google Tag Manager in 5 minutes.',
#   'Published_date': '2016-10-24T14:14:20Z',
#   'Views': '1702',
#   'Like_count': '4',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Track Outbound Links with Google Tag Manager',
#   'Published_date': '2016-08-21T11:49:59Z',
#   'Views': '13398',
#   'Like_count': '42',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Adjusted Bounce Rate with Google Tag Manager',
#   'Published_date': '2016-07-16T08:04:50Z',
#   'Views': '1829',
#   'Like_count': '4',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'The Best Time of Day to Publish a Blog Post',
#   'Published_date': '2016-04-24T14:42:10Z',
#   'Views': '266',
#   'Like_count': '4',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Absent Data',
#   'Title': 'Track Button Clicks in Google Tag Manager',
#   'Published_date': '2016-04-14T15:32:57Z',
#   'Views': '9897',
#   'Like_count': '72',
# ...
#   'Published_date': '2024-05-10T13:00:03Z',
#   'Views': '2650',
#   'Like_count': '59',
#   'Comment_Count': '4'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Chat with your Documents Privately with Local AI using Ollama and AnythingLLM',
#   'Published_date': '2024-05-05T14:47:02Z',
#   'Views': '5543',
#   'Like_count': '117',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Private Chat GPT-clone with LLama3, Ollama and Msty - Free and Easier than Open WebUI',
#   'Published_date': '2024-05-02T12:00:33Z',
#   'Views': '3407',
#   'Like_count': '99',
#   'Comment_Count': '17'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': "Can my Laptop run Meta's Llama 3, WizardLM 2, DBRX, Mixtral 8x22b, and Command R+?",
#   'Published_date': '2024-04-20T19:15:00Z',
#   'Views': '2626',
#   'Like_count': '51',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Sentiment Analysis of Financial News in Python - 3 Ways using Dictionary, FinBert and LLMs',
#   'Published_date': '2024-04-12T13:00:18Z',
#   'Views': '3524',
#   'Like_count': '88',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Scrape Financial Data from SEC Edgar with Python',
#   'Published_date': '2024-04-06T15:00:38Z',
#   'Views': '8432',
#   'Like_count': '288',
#   'Comment_Count': '28'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Summarize PDFs with a Local AI (Private GPT) in Python',
#   'Published_date': '2024-03-30T14:24:22Z',
#   'Views': '6814',
#   'Like_count': '207',
#   'Comment_Count': '19'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Faster NumPy on Mac GPU with MLX',
#   'Published_date': '2024-03-22T13:00:23Z',
#   'Views': '2257',
#   'Like_count': '69',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Free and Private GitHub Copilot Clone for VS Code Using Ollama and Continue',
#   'Published_date': '2024-03-15T13:00:13Z',
#   'Views': '13514',
#   'Like_count': '290',
#   'Comment_Count': '23'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Private Chat GPT, Free and Uncensored, with Ollama + Open WebUI',
#   'Published_date': '2024-03-11T20:29:22Z',
#   'Views': '10174',
#   'Like_count': '227',
#   'Comment_Count': '9'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Run your Own Private Chat GPT, Free and Uncensored, with Ollama + Open WebUI',
#   'Published_date': '2024-03-08T14:00:26Z',
#   'Views': '26184',
#   'Like_count': '765',
#   'Comment_Count': '85'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Pandas read_csv() 5x faster with pyarrow!',
#   'Published_date': '2024-03-08T03:26:47Z',
#   'Views': '1249',
#   'Like_count': '49',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': '5 tips for reading large CSV files faster',
#   'Published_date': '2024-03-01T14:00:21Z',
#   'Views': '631',
#   'Like_count': '24',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Setup VS Code for Scientific Writing with LaTeX',
#   'Published_date': '2024-02-23T14:00:46Z',
#   'Views': '52544',
#   'Like_count': '814',
#   'Comment_Count': '36'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Use Github For Academic Research Projects: Track Changes Like a Pro',
#   'Published_date': '2024-02-16T13:04:10Z',
#   'Views': '1424',
#   'Like_count': '30',
#   'Comment_Count': '2'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Time Series Regressions in Python with Statsmodels',
#   'Published_date': '2024-02-10T13:37:35Z',
#   'Views': '442',
#   'Like_count': '8',
#   'Comment_Count': '0'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'Panel Regressions in Python with linearmodels',
#   'Published_date': '2024-01-27T02:10:03Z',
#   'Views': '3044',
#   'Like_count': '48',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Title': 'How to Install Python 3.12 on mac OS (2024) + VS Code and Poetry with Homebrew',
#   'Published_date': '2024-01-03T19:19:10Z',
#   'Views': '2010',
#   'Like_count': '42',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Updated AI Roadmap For 2025',
#   'Published_date': '2025-05-24T14:44:44Z',
#   'Views': '28997',
#   'Like_count': '1226',
#   'Comment_Count': '97'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Vibe Coding Fundamentals In 33 minutes',
#   'Published_date': '2025-05-19T13:01:17Z',
#   'Views': '125256',
#   'Like_count': '5362',
#   'Comment_Count': '345'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Google Firebase Studio In 23 Minutes',
#   'Published_date': '2025-05-13T12:00:48Z',
#   'Views': '168430',
#   'Like_count': '5840',
#   'Comment_Count': '230'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Building AI Agents In 44 Minutes',
#   'Published_date': '2025-04-21T15:27:59Z',
#   'Views': '173952',
#   'Like_count': '6544',
#   'Comment_Count': '245'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Building AI Agents: A Step-by-Step Guide',
#   'Published_date': '2025-04-21T01:11:30Z',
#   'Views': '46689',
#   'Like_count': '2008',
#   'Comment_Count': '64'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Vibe Coding 101',
#   'Published_date': '2025-04-13T01:28:31Z',
#   'Views': '27406',
#   'Like_count': '1116',
#   'Comment_Count': '23'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 How To Choose The Best LLM',
#   'Published_date': '2025-03-30T01:20:54Z',
#   'Views': '12218',
#   'Like_count': '479',
#   'Comment_Count': '21'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Claude In 29 Minutes',
#   'Published_date': '2025-03-18T13:01:30Z',
#   'Views': '85371',
#   'Like_count': '3072',
#   'Comment_Count': '125'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Everything about Claude',
#   'Published_date': '2025-03-16T01:20:06Z',
#   'Views': '16051',
#   'Like_count': '713',
#   'Comment_Count': '40'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Google AI Studio In 26 Minutes',
#   'Published_date': '2025-03-09T17:04:00Z',
#   'Views': '191960',
#   'Like_count': '6795',
#   'Comment_Count': '416'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Building AI Agents',
#   'Published_date': '2025-03-02T01:43:58Z',
#   'Views': '55819',
#   'Like_count': '2114',
#   'Comment_Count': '72'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Science Based Learning Strategies In 16 Minutes',
#   'Published_date': '2025-02-24T17:02:24Z',
#   'Views': '45578',
#   'Like_count': '2885',
#   'Comment_Count': '141'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'AI Agents Fundamentals In 21 Minutes',
#   'Published_date': '2025-02-16T14:33:21Z',
#   'Views': '1077128',
#   'Like_count': '39870',
#   'Comment_Count': '1086'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 AI Agents Crash Course',
#   'Published_date': '2025-02-16T01:08:33Z',
#   'Views': '63840',
#   'Like_count': '2643',
#   'Comment_Count': '103'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Budgeting In 26 Minutes',
#   'Published_date': '2025-01-31T16:06:00Z',
#   'Views': '43151',
#   'Like_count': '1959',
#   'Comment_Count': '118'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'The One Skill That Would Solve 90% Of Your Problems',
#   'Published_date': '2025-01-16T17:10:17Z',
#   'Views': '41593',
#   'Like_count': '2120',
#   'Comment_Count': '92'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'My SMART Goals For 2025',
#   'Published_date': '2025-01-10T16:00:50Z',
#   'Views': '18948',
#   'Like_count': '949',
#   'Comment_Count': '85'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: AI Fundamentals for 2025',
#   'Published_date': '2025-01-10T14:24:24Z',
#   'Views': '17457',
#   'Like_count': '526',
#   'Comment_Count': '34'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Financial Literacy In 63 Minutes',
#   'Published_date': '2025-01-01T19:00:26Z',
#   'Views': '1270481',
#   'Like_count': '88169',
#   'Comment_Count': '1547'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': "Google's 9 Hour AI Prompt Engineering Course In 20 Minutes",
#   'Published_date': '2024-12-09T13:30:33Z',
#   'Views': '740838',
#   'Like_count': '25256',
#   'Comment_Count': '589'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Learn To Learn In 25 Minutes',
#   'Published_date': '2024-11-27T14:59:38Z',
#   'Views': '435461',
#   'Like_count': '28603',
#   'Comment_Count': '427'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'How To Train Yourself To Become A Genius',
#   'Published_date': '2024-11-12T19:42:10Z',
#   'Views': '400249',
#   'Like_count': '22464',
#   'Comment_Count': '589'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': "Google's 8 Hour AI Essentials Course In 15 Minutes",
#   'Published_date': '2024-10-28T19:08:48Z',
#   'Views': '444267',
#   'Like_count': '16496',
#   'Comment_Count': '551'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Andrew Ng’s 3 Week Intro AI Course in 25 Minutes| Deep Learning AI',
#   'Published_date': '2024-10-22T13:01:07Z',
#   'Views': '55602',
#   'Like_count': '2097',
#   'Comment_Count': '88'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'It’s Time To Take Your Dreams Seriously - The Alchemist by Paulo Coelho',
#   'Published_date': '2024-10-03T13:41:40Z',
#   'Views': '17940',
#   'Like_count': '955',
#   'Comment_Count': '108'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'How To Make The ULTIMATE Self Study Plan With ChatGPT (step by step prompting guide)',
#   'Published_date': '2024-09-22T16:42:11Z',
#   'Views': '63735',
#   'Like_count': '3500',
#   'Comment_Count': '94'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '10 Principles To Learn Anything',
#   'Published_date': '2024-09-08T14:00:31Z',
#   'Views': '88346',
#   'Like_count': '5767',
#   'Comment_Count': '209'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: How to use AI to 10x Learning Things Part 3!',
#   'Published_date': '2024-09-08T08:29:22Z',
#   'Views': '6704',
#   'Like_count': '362',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: How to use AI to 10x Learning Things Part 2!',
#   'Published_date': '2024-08-31T20:49:26Z',
#   'Views': '8088',
#   'Like_count': '495',
#   'Comment_Count': '7'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Screen Resumes With Me! (hiring for our team) 🐙',
#   'Published_date': '2024-08-28T18:58:37Z',
#   'Views': '10861',
#   'Like_count': '529',
#   'Comment_Count': '33'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: How to use AI to 10x Learning Things',
#   'Published_date': '2024-08-24T20:29:22Z',
#   'Views': '15174',
#   'Like_count': '708',
#   'Comment_Count': '30'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '5 Unique AI Projects (beginner to intermediate) | Python, LangChain, RAG, OpenAI, ChatGPT, ChatBot',
#   'Published_date': '2024-08-16T18:39:55Z',
#   'Views': '66577',
#   'Like_count': '2253',
#   'Comment_Count': '70'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'How To Start Freelancing (a step by step guide)',
#   'Published_date': '2024-08-12T14:11:38Z',
#   'Views': '78317',
#   'Like_count': '3112',
#   'Comment_Count': '112'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': "🐙 Lunch & Learn: Let's Try Out Meta Models (Llama 3.1 & SAM 2)",
#   'Published_date': '2024-08-04T08:34:28Z',
#   'Views': '5241',
#   'Like_count': '179',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Why You (probably) Should Not Get A Master’s Degree In 2024',
#   'Published_date': '2024-07-29T18:37:41Z',
#   'Views': '80932',
#   'Like_count': '2903',
#   'Comment_Count': '419'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': "🐙 Lunch & Learn: Let's Talk about GPT-4o Mini",
#   'Published_date': '2024-07-21T08:15:47Z',
#   'Views': '6973',
#   'Like_count': '241',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: The Hoarding of AI Chips',
#   'Published_date': '2024-07-14T08:02:57Z',
#   'Views': '4032',
#   'Like_count': '181',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: AI Skills for your Resume',
#   'Published_date': '2024-07-06T20:24:54Z',
#   'Views': '6967',
#   'Like_count': '439',
#   'Comment_Count': '8'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'How I Would Start My Career In 2024 (if I could redo over)',
#   'Published_date': '2024-07-01T06:09:32Z',
#   'Views': '47958',
#   'Like_count': '2261',
#   'Comment_Count': '165'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: Let’s talk about Claude 3.5',
#   'Published_date': '2024-06-29T20:12:05Z',
#   'Views': '5679',
#   'Like_count': '203',
#   'Comment_Count': '13'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: Ilya Sutskever & AI Safety',
#   'Published_date': '2024-06-23T08:19:09Z',
#   'Views': '5707',
#   'Like_count': '203',
#   'Comment_Count': '26'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Study With Me Using GPT-4o',
#   'Published_date': '2024-06-20T13:00:01Z',
#   'Views': '17815',
#   'Like_count': '743',
#   'Comment_Count': '63'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: How to Showcase your AI Projects + LO Q&A',
#   'Published_date': '2024-06-09T08:32:22Z',
#   'Views': '8275',
#   'Like_count': '264',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': "Why You Can't Find A Job",
#   'Published_date': '2024-05-31T21:01:07Z',
#   'Views': '249861',
#   'Like_count': '9393',
#   'Comment_Count': '1469'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Making My New Self Study Plan',
#   'Published_date': '2024-05-26T16:32:04Z',
#   'Views': '32825',
#   'Like_count': '1624',
#   'Comment_Count': '116'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': "🐙 Lunch & Learn: Let's Build An AI Assistant With GPT-4o (w/ Joe & Winston of @Posit)",
#   'Published_date': '2024-05-26T02:53:26Z',
#   'Views': '30105',
#   'Like_count': '918',
#   'Comment_Count': '27'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: ChatGPT-4o',
#   'Published_date': '2024-05-19T02:31:56Z',
#   'Views': '13124',
#   'Like_count': '424',
#   'Comment_Count': '31'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': "🐙 Lunch & Learn: Let's make some AI Music",
#   'Published_date': '2024-05-05T18:37:57Z',
#   'Views': '6543',
#   'Like_count': '276',
#   'Comment_Count': '11'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Big Tech AI Is A Lie',
#   'Published_date': '2024-05-01T03:49:56Z',
#   'Views': '285585',
#   'Like_count': '13735',
#   'Comment_Count': '2277'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: Let’s Talk about LLAMA3 and AI Girlfriends 🥹',
#   'Published_date': '2024-04-28T14:50:18Z',
#   'Views': '6607',
#   'Like_count': '249',
#   'Comment_Count': '21'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: Google Be Hopping On The AI Agents Train (finally)!',
#   'Published_date': '2024-04-13T21:24:39Z',
#   'Views': '8143',
#   'Like_count': '286',
#   'Comment_Count': '15'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: Let’s talk about NVIDIA GTC (It was wild!)',
#   'Published_date': '2024-03-23T20:12:11Z',
#   'Views': '6789',
#   'Like_count': '318',
#   'Comment_Count': '5'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'From zero momentum to unstoppable force - mastering the #coldstart like a champ #AI #chatgpt',
#   'Published_date': '2024-03-18T16:08:56Z',
#   'Views': '6285',
#   'Like_count': '274',
#   'Comment_Count': '10'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': "🐙 Lunch & Learn: Let's talk about Devin",
#   'Published_date': '2024-03-16T20:43:06Z',
#   'Views': '9826',
#   'Like_count': '340',
#   'Comment_Count': '26'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Sharing one of my favorite #AI apps with you',
#   'Published_date': '2024-03-14T14:47:37Z',
#   'Views': '6079',
#   'Like_count': '263',
#   'Comment_Count': '6'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'How to overcome procrastination',
#   'Published_date': '2024-03-12T15:50:17Z',
#   'Views': '32622',
#   'Like_count': '2326',
#   'Comment_Count': '54'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': 'Trick for effective #selfstudy',
#   'Published_date': '2024-03-11T16:36:08Z',
#   'Views': '10800',
#   'Like_count': '636',
#   'Comment_Count': '12'},
#  {'Channel_Name': 'Tina Huang',
#   'Title': '🐙 Lunch & Learn: Intro to Open Source Models',
#   'Published_date': '2024-03-09T14:38:10Z',
#   'Views': '9187',
#   'Like_count': '424',
#   'Comment_Count': '14'},
#  ...]

# %%
Video_data=pd.DataFrame(video_details)

# %%
Video_data
# Out:
#        Channel_Name                                              Title  \
# 0       Absent Data  Microsoft SQL Interview Question | CASE & SUB-...
# 1       Absent Data  Uber SQL  Interview Question | Pivot Table | C...
# 2       Absent Data  SQL Interview Question | Tinder | Subquery & W...
# 3       Absent Data  Data Analysis End to End | Project Analytics |...
# 4       Absent Data  UBER SQL Interview Question | Late Delivery Pe...
# ...             ...                                                ...
# 30129  Data Factory  Azure Data Factory Hands-on Lab V2 - Enhance D...
# 30130  Data Factory  Azure Data Factory Hands-on Lab V2 - Setting u...
# 30131  Data Factory         Azure Data Factory Hands-on Lab V2 - Intro
# 30132  Data Factory        Azure Data Factory and Customer Churn Story
# 30133  Data Factory  Azure Data Factory   ADF V2 Quickstart Templat...
#
#              Published_date  Views Like_count Comment_Count
# 0      2025-04-27T20:10:19Z   7790        224             3
# 1      2025-04-20T02:10:46Z  11656        386             4
# 2      2025-02-24T16:44:53Z  10371        544             7
# 3      2024-11-22T17:42:07Z  70296       2197           137
# 4      2024-10-27T16:12:42Z  18992       1080            27
# ...                     ...    ...        ...           ...
# 30129  2018-01-29T07:29:09Z   1798          3             0
# 30130  2018-01-29T07:29:09Z  11155         19             2
# 30131  2018-01-29T07:29:08Z   9215         33             1
# 30132  2018-01-29T06:27:40Z  41562         16             0
# 30133  2017-10-17T17:22:34Z   9295         18             1
#
# [30134 rows x 6 columns]

# %%
Video_data['Views'] = Video_data['Views'].replace("N/A", np.nan)
Video_data['Like_count'] = Video_data['Like_count'].replace("N/A", np.nan)
Video_data['Comment_Count'] = Video_data['Comment_Count'].replace("N/A", np.nan)

# %%
Video_data['Views'] = pd.to_numeric(Video_data['Views'], errors='coerce')
Video_data['Like_count'] = pd.to_numeric(Video_data['Like_count'], errors='coerce')
Video_data['Comment_Count'] = pd.to_numeric(Video_data['Comment_Count'], errors='coerce')

# %%
Video_data['Published_date'] = pd.to_datetime(Video_data['Published_date']).dt.date

# %%
Video_data.dtypes
# Out:
# Channel_Name       object
# Title              object
# Published_date     object
# Views             float64
# Like_count        float64
# Comment_Count     float64
# dtype: object

# %%
Video_data.to_csv(r'A:\data science material\data set\youtube\Youtube_dataset_all_dataScience_channels.csv', index=False)

# %% [markdown]
# **Youtube Channels Analysis With Advance Visuals**

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import offline, iplot
from IPython.display import display, HTML
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="plotly")
pd.options.display.float_format = "{:,.1f}".format

# %%
def update_layout(title_font_size = 28, hover_font_size = 16, hover_bgcolor = "#45FFCA", showlegend = False):
    fig.update_layout(
        showlegend = showlegend,
        title = {
            "font" : {
                "size" :title_font_size,
                "family" :"tahoma"
            }
        },
        hoverlabel={
            "bgcolor": hover_bgcolor,
            "font_size": hover_font_size,
            "font_family": "tahoma"
        }
    )

# %%
df=pd.read_csv(r"/content/A:\data science material\data set\youtube\Youtube_dataset_all_dataScience_channels.csv")
df.sample(n=10)
# Out:
#            Channel_Name                                              Title  \
# 16131    Sujay Nadkarni  See How You Can run Machine Learning Algorithm...
# 27560   Kevin Stratvert  How to Get your WIFI Password on Windows and i...
# 17049  freeCodeCamp.org  Deep Learning with PyTorch Live Course - Worki...
# 5466      Leila Gharani  Find Which Exact Color Is In The Picture (Find...
# 18279        codebasics                                    Is Python SLOW?
# 8195        Tableau Tim  Tableau Next: Exploring Tableau's New Directio...
# 17064  freeCodeCamp.org  PyTorch for Deep Learning - Full Course / Tuto...
# 26981        Krish Naik  Feedback Regarding The Initiative To Give Back...
# 19864       WsCube Tech  Data Analytics Mentorship Program with 100% Pl...
# 23577       WsCube Tech  How to use Mesh Tool & Symbol Sprayer Tool in ...
#
#       Published_date     Views  Like_count  Comment_Count
# 16131     2022-01-14   1,265.0        35.0            7.0
# 27560     2025-01-21  28,757.0       797.0           14.0
# 17049     2020-05-30  76,549.0     1,612.0           64.0
# 5466      2023-06-11  28,024.0     1,342.0           17.0
# 18279     2024-02-15  13,582.0       667.0           24.0
# 8195      2025-02-18   5,767.0        96.0           38.0
# 17064     2020-04-30 851,031.0    17,977.0          388.0
# 26981     2020-05-10   2,719.0       157.0          110.0
# 19864     2024-10-07   2,748.0       110.0            3.0
# 23577     2021-01-16   4,702.0        81.0            2.0

# %%
df.shape
# Out:
# (30134, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30134 entries, 0 to 30133
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Channel_Name    30134 non-null  object
#  1   Title           30134 non-null  object
#  2   Published_date  30134 non-null  object
#  3   Views           30132 non-null  float64
#  4   Like_count      30077 non-null  float64
#  5   Comment_Count   30103 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 1.4+ MB

# %%
df=df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30134 entries, 0 to 30133
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Channel_Name    30134 non-null  object
#  1   Title           30134 non-null  object
#  2   Published_date  30134 non-null  object
#  3   Views           30134 non-null  float64
#  4   Like_count      30134 non-null  float64
#  5   Comment_Count   30134 non-null  float64
# dtypes: float64(3), object(3)
# memory usage: 1.4+ MB

# %%
df.dtypes
# Out:
# Channel_Name       object
# Title              object
# Published_date     object
# Views             float64
# Like_count        float64
# Comment_Count     float64
# dtype: object

# %%
df['Published_date'] = pd.to_datetime(df['Published_date'], format='%Y-%m-%d')

# %%
df['Views'] = df['Views'].astype('int64')
df['Like_count'] = df['Like_count'].astype('int64')
df['Comment_Count'] = df['Comment_Count'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30134 entries, 0 to 30133
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Channel_Name    30134 non-null  object
#  1   Title           30134 non-null  object
#  2   Published_date  30134 non-null  datetime64[ns]
#  3   Views           30134 non-null  int64
#  4   Like_count      30134 non-null  int64
#  5   Comment_Count   30134 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 1.4+ MB

# %%
Channel = df["Channel_Name"].value_counts()
(Channel / df.shape[0] * 100).apply(lambda x: f"{x: 0.2f} %")
# Out:
# Channel_Name
# WsCube Tech                     18.57 %
# excelisfun                      12.72 %
# Krish Naik                       6.44 %
# freeCodeCamp.org                 6.19 %
# sentdex                          4.19 %
# CampusX                          3.70 %
# Guy in a Cube                    3.69 %
# codebasics                       3.52 %
# Kevin Stratvert                  3.47 %
# Socratica                        2.24 %
# Leila Gharani                    1.99 %
# Tableau Tim                      1.92 %
# Donut Gaming                     1.77 %
# Chandoo                          1.74 %
# Kaggle                           1.68 %
# DeepLearningAI                   1.65 %
# Piyush Garg                      1.42 %
# Loves Data                       1.34 %
# Alex The Analyst                 1.21 %
# TechTrapture                     1.16 %
# NitMan Talks                     1.04 %
# Nicholas Renotte                 1.04 %
# Zero Analyst                     0.99 %
# Ryan & Matt Data Science         0.98 %
# StatQuest with Josh Starmer      0.97 %
# Ken Jee                          0.96 %
# Coupler․io Academy               0.93 %
# Xamasco                          0.87 %
# Tina Huang                       0.83 %
# Sujay Nadkarni                   0.75 %
# Absent Data                      0.74 %
# DataScience RoadMap              0.73 %
# Data Engineering Simplified      0.66 %
# Data Factory                     0.66 %
# DATA SCIENCE LOVERS              0.57 %
# Data Tutorials                   0.55 %
# Luke Barousse                    0.55 %
# Learn Data Analytics             0.54 %
# Rob Mulla                        0.54 %
# Darshil Parmar                   0.54 %
# techTFQ                          0.46 %
# Rishabh Mishra                   0.42 %
# Keith Galli                      0.36 %
# Streamlit                        0.34 %
# Thu Vu                           0.32 %
# MPrashant TECH                   0.31 %
# Dataquest                        0.25 %
# Murtaza Hassan                   0.21 %
# Beyond Numberz                   0.20 %
# Deep Charts                      0.20 %
# coder2j                          0.17 %
# Stacey Samoe                     0.16 %
# The Live Coders                  0.16 %
# Mansi G.                         0.11 %
# Vincent Codes Finance            0.09 %
# Data Wale Bhaiya                 0.07 %
# Andrej Karpathy                  0.06 %
# ThePrefectPM                     0.04 %
# Sid Palas                        0.03 %
# The Code Tech                    0.02 %
# Name: count, dtype: object

# %% [markdown]
# Channel Name and Number of videos(%)

# %%
# Create the bar plot
fig = px.bar(
    data_frame=Channel.head(10),
    x=Channel.head(10).index,
    y=(Channel / sum(Channel) * 100).head(10),
    color=Channel.head(10).index,
    color_discrete_sequence=["#FF0060", "#45FFCA", "#45FFCA", "#293462", "#FF55BB", "#293462"],
    labels={"index": "Channel Name", "y": "(%)"},
    title="Channel Name and Number of videos(%)",
    text=Channel.head(10).apply(lambda x: f"{x / sum(Channel) * 100:0.2f}%"),
    template="plotly_dark"
)

# Update the layout
fig.update_layout(
    hoverlabel=dict(bgcolor="#111"),
    title_font=dict(size=24, color='lightgreen'),
    xaxis=dict(title='Channel Name'),
    yaxis=dict(title='Videos(%)'),
)

# Update traces
fig.update_traces(
    textfont={
        "family": "tahoma",
        "size": 13,
    },
    hovertemplate="Channel Name: %{x}<br>Videos: %{y:0.2f}%"
)

# Display the plot
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9c2f4b70-2aa9-42fd-b373-45063b27d4c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c2f4b70-2aa9-42fd-b373-45063b27d4c2")) {                    Plotly.newPlot(                        "9c2f4b70-2aa9-42fd-b373-45063b27d4c2",                        [{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"WsCube Tech","marker":{"color":"#FF0060","pattern":{"shape":""}},"name":"WsCube Tech","offsetgroup":"WsCube Tech","orientation":"v","showlegend":true,"text":["18.57%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["WsCube Tech"],"xaxis":"x","y":[18.573704121590232],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"excelisfun","marker":{"color":"#45FFCA","pattern":{"shape":""}},"name":"excelisfun","offsetgroup":"excelisfun","orientation":"v","showlegend":true,"text":["12.72%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["excelisfun"],"xaxis":"x","y":[12.716532820070354],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"Krish Naik","marker":{"color":"#45FFCA","pattern":{"shape":""}},"name":"Krish Naik","offsetgroup":"Krish Naik","orientation":"v","showlegend":true,"text":["6.44%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Krish Naik"],"xaxis":"x","y":[6.437910665693238],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"freeCodeCamp.org","marker":{"color":"#293462","pattern":{"shape":""}},"name":"freeCodeCamp.org","offsetgroup":"freeCodeCamp.org","orientation":"v","showlegend":true,"text":["6.19%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["freeCodeCamp.org"],"xaxis":"x","y":[6.189022366761797],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"sentdex","marker":{"color":"#FF55BB","pattern":{"shape":""}},"name":"sentdex","offsetgroup":"sentdex","orientation":"v","showlegend":true,"text":["4.19%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["sentdex"],"xaxis":"x","y":[4.187960443353023],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"CampusX","marker":{"color":"#293462","pattern":{"shape":""}},"name":"CampusX","offsetgroup":"CampusX","orientation":"v","showlegend":true,"text":["3.70%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["CampusX"],"xaxis":"x","y":[3.7001393774474014],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"Guy in a Cube","marker":{"color":"#FF0060","pattern":{"shape":""}},"name":"Guy in a Cube","offsetgroup":"Guy in a Cube","orientation":"v","showlegend":true,"text":["3.69%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Guy in a Cube"],"xaxis":"x","y":[3.693502356142563],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideos: %{y:0.2f}%","legendgroup":"codebasics","marker":{"color":"#45FFCA","pattern":{"shape":""}},"name":"codebasics","offsetgroup":"codebasics","orientation":"v","showlegend":true,"text":["3.52%"],"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["codebasics"],"xaxis":"x","y":[3.517621291564346],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel Name: %{x}\u003cbr\u003eVideo ...

# %% [markdown]
# Number of Videos of data Science educators Through Years

# %%
view_by_year=df.groupby(df['Published_date'].dt.year)['Views'].agg('sum')
view_by_year
# Out:
# Published_date
# 2008     22191696
# 2009     27346645
# 2010     22897829
# 2011     16371764
# 2012     19431003
# 2013     27174755
# 2014     41923602
# 2015     41079752
# 2016     54729554
# 2017    120756583
# 2018    280454617
# 2019    398784301
# 2020    477558027
# 2021    584362595
# 2022    530147317
# 2023    359422093
# 2024    194614685
# 2025     37612551
# Name: Views, dtype: int64

# %%
fig = px.area(view_by_year,
            x = view_by_year.index,
            y =view_by_year,
            labels = {"index" :"Year", "y" :"View Counts"},
            line_shape="spline",
            color_discrete_sequence=["#FF0060"],
            title = "Views in Data Science Content Through Years ⌛",
            template="plotly_dark",
              markers="O",

       )


update_layout()

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Year: %{x}<br>View Counts: %{y:0.2s}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4c4aed87-ef1e-4542-bcd5-f2e0307b5494" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c4aed87-ef1e-4542-bcd5-f2e0307b5494")) {                    Plotly.newPlot(                        "4c4aed87-ef1e-4542-bcd5-f2e0307b5494",                        [{"fillpattern":{"shape":""},"hovertemplate":"Year: %{x}\u003cbr\u003eView Counts: %{y:0.2s}","legendgroup":"","line":{"color":"#FF0060","shape":"spline"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"stackgroup":"1","textfont":{"family":"tahoma","size":13},"x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[22191696,27346645,22897829,16371764,19431003,27174755,41923602,41079752,54729554,120756583,280454617,398784301,477558027,584362595,530147317,359422093,194614685,37612551],"yaxis":"y","type":"scatter"}],                        {"hoverlabel":{"bgcolor":"#45FFCA","font":{"family":"tahoma","size":16}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"] ...

# %%
year=df['Published_date'].dt.year.value_counts().sort_index()
year
# Out:
# Published_date
# 2008     366
# 2009     614
# 2010     489
# 2011     362
# 2012     443
# 2013     686
# 2014     502
# 2015     618
# 2016     656
# 2017    1185
# 2018    1201
# 2019    2125
# 2020    3433
# 2021    4060
# 2022    4160
# 2023    3784
# 2024    3937
# 2025    1513
# Name: count, dtype: int64

# %%
fig = px.area(year,
        x = year.index,
        y =year,
        labels = {"index" :"Year", "y" :"Videos Counts"},
        line_shape="spline",
        color_discrete_sequence=["#45FFCA"],
        title = "Number of Videos of data Science educators Through Years 🗓️",
        template="plotly_dark",
       )


update_layout()
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4a675365-c44c-4a62-a5ae-946a4c0e3f1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a675365-c44c-4a62-a5ae-946a4c0e3f1c")) {                    Plotly.newPlot(                        "4a675365-c44c-4a62-a5ae-946a4c0e3f1c",                        [{"fillpattern":{"shape":""},"hovertemplate":"Published_date=%{x}\u003cbr\u003eVideos Counts=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#45FFCA","shape":"spline"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":[2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[366,614,489,362,443,686,502,618,656,1185,1201,2125,3433,4060,4160,3784,3937,1513],"yaxis":"y","type":"scatter"}],                        {"hoverlabel":{"bgcolor":"#45FFCA","font":{"family":"tahoma","size":16}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"s ...

# %%
df1= df.groupby('Channel_Name', as_index=False)['Views'].agg(['count', 'mean', 'sum'])
df1.columns = ['Channel_Name','video_count', 'view_mean', 'view_count']
df1
# Out:
#                    Channel_Name  video_count   view_mean  view_count
# 0                   Absent Data          223    20,826.8     4644370
# 1              Alex The Analyst          364   138,467.3    50402096
# 2               Andrej Karpathy           17 1,129,209.5    19196561
# 3                Beyond Numberz           61     2,704.9      165000
# 4                       CampusX         1115    36,218.3    40383410
# 5                       Chandoo          524   110,162.0    57724901
# 6            Coupler․io Academy          280    19,812.0     5547364
# 7           DATA SCIENCE LOVERS          173     8,858.7     1532562
# 8                Darshil Parmar          162    56,806.0     9202572
# 9   Data Engineering Simplified          200    18,977.6     3795520
# 10                 Data Factory          199     7,133.7     1419603
# 11               Data Tutorials          166    63,637.9    10563897
# 12             Data Wale Bhaiya           20     7,548.1      150963
# 13          DataScience RoadMap          219     7,129.9     1561452
# 14                    Dataquest           74    36,437.0     2696337
# 15                  Deep Charts           61     5,414.5      330284
# 16               DeepLearningAI          498    44,771.7    22296288
# 17                 Donut Gaming          534       263.8      140845
# 18                Guy in a Cube         1113    37,359.3    41580940
# 19                       Kaggle          506    10,172.9     5147466
# 20                  Keith Galli          107   158,775.1    16988938
# 21                      Ken Jee          288    32,749.9     9431973
# 22              Kevin Stratvert         1045   517,954.8   541262731
# 23                   Krish Naik         1940    60,494.5   117359325
# 24         Learn Data Analytics          163     1,306.7      212991
# 25                Leila Gharani          600   476,254.8   285752857
# 26                   Loves Data          403    24,953.9    10056417
# 27                Luke Barousse          165   159,607.1    26335168
# 28               MPrashant TECH           94    16,204.0     1523172
# 29                     Mansi G.           32    18,876.9      604061
# 30               Murtaza Hassan           62     1,314.9       81522
# 31             Nicholas Renotte          312    70,110.3    21874412
# 32                 NitMan Talks          313    20,905.4     6543387
# 33                  Piyush Garg          429    47,526.3    20388763
# 34               Rishabh Mishra          127   248,050.8    31502450
# 35                    Rob Mulla          162    88,032.5    14261258
# 36     Ryan & Matt Data Science          296     3,777.9     1118258
# 37                    Sid Palas            9     2,485.8       22372
# 38                    Socratica          676    94,430.0    63834659
# 39                 Stacey Samoe           48     1,862.6       89405
# 40  StatQuest with Josh Starmer          292   273,638.9    79902568
# 41                    Streamlit          101    11,376.7     1149051
# 42               Sujay Nadkarni          227     2,814.9      638983
# 43                  Tableau Tim          578     8,761.2     5063970
# 44                 TechTrapture          351     3,941.2     1383368
# 45                The Code Tech            5       833.8        4169
# 46              The Live Coders           48       464.7       22306
# 47                 ThePrefectPM           11       149.7        1647
# 48                       Thu Vu           96   114,311.0    10973852
# 49                   Tina Huang          250   156,139.2    39034792
# 50        Vincent Codes Finance           28     5,811.9      162732
# 51                  WsCube Tech         5597    65,629.3   367327355
# 52                      Xamasco          262     3,016.6      790338
# 53                 Zero Analyst          299     3,213.5      960822
# 54                   codebasics         1060   124,523.0   131994399
# 55                      coder2j           50    30,397.9     1519896
# 56                   excelisfun         3832    41,746.8   159973880
# 57             freeCodeCamp.org         1865   465,885.2   868875935
# 58                      sentdex         1262    93,489.4   117983679
# 59                      techTFQ          140   152,636.3    21369077

# %%
df2 = df.groupby('Channel_Name', as_index=False)['Like_count'].agg(['mean', 'count', 'sum'])
df2.columns = ['Channel_Name','Like_mean', 'video_count', 'Like_count']
df2
# Out:
#                    Channel_Name  Like_mean  video_count  Like_count
# 0                   Absent Data      469.3          223      104646
# 1              Alex The Analyst    3,322.9          364     1209525
# 2               Andrej Karpathy   27,872.5           17      473833
# 3                Beyond Numberz       97.2           61        5928
# 4                       CampusX    1,023.1         1115     1140768
# 5                       Chandoo    2,366.5          524     1240023
# 6            Coupler․io Academy      199.6          280       55879
# 7           DATA SCIENCE LOVERS      148.8          173       25740
# 8                Darshil Parmar    1,647.2          162      266848
# 9   Data Engineering Simplified      241.7          200       48343
# 10                 Data Factory       41.2          199        8203
# 11               Data Tutorials    1,390.7          166      230862
# 12             Data Wale Bhaiya      263.4           20        5267
# 13          DataScience RoadMap      122.2          219       26772
# 14                    Dataquest      826.7           74       61175
# 15                  Deep Charts      180.7           61       11020
# 16               DeepLearningAI      520.0          498      258964
# 17                 Donut Gaming        4.3          534        2308
# 18                Guy in a Cube      601.6         1113      669606
# 19                       Kaggle      189.0          506       95619
# 20                  Keith Galli    3,394.4          107      363200
# 21                      Ken Jee    1,156.3          288      333022
# 22              Kevin Stratvert    9,356.2         1045     9777255
# 23                   Krish Naik    1,389.9         1940     2696480
# 24         Learn Data Analytics       34.0          163        5534
# 25                Leila Gharani   10,316.4          600     6189840
# 26                   Loves Data      391.4          403      157726
# 27                Luke Barousse    5,214.2          165      860349
# 28               MPrashant TECH      353.3           94       33211
# 29                     Mansi G.      886.9           32       28380
# 30               Murtaza Hassan       41.2           62        2556
# 31             Nicholas Renotte    2,105.9          312      657029
# 32                 NitMan Talks      449.0          313      140550
# 33                  Piyush Garg    1,389.3          429      595994
# 34               Rishabh Mishra    6,983.2          127      886863
# 35                    Rob Mulla    3,358.1          162      544015
# 36     Ryan & Matt Data Science      101.3          296       29990
# 37                    Sid Palas       28.3            9         255
# 38                    Socratica    1,887.6          676     1276043
# 39                 Stacey Samoe       56.4           48        2705
# 40  StatQuest with Josh Starmer    5,846.1          292     1707054
# 41                    Streamlit      190.4          101       19227
# 42               Sujay Nadkarni       73.1          227       16600
# 43                  Tableau Tim      119.8          578       69250
# 44                 TechTrapture       49.0          351       17214
# 45                The Code Tech       26.8            5         134
# 46              The Live Coders        9.1           48         435
# 47                 ThePrefectPM        3.9           11          43
# 48                       Thu Vu    4,597.1           96      441321
# 49                   Tina Huang    6,981.5          250     1745374
# 50        Vincent Codes Finance      133.3           28        3732
# 51                  WsCube Tech    1,558.9         5597     8725324
# 52                      Xamasco       29.8          262        7810
# 53                 Zero Analyst       88.5          299       26467
# 54                   codebasics    2,672.0         1060     2832354
# 55                      coder2j      473.8           50       23689
# 56                   excelisfun      295.3         3832     1131402
# 57             freeCodeCamp.org    9,908.0         1865    18478330
# 58                      sentdex    1,112.3         1262     1403672
# 59                      techTFQ    3,736.5          140      523116

# %%
df3 = df.groupby('Channel_Name', as_index=False)['Comment_Count'].agg(['mean', 'count', 'sum'])
df3.columns = ['Channel_Name','Comment_mean', 'video_count', 'Comment_count']
df3
# Out:
#                    Channel_Name  Comment_mean  video_count  Comment_count
# 0                   Absent Data          18.0          223           4005
# 1              Alex The Analyst         180.3          364          65641
# 2               Andrej Karpathy       1,128.9           17          19191
# 3                Beyond Numberz           7.4           61            449
# 4                       CampusX          56.4         1115          62878
# 5                       Chandoo          96.1          524          50343
# 6            Coupler․io Academy           7.6          280           2120
# 7           DATA SCIENCE LOVERS           9.7          173           1675
# 8                Darshil Parmar         104.2          162          16874
# 9   Data Engineering Simplified          28.3          200           5667
# 10                 Data Factory           5.6          199           1118
# 11               Data Tutorials          54.9          166           9114
# 12             Data Wale Bhaiya          41.0           20            819
# 13          DataScience RoadMap           7.0          219           1536
# 14                    Dataquest          36.9           74           2731
# 15                  Deep Charts          10.1           61            616
# 16               DeepLearningAI          14.9          498           7411
# 17                 Donut Gaming           0.1          534             48
# 18                Guy in a Cube          41.8         1113          46485
# 19                       Kaggle           7.2          506           3665
# 20                  Keith Galli         158.7          107          16985
# 21                      Ken Jee          97.9          288          28184
# 22              Kevin Stratvert         355.7         1045         371658
# 23                   Krish Naik          73.4         1940         142327
# 24         Learn Data Analytics           1.6          163            260
# 25                Leila Gharani         374.1          600         224456
# 26                   Loves Data          37.7          403          15183
# 27                Luke Barousse         200.4          165          33067
# 28               MPrashant TECH          21.1           94           1988
# 29                     Mansi G.         188.8           32           6043
# 30               Murtaza Hassan           2.2           62            138
# 31             Nicholas Renotte         136.6          312          42631
# 32                 NitMan Talks          42.4          313          13272
# 33                  Piyush Garg          76.3          429          32719
# 34               Rishabh Mishra         383.5          127          48707
# 35                    Rob Mulla          88.7          162          14368
# 36     Ryan & Matt Data Science           8.8          296           2596
# 37                    Sid Palas           4.7            9             42
# 38                    Socratica          80.4          676          54346
# 39                 Stacey Samoe           6.1           48            292
# 40  StatQuest with Josh Starmer         356.4          292         104058
# 41                    Streamlit           9.2          101            925
# 42               Sujay Nadkarni           3.4          227            771
# 43                  Tableau Tim          11.5          578           6639
# 44                 TechTrapture           6.3          351           2197
# 45                The Code Tech           1.6            5              8
# 46              The Live Coders           0.7           48             33
# 47                 ThePrefectPM           0.0           11              0
# 48                       Thu Vu         129.4           96          12420
# 49                   Tina Huang         213.8          250          53456
# 50        Vincent Codes Finance          12.0           28            337
# 51                  WsCube Tech          44.5         5597         249318
# 52                      Xamasco           1.3          262            347
# 53                 Zero Analyst          12.2          299           3653
# 54                   codebasics          84.6         1060          89626
# 55                      coder2j          31.2           50           1559
# 56                   excelisfun          41.0         3832         157273
# 57             freeCodeCamp.org         298.3         1865         556258
# 58                      sentdex         109.0         1262         137559
# 59                      techTFQ         190.4          140          26654

# %%
Channel_comparison = pd.concat([df1, df2[['Like_mean','Like_count']],df3[['Comment_mean','Comment_count']]],axis=1).query('video_count>20')
Channel_comparison
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 0                   Absent Data          223   20,826.8     4644370
# 1              Alex The Analyst          364  138,467.3    50402096
# 3                Beyond Numberz           61    2,704.9      165000
# 4                       CampusX         1115   36,218.3    40383410
# 5                       Chandoo          524  110,162.0    57724901
# 6            Coupler․io Academy          280   19,812.0     5547364
# 7           DATA SCIENCE LOVERS          173    8,858.7     1532562
# 8                Darshil Parmar          162   56,806.0     9202572
# 9   Data Engineering Simplified          200   18,977.6     3795520
# 10                 Data Factory          199    7,133.7     1419603
# 11               Data Tutorials          166   63,637.9    10563897
# 13          DataScience RoadMap          219    7,129.9     1561452
# 14                    Dataquest           74   36,437.0     2696337
# 15                  Deep Charts           61    5,414.5      330284
# 16               DeepLearningAI          498   44,771.7    22296288
# 17                 Donut Gaming          534      263.8      140845
# 18                Guy in a Cube         1113   37,359.3    41580940
# 19                       Kaggle          506   10,172.9     5147466
# 20                  Keith Galli          107  158,775.1    16988938
# 21                      Ken Jee          288   32,749.9     9431973
# 22              Kevin Stratvert         1045  517,954.8   541262731
# 23                   Krish Naik         1940   60,494.5   117359325
# 24         Learn Data Analytics          163    1,306.7      212991
# 25                Leila Gharani          600  476,254.8   285752857
# 26                   Loves Data          403   24,953.9    10056417
# 27                Luke Barousse          165  159,607.1    26335168
# 28               MPrashant TECH           94   16,204.0     1523172
# 29                     Mansi G.           32   18,876.9      604061
# 30               Murtaza Hassan           62    1,314.9       81522
# 31             Nicholas Renotte          312   70,110.3    21874412
# 32                 NitMan Talks          313   20,905.4     6543387
# 33                  Piyush Garg          429   47,526.3    20388763
# 34               Rishabh Mishra          127  248,050.8    31502450
# 35                    Rob Mulla          162   88,032.5    14261258
# 36     Ryan & Matt Data Science          296    3,777.9     1118258
# 38                    Socratica          676   94,430.0    63834659
# 39                 Stacey Samoe           48    1,862.6       89405
# 40  StatQuest with Josh Starmer          292  273,638.9    79902568
# 41                    Streamlit          101   11,376.7     1149051
# 42               Sujay Nadkarni          227    2,814.9      638983
# 43                  Tableau Tim          578    8,761.2     5063970
# 44                 TechTrapture          351    3,941.2     1383368
# 46              The Live Coders           48      464.7       22306
# 48                       Thu Vu           96  114,311.0    10973852
# 49                   Tina Huang          250  156,139.2    39034792
# 50        Vincent Codes Finance           28    5,811.9      162732
# 51                  WsCube Tech         5597   65,629.3   367327355
# 52                      Xamasco          262    3,016.6      790338
# 53                 Zero Analyst          299    3,213.5      960822
# 54                   codebasics         1060  124,523.0   131994399
# 55                      coder2j           50   30,397.9     1519896
# 56                   excelisfun         3832   41,746.8   159973880
# 57             freeCodeCamp.org         1865  465,885.2   868875935
# 58                      sentdex         1262   93,489.4   117983679
# 59                      techTFQ          140  152,636.3    21369077
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 0       469.3      104646          18.0           4005
# 1     3,322.9     1209525         180.3          65641
# 3        97.2        5928           7.4            449
# 4     1,023.1     1140768          56.4          62878
# 5     2,366.5     1240023          96.1          50343
# 6       199.6       55879           7.6           2120
# 7       148.8       25740           9.7           1675
# 8     1,647.2      266848         104.2          16874
# 9       241.7       48343          28.3           5667
# 10       41.2        8203           5.6           1118
# 11    1,390.7      230862          54.9           9114
# 13      122.2       26772           7.0           1536
# 14      826.7       61175          36.9           2731
# 15      180.7       11020          10.1            616
# 16      520.0      258964          14.9           7411
# 17        4.3        2308           0.1             48
# 18      601.6      669606          41.8          46485
# 19      189.0       95619           7.2           3665
# 20    3,394.4      363200         158.7          16985
# 21    1,156.3      333022          97.9          28184
# 22    9,356.2     9777255         355.7         371658
# 23    1,389.9     2696480          73.4         142327
# 24       34.0        5534           1.6            260
# 25   10,316.4     6189840         374.1         224456
# 26      391.4      157726          37.7          15183
# 27    5,214.2      860349         200.4          33067
# 28      353.3       33211          21.1           1988
# 29      886.9       28380         188.8           6043
# 30       41.2        2556           2.2            138
# 31    2,105.9      657029         136.6          42631
# 32      449.0      140550          42.4          13272
# 33    1,389.3      595994          76.3          32719
# 34    6,983.2      886863         383.5          48707
# 35    3,358.1      544015          88.7          14368
# 36      101.3       29990           8.8           2596
# 38    1,887.6     1276043          80.4          54346
# 39       56.4        2705           6.1            292
# 40    5,846.1     1707054         356.4         104058
# 41      190.4       19227           9.2            925
# 42       73.1       16600           3.4            771
# 43      119.8       69250          11.5           6639
# 44       49.0       17214           6.3           2197
# 46        9.1         435           0.7             33
# 48    4,597.1      441321         129.4          12420
# 49    6,981.5     1745374         213.8          53456
# 50      133.3        3732          12.0            337
# 51    1,558.9     8725324          44.5         249318
# 52       29.8        7810           1.3            347
# 53       88.5       26467          12.2           3653
# 54    2,672.0     2832354          84.6          89626
# 55      473.8       23689          31.2           1559
# 56      295.3     1131402          41.0         157273
# 57    9,908.0    18478330         298.3         556258
# 58    1,112.3     1403672         109.0         137559
# 59    3,736.5      523116         190.4          26654

# %%
channel_views = Channel_comparison.sort_values(by='view_mean', ascending=True)
channel_views.tail(10)
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 1              Alex The Analyst          364  138,467.3    50402096
# 59                      techTFQ          140  152,636.3    21369077
# 49                   Tina Huang          250  156,139.2    39034792
# 20                  Keith Galli          107  158,775.1    16988938
# 27                Luke Barousse          165  159,607.1    26335168
# 34               Rishabh Mishra          127  248,050.8    31502450
# 40  StatQuest with Josh Starmer          292  273,638.9    79902568
# 57             freeCodeCamp.org         1865  465,885.2   868875935
# 25                Leila Gharani          600  476,254.8   285752857
# 22              Kevin Stratvert         1045  517,954.8   541262731
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 1     3,322.9     1209525         180.3          65641
# 59    3,736.5      523116         190.4          26654
# 49    6,981.5     1745374         213.8          53456
# 20    3,394.4      363200         158.7          16985
# 27    5,214.2      860349         200.4          33067
# 34    6,983.2      886863         383.5          48707
# 40    5,846.1     1707054         356.4         104058
# 57    9,908.0    18478330         298.3         556258
# 25   10,316.4     6189840         374.1         224456
# 22    9,356.2     9777255         355.7         371658

# %%
fig = px.bar(
    data_frame= channel_views.tail(10),
    orientation = "h",
    y = channel_views.tail(10).Channel_Name,
    x = channel_views.tail(10).view_mean,
    color = channel_views.tail(10).view_mean,

    labels = {"x": "average views", "y" : "Data Science YouTube channels"},
    title = "Top 10 Data Science YouTube channels with highest average views",
    text_auto= ".2s",
    template = "plotly_dark",
     color_continuous_scale=['#A084E8', '#00FFAB', '#00FFAB']
      )

update_layout(hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textposition = "outside",
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Data Science YouTube channels: %{y}<br>average views: %{x:0.3s}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1af9e90f-66e9-499a-a7c7-a37eb223e495" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1af9e90f-66e9-499a-a7c7-a37eb223e495")) {                    Plotly.newPlot(                        "1af9e90f-66e9-499a-a7c7-a37eb223e495",                        [{"alignmentgroup":"True","hovertemplate":"Data Science YouTube channels: %{y}\u003cbr\u003eaverage views: %{x:0.3s}","legendgroup":"","marker":{"color":[138467.2967032967,152636.26428571428,156139.168,158775.1214953271,159607.0787878788,248050.7874015748,273638.9315068493,465885.2198391421,476254.76166666666,517954.76650717703],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textfont":{"family":"tahoma","size":13},"textposition":"outside","texttemplate":"%{x:.2s}","x":[138467.2967032967,152636.26428571428,156139.168,158775.1214953271,159607.0787878788,248050.7874015748,273638.9315068493,465885.2198391421,476254.76166666666,517954.76650717703],"xaxis":"x","y":["Alex The Analyst","techTFQ","Tina Huang","Keith Galli","Luke Barousse","Rishabh Mishra","StatQuest with Josh Starmer","freeCodeCamp.org","Leila Gharani","Kevin Stratvert"],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"color"}},"colorscale":[[0.0,"#A084E8"],[0.5,"#00FFAB"],[1.0,"#00FFAB"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":14}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778 ...

# %%
channel_Like_mean=Channel_comparison.sort_values(by='Like_mean',ascending=False)
channel_Like_mean.head(10)
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 25                Leila Gharani          600  476,254.8   285752857
# 57             freeCodeCamp.org         1865  465,885.2   868875935
# 22              Kevin Stratvert         1045  517,954.8   541262731
# 34               Rishabh Mishra          127  248,050.8    31502450
# 49                   Tina Huang          250  156,139.2    39034792
# 40  StatQuest with Josh Starmer          292  273,638.9    79902568
# 27                Luke Barousse          165  159,607.1    26335168
# 48                       Thu Vu           96  114,311.0    10973852
# 59                      techTFQ          140  152,636.3    21369077
# 20                  Keith Galli          107  158,775.1    16988938
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 25   10,316.4     6189840         374.1         224456
# 57    9,908.0    18478330         298.3         556258
# 22    9,356.2     9777255         355.7         371658
# 34    6,983.2      886863         383.5          48707
# 49    6,981.5     1745374         213.8          53456
# 40    5,846.1     1707054         356.4         104058
# 27    5,214.2      860349         200.4          33067
# 48    4,597.1      441321         129.4          12420
# 59    3,736.5      523116         190.4          26654
# 20    3,394.4      363200         158.7          16985

# %%
fig = px.bar(channel_Like_mean.head(10),
                 x = "Channel_Name",
                 y = "Like_mean",
                 color = "Channel_Name",
                 template = "plotly_dark",
                 color_discrete_sequence=["#45FFCA","#FF0060","#FF55BB", "#FFFDAF"],
                 opacity = 0.89,
                title = "Top 10 Data Science YouTube channels with highest average Likes")


update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Channel_Name: %{x}<br>average Likes: %{y}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b39c0037-8f31-44ca-9a74-d279bc35d972" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b39c0037-8f31-44ca-9a74-d279bc35d972")) {                    Plotly.newPlot(                        "b39c0037-8f31-44ca-9a74-d279bc35d972",                        [{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Leila Gharani","marker":{"color":"#45FFCA","opacity":0.89,"pattern":{"shape":""}},"name":"Leila Gharani","offsetgroup":"Leila Gharani","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Leila Gharani"],"xaxis":"x","y":[10316.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"freeCodeCamp.org","marker":{"color":"#FF0060","opacity":0.89,"pattern":{"shape":""}},"name":"freeCodeCamp.org","offsetgroup":"freeCodeCamp.org","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["freeCodeCamp.org"],"xaxis":"x","y":[9907.951742627345],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Kevin Stratvert","marker":{"color":"#FF55BB","opacity":0.89,"pattern":{"shape":""}},"name":"Kevin Stratvert","offsetgroup":"Kevin Stratvert","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Kevin Stratvert"],"xaxis":"x","y":[9356.224880382775],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Rishabh Mishra","marker":{"color":"#FFFDAF","opacity":0.89,"pattern":{"shape":""}},"name":"Rishabh Mishra","offsetgroup":"Rishabh Mishra","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Rishabh Mishra"],"xaxis":"x","y":[6983.173228346457],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Tina Huang","marker":{"color":"#45FFCA","opacity":0.89,"pattern":{"shape":""}},"name":"Tina Huang","offsetgroup":"Tina Huang","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Tina Huang"],"xaxis":"x","y":[6981.496],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"StatQuest with Josh Starmer","marker":{"color":"#FF0060","opacity":0.89,"pattern":{"shape":""}},"name":"StatQuest with Josh Starmer","offsetgroup":"StatQuest with Josh Starmer","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["StatQuest with Josh Starmer"],"xaxis":"x","y":[5846.075342465753],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Luke Barousse","marker":{"color":"#FF55BB","opacity":0.89,"pattern":{"shape":""}},"name":"Luke Barousse","offsetgroup":"Luke Barousse","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Luke Barousse"],"xaxis":"x","y":[5214.236363636363],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Channel_Name: %{x}\u003cbr\u003eaverage Likes: %{y}","legendgroup":"Thu Vu","marker":{"color":"#FFFDAF","opacity":0.89,"pattern":{"shape":""}},"name":"Thu Vu","offsetgroup":"Thu Vu","orientation":"v","showlegend":true,"textfont":{"family":"tahoma","size":13},"textposition":"auto","x":["Thu Vu"],"xaxis":"x","y":[4597.09375],"yaxis":"y","type":"bar" ...

# %%
channel_Comment_mean=Channel_comparison.sort_values(by='Comment_mean',ascending=True)
channel_Comment_mean.tail(10)
# Out:
#                    Channel_Name  video_count  view_mean  view_count  \
# 1              Alex The Analyst          364  138,467.3    50402096
# 29                     Mansi G.           32   18,876.9      604061
# 59                      techTFQ          140  152,636.3    21369077
# 27                Luke Barousse          165  159,607.1    26335168
# 49                   Tina Huang          250  156,139.2    39034792
# 57             freeCodeCamp.org         1865  465,885.2   868875935
# 22              Kevin Stratvert         1045  517,954.8   541262731
# 40  StatQuest with Josh Starmer          292  273,638.9    79902568
# 25                Leila Gharani          600  476,254.8   285752857
# 34               Rishabh Mishra          127  248,050.8    31502450
#
#     Like_mean  Like_count  Comment_mean  Comment_count
# 1     3,322.9     1209525         180.3          65641
# 29      886.9       28380         188.8           6043
# 59    3,736.5      523116         190.4          26654
# 27    5,214.2      860349         200.4          33067
# 49    6,981.5     1745374         213.8          53456
# 57    9,908.0    18478330         298.3         556258
# 22    9,356.2     9777255         355.7         371658
# 40    5,846.1     1707054         356.4         104058
# 25   10,316.4     6189840         374.1         224456
# 34    6,983.2      886863         383.5          48707

# %%
fig = px.scatter(channel_Comment_mean.tail(10),
                 y = "Channel_Name",
                 x = "Comment_mean",
                 size = "Comment_mean",
                 color = "Comment_mean",
                 template = "plotly_dark",
                 labels={"name" :"Data Science YouTube channels", "score" :"average comments"},
                 opacity = 0.89,
                title = "Top 10 Data Science YouTube channels with highest average comments",
                color_continuous_scale=['#A084E8', '#8BE8E5', '#00FFAB'])


update_layout(hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "YouTube channels: %{y}<br>average comments: %{x}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c767bcbb-ce72-497a-a0c8-10ba499075a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c767bcbb-ce72-497a-a0c8-10ba499075a5")) {                    Plotly.newPlot(                        "c767bcbb-ce72-497a-a0c8-10ba499075a5",                        [{"hovertemplate":"YouTube channels: %{y}\u003cbr\u003eaverage comments: %{x}","legendgroup":"","marker":{"color":[180.33241758241758,188.84375,190.38571428571427,200.4060606060606,213.824,298.26166219839143,355.6535885167464,356.36301369863014,374.0933333333333,383.5196850393701],"coloraxis":"coloraxis","opacity":0.89,"size":[180.33241758241758,188.84375,190.38571428571427,200.4060606060606,213.824,298.26166219839143,355.6535885167464,356.36301369863014,374.0933333333333,383.5196850393701],"sizemode":"area","sizeref":0.9587992125984252,"symbol":"circle"},"mode":"markers","name":"","orientation":"h","showlegend":false,"textfont":{"family":"tahoma","size":13},"x":[180.33241758241758,188.84375,190.38571428571427,200.4060606060606,213.824,298.26166219839143,355.6535885167464,356.36301369863014,374.0933333333333,383.5196850393701],"xaxis":"x","y":["Alex The Analyst","Mansi G.","techTFQ","Luke Barousse","Tina Huang","freeCodeCamp.org","Kevin Stratvert","StatQuest with Josh Starmer","Leila Gharani","Rishabh Mishra"],"yaxis":"y","type":"scatter"}],                        {"coloraxis":{"colorbar":{"title":{"text":"Comment_mean"}},"colorscale":[[0.0,"#A084E8"],[0.5,"#8BE8E5"],[1.0,"#00FFAB"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":14}},"legend":{"itemsizing":"constant","tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333 ...

# %% [markdown]
# ♣ Is There Any Correlation in the data set?!🎬

# %%
df_corr = Channel_comparison[["video_count", "view_mean",  "Like_mean", "Comment_mean"]]

# %%
df_corr.corr(numeric_only=True)
# Out:
#               video_count  view_mean  Like_mean  Comment_mean
# video_count           1.0        0.2        0.1           0.0
# view_mean             0.2        1.0        1.0           0.9
# Like_mean             0.1        1.0        1.0           0.9
# Comment_mean          0.0        0.9        0.9           1.0

# %%
# Create The Plotly Heat Map
fig = px.imshow(
    df_corr.corr(numeric_only = True),
    text_auto="0.2f", aspect="auto", template="plotly_dark",
    title="Correlation",
    color_continuous_scale = "earth"
)

update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=15)

fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 16,
    },
    hovertemplate= "Feature[1]: %{x}<br>Feature[2]: %{y}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0a85ae38-147f-4edb-97c6-d3d2b73a390b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a85ae38-147f-4edb-97c6-d3d2b73a390b")) {                    Plotly.newPlot(                        "0a85ae38-147f-4edb-97c6-d3d2b73a390b",                        [{"coloraxis":"coloraxis","hovertemplate":"Feature[1]: %{x}\u003cbr\u003eFeature[2]: %{y}","name":"0","textfont":{"family":"tahoma","size":16},"texttemplate":"%{z:0.2f}","x":["video_count","view_mean","Like_mean","Comment_mean"],"xaxis":"x","y":["video_count","view_mean","Like_mean","Comment_mean"],"yaxis":"y","z":[[1.0,0.1565473964559738,0.09357362228948231,0.04397856566925021],[0.1565473964559738,1.0,0.9586201942485542,0.8992352185681454],[0.09357362228948231,0.9586201942485542,1.0,0.9291646486848274],[0.04397856566925021,0.8992352185681454,0.9291646486848274,1.0]],"type":"heatmap"}],                        {"coloraxis":{"colorscale":[[0.0,"rgb(161, 105, 40)"],[0.16666666666666666,"rgb(189, 146, 90)"],[0.3333333333333333,"rgb(214, 189, 141)"],[0.5,"rgb(237, 234, 194)"],[0.6666666666666666,"rgb(181, 200, 184)"],[0.8333333333333334,"rgb(121, 167, 172)"],[1.0,"rgb(40, 135, 161)"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":15}},"showlegend":true,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7 ...

# %% [markdown]
# ► From The HeatMap, We Can Say 😉🧐
# 1) There Is a Very Strong Positive Correlation Between view_mean and Like_mean (1.0)🔗..
#
#
# 2) There Is a Strong Positive Correlation Between view_mean and Comment_mean (0.89)🔗
#
# *   List item
# *   List item

# %%
fig = px.scatter(
    Channel_comparison,
    x = Channel_comparison["view_mean"],
    y = Channel_comparison["Like_mean"],
    trendline="ols",
    template="plotly_dark",
    color = Channel_comparison["Like_mean"],
    color_discrete_sequence=["#45FFCA"],
    title = "Relation Between Views & Likes",

          )

update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=15)
fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 16,
    },
    hovertemplate= "Views: %{x:0.3s}<br>Likes: %{y:0.3s}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5d44c707-ce24-4cb5-ab0a-551a0496d4b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d44c707-ce24-4cb5-ab0a-551a0496d4b4")) {                    Plotly.newPlot(                        "5d44c707-ce24-4cb5-ab0a-551a0496d4b4",                        [{"hovertemplate":"Views: %{x:0.3s}\u003cbr\u003eLikes: %{y:0.3s}","legendgroup":"","marker":{"color":[469.2645739910314,3322.870879120879,97.18032786885246,1023.1103139013453,2366.456106870229,199.56785714285715,148.78612716763007,1647.20987654321,241.715,41.221105527638194,1390.7349397590363,122.24657534246575,826.6891891891892,180.65573770491804,520.0080321285141,4.322097378277154,601.622641509434,188.97035573122528,3394.392523364486,1156.326388888889,9356.224880382775,1389.9381443298969,33.95092024539877,10316.4,391.37965260545906,5214.236363636363,353.3085106382979,886.875,41.225806451612904,2105.8621794871797,449.04153354632587,1389.2634032634032,6983.173228346457,3358.117283950617,101.31756756756756,1887.637573964497,56.354166666666664,5846.075342465753,190.36633663366337,73.12775330396475,119.80968858131487,49.042735042735046,9.0625,4597.09375,6981.496,133.28571428571428,1558.9287118098982,29.80916030534351,88.51839464882943,2672.032075471698,473.78,295.2510438413361,9907.951742627345,1112.2599049128369,3736.542857142857],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"textfont":{"family":"tahoma","size":16},"x":[20826.771300448432,138467.2967032967,2704.9180327868853,36218.304932735424,110162.0248091603,19812.014285714286,8858.739884393064,56806.0,18977.6,7133.683417085427,63637.93373493976,7129.917808219178,36436.98648648649,5414.491803278688,44771.66265060241,263.75468164794006,37359.33513027852,10172.857707509882,158775.1214953271,32749.90625,517954.76650717703,60494.49742268041,1306.6932515337423,476254.76166666666,24953.888337468983,159607.0787878788,16203.95744680851,18876.90625,1314.8709677419354,70110.29487179487,20905.389776357828,47526.25407925408,248050.7874015748,88032.45679012345,3777.8986486486488,94429.96893491125,1862.6041666666667,273638.9315068493,11376.742574257425,2814.9030837004407,8761.193771626298,3941.219373219373,464.7083333333333,114310.95833333333,156139.168,5811.857142857143,65629.32910487762,3016.557251908397,3213.4515050167224,124523.0179245283,30397.92,41746.837160751566,465885.2198391421,93489.44453248811,152636.26428571428],"xaxis":"x","y":[469.2645739910314,3322.870879120879,97.18032786885246,1023.1103139013453,2366.456106870229,199.56785714285715,148.78612716763007,1647.20987654321,241.715,41.221105527638194,1390.7349397590363,122.24657534246575,826.6891891891892,180.65573770491804,520.0080321285141,4.322097378277154,601.622641509434,188.97035573122528,3394.392523364486,1156.326388888889,9356.224880382775,1389.9381443298969,33.95092024539877,10316.4,391.37965260545906,5214.236363636363,353.3085106382979,886.875,41.225806451612904,2105.8621794871797,449.04153354632587,1389.2634032634032,6983.173228346457,3358.117283950617,101.31756756756756,1887.637573964497,56.354166666666664,5846.075342465753,190.36633663366337,73.12775330396475,119.80968858131487,49.042735042735046,9.0625,4597.09375,6981.496,133.28571428571428,1558.9287118098982,29.80916030534351,88.51839464882943,2672.032075471698,473.78,295.2510438413361,9907.951742627345,1112.2599049128369,3736.542857142857],"yaxis":"y","type":"scatter"},{"hovertemplate":"Views: %{x:0.3s}\u003cbr\u003eLikes: %{y:0.3s}","legendgroup":"","marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"textfont":{"family":"tahoma","size":16},"x":[263.75468164794006,464.7083333333333,1306.6932515337423,1314.8709677419354,1862.604 ...

# %%
fig = px.scatter(
    Channel_comparison,
    x = Channel_comparison["view_mean"],
    y = Channel_comparison["Comment_mean"],
    trendline="ols",
    template="plotly_dark",
    color = Channel_comparison["Comment_mean"],
    color_discrete_sequence=["#45FFCA"],
    title = "Relation Between Views & Comments",

          )

update_layout(showlegend=True, hover_bgcolor="#222", hover_font_size=15)
fig.update_traces(
    textfont = {
        "family": "tahoma",
         "size": 16,
    },
    hovertemplate= "Views: %{x:0.4s}<br>Comments: %{y:0.4s}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="24b00c58-298e-458e-8bab-f681709b61fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24b00c58-298e-458e-8bab-f681709b61fb")) {                    Plotly.newPlot(                        "24b00c58-298e-458e-8bab-f681709b61fb",                        [{"hovertemplate":"Views: %{x:0.4s}\u003cbr\u003eComments: %{y:0.4s}","legendgroup":"","marker":{"color":[17.95964125560538,180.33241758241758,7.360655737704918,56.39282511210762,96.07442748091603,7.571428571428571,9.68208092485549,104.1604938271605,28.335,5.618090452261306,54.903614457831324,7.013698630136986,36.9054054054054,10.098360655737705,14.88152610441767,0.0898876404494382,41.76549865229111,7.243083003952569,158.73831775700936,97.86111111111111,355.6535885167464,73.36443298969073,1.5950920245398772,374.0933333333333,37.67493796526055,200.4060606060606,21.148936170212767,188.84375,2.225806451612903,136.63782051282053,42.40255591054313,76.26806526806527,383.5196850393701,88.69135802469135,8.77027027027027,80.39349112426035,6.083333333333333,356.36301369863014,9.158415841584159,3.39647577092511,11.486159169550174,6.2592592592592595,0.6875,129.375,213.824,12.035714285714286,44.54493478649277,1.3244274809160306,12.217391304347826,84.55283018867925,31.18,41.042014613778704,298.26166219839143,109.00079239302694,190.38571428571427],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"textfont":{"family":"tahoma","size":16},"x":[20826.771300448432,138467.2967032967,2704.9180327868853,36218.304932735424,110162.0248091603,19812.014285714286,8858.739884393064,56806.0,18977.6,7133.683417085427,63637.93373493976,7129.917808219178,36436.98648648649,5414.491803278688,44771.66265060241,263.75468164794006,37359.33513027852,10172.857707509882,158775.1214953271,32749.90625,517954.76650717703,60494.49742268041,1306.6932515337423,476254.76166666666,24953.888337468983,159607.0787878788,16203.95744680851,18876.90625,1314.8709677419354,70110.29487179487,20905.389776357828,47526.25407925408,248050.7874015748,88032.45679012345,3777.8986486486488,94429.96893491125,1862.6041666666667,273638.9315068493,11376.742574257425,2814.9030837004407,8761.193771626298,3941.219373219373,464.7083333333333,114310.95833333333,156139.168,5811.857142857143,65629.32910487762,3016.557251908397,3213.4515050167224,124523.0179245283,30397.92,41746.837160751566,465885.2198391421,93489.44453248811,152636.26428571428],"xaxis":"x","y":[17.95964125560538,180.33241758241758,7.360655737704918,56.39282511210762,96.07442748091603,7.571428571428571,9.68208092485549,104.1604938271605,28.335,5.618090452261306,54.903614457831324,7.013698630136986,36.9054054054054,10.098360655737705,14.88152610441767,0.0898876404494382,41.76549865229111,7.243083003952569,158.73831775700936,97.86111111111111,355.6535885167464,73.36443298969073,1.5950920245398772,374.0933333333333,37.67493796526055,200.4060606060606,21.148936170212767,188.84375,2.225806451612903,136.63782051282053,42.40255591054313,76.26806526806527,383.5196850393701,88.69135802469135,8.77027027027027,80.39349112426035,6.083333333333333,356.36301369863014,9.158415841584159,3.39647577092511,11.486159169550174,6.2592592592592595,0.6875,129.375,213.824,12.035714285714286,44.54493478649277,1.3244274809160306,12.217391304347826,84.55283018867925,31.18,41.042014613778704,298.26166219839143,109.00079239302694,190.38571428571427],"yaxis":"y","type":"scatter"},{"hovertemplate":"Views: %{x:0.4s}\u003cbr\u003eComments: %{y:0.4s}","legendgroup":"","marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"textfont":{"family":"tahoma","size":16},"x":[263.75468164794006,464.7083333333333,1306.6932515337423,1314.8709677419354,18 ...

# %%
df.sample(10)
# Out:
#                    Channel_Name  \
# 7794                    CampusX
# 9426                     Kaggle
# 14912                   sentdex
# 7010   Ryan & Matt Data Science
# 6280                    Chandoo
# 1728               Donut Gaming
# 21473               WsCube Tech
# 28129           Kevin Stratvert
# 1214               Stacey Samoe
# 9442                     Kaggle
#
#                                                    Title Published_date  \
# 7794   How to become a great coder Part 11 - Document...     2020-05-23
# 9426   Kaggle Live Coding: Hierarchical Document Clus...     2019-08-02
# 14912          Python 3 Programming Tutorial - Functions     2014-04-20
# 7010   Data Analyst Portfolio Project Walkthrough (Ex...     2023-06-05
# 6280   Data Cleaning in Excel - 10 Tricks (Beginner t...     2022-04-12
# 1728   SETH ROLLINS 15 WWE 2K24 ENTRANCE - #WWE2K24 S...     2024-06-17
# 21473  What are NumPy Insert and Delete Arrays Functi...     2022-05-25
# 28129                              Google Forms Tutorial     2021-03-18
# 1214   SQL+Tableau Data Analysis Portfolio Project| F...     2023-10-17
# 9442   What's your favorite Kaggle Competition? | Ask...     2019-07-03
#
#          Views  Like_count  Comment_Count
# 7794       283          17              0
# 9426      7370         127              2
# 14912   291351        2283             79
# 7010     26534        1345             61
# 6280    428506        8123            270
# 1728        17           1              0
# 21473    20904         368             13
# 28129  1441141       24769            938
# 1214      5162         123             22
# 9442      3420          56              0

# %%
best_videos=df.sort_values(by=['Views', 'Like_count', 'Comment_Count'], ascending=True)
best_videos.tail(10)
# Out:
#            Channel_Name                                              Title  \
# 17068  freeCodeCamp.org  Introduction to Programming and Computer Scien...
# 16963  freeCodeCamp.org  Microsoft Excel Tutorial for Beginners - Full ...
# 16645  freeCodeCamp.org  Harvard CS50 – Full Computer Science Universit...
# 17381  freeCodeCamp.org           C++ Tutorial for Beginners - Full Course
# 17393  freeCodeCamp.org               C Programming Tutorial for Beginners
# 17451  freeCodeCamp.org  SQL Tutorial - Full Database Course for Beginners
# 17241  freeCodeCamp.org       Learn JavaScript - Full Course for Beginners
# 22405       WsCube Tech  Ethical HACKING Full Course in 10 HOURS (Begin...
# 18258        codebasics     Don't put toy dataset projects on your resume!
# 17434  freeCodeCamp.org  Learn Python - Full Course for Beginners [Tuto...
#
#       Published_date     Views  Like_count  Comment_Count
# 17068     2020-04-21   9531394      221383           4574
# 16963     2020-10-28  10313976      171322           2891
# 16645     2022-10-19  12290862      470532           7825
# 17381     2018-08-24  12962844      291146          11797
# 17393     2018-08-15  17769574      227623           7459
# 17451     2018-07-02  19689873      365389          11655
# 17241     2018-12-10  19720269      277866           8800
# 22405     2021-08-29  22491474      587151           7404
# 18258     2024-03-22  29814758      571330           1193
# 17434     2018-07-11  46783663     1085018          45169

# %%
fig = px.bar(
    data_frame=best_videos.tail(10),
    orientation="h",
    y=best_videos.tail(10).Title,
    x=best_videos.tail(10).Views,
    color=best_videos.tail(10).Views,
    labels={"x": "View,Likes and Comment", "y": "Videos"},
    title="Top 10 Videos on the basis of View,Likes and Comment",
    text_auto=".2s",
    template="plotly_dark",
    color_continuous_scale=['#FF5733', '#C70039', '#900C3F']
)
update_layout(hover_bgcolor="#222", hover_font_size=14)

fig.update_traces(
    textposition = "outside",
    textfont = {
        "family": "tahoma",
         "size": 13,
    },
    hovertemplate= "Videos: %{y}<br>AVG View: %{x:0.3s}"
)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5fd29416-acc6-4a96-ae70-4c56e07bbc57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fd29416-acc6-4a96-ae70-4c56e07bbc57")) {                    Plotly.newPlot(                        "5fd29416-acc6-4a96-ae70-4c56e07bbc57",                        [{"alignmentgroup":"True","hovertemplate":"Videos: %{y}\u003cbr\u003eAVG View: %{x:0.3s}","legendgroup":"","marker":{"color":[9531394,10313976,12290862,12962844,17769574,19689873,19720269,22491474,29814758,46783663],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textfont":{"family":"tahoma","size":13},"textposition":"outside","texttemplate":"%{x:.2s}","x":[9531394,10313976,12290862,12962844,17769574,19689873,19720269,22491474,29814758,46783663],"xaxis":"x","y":["Introduction to Programming and Computer Science - Full Course","Microsoft Excel Tutorial for Beginners - Full Course","Harvard CS50 – Full Computer Science University Course","C++ Tutorial for Beginners - Full Course","C Programming Tutorial for Beginners","SQL Tutorial - Full Database Course for Beginners","Learn JavaScript - Full Course for Beginners","Ethical HACKING Full Course in 10 HOURS (Beginners to Pro) | Learn Ethical Hacking 2025","Don't put toy dataset projects on your resume!","Learn Python - Full Course for Beginners [Tutorial]"],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"color"}},"colorscale":[[0.0,"#FF5733"],[0.5,"#C70039"],[1.0,"#900C3F"]]},"hoverlabel":{"bgcolor":"#222","font":{"family":"tahoma","size":14}},"legend":{"tracegroupgap":0},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f ...

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    for i in range(0, len(channel_ids), 50):
        batch_ids = channel_ids[i:i + 50]
        request = youtube.channels().list(
            part='snippet,contentDetails,statistics',
            id=','.join(batch_ids)
        )
        response = request.execute()

        for item in response.get('items', []):
            data = {
                'Channel_Name': item['snippet']['title'],
                'Subscribers': int(item['statistics'].get('subscriberCount', 0)),
                'Views': int(item['statistics'].get('viewCount', 0)),
                'Total_videos': int(item['statistics'].get('videoCount', 0)),
                'Playlist_id': item['contentDetails']['relatedPlaylists']['uploads']
            }
            all_data.append(data)
    return all_data

# %%
# Call the function after client initialization
# Step 4: Call the function
channel_data = get_channel_stats(youtube, channel_ids)

# %%
channel_data
# Out:
# [{'Channel_Name': 'Andrej Karpathy',
#   'Subscribers': 868000,
#   'Views': 19194446,
#   'Total_videos': 17,
#   'Playlist_id': 'UUXUPKJO5MZQN11PqgIvyuvQ'},
#  {'Channel_Name': 'techTFQ',
#   'Subscribers': 370000,
#   'Views': 21368721,
#   'Total_videos': 140,
#   'Playlist_id': 'UUnz-ZXXER4jOvuED5trXfEA'},
#  {'Channel_Name': 'Luke Barousse',
#   'Subscribers': 527000,
#   'Views': 26334542,
#   'Total_videos': 164,
#   'Playlist_id': 'UULLw7jmFsvfIVaUFsLs8mlQ'},
#  {'Channel_Name': 'Dataquest',
#   'Subscribers': 68000,
#   'Views': 2696316,
#   'Total_videos': 74,
#   'Playlist_id': 'UU_lePY0Lm0E2-_IkYUWpI5A'},
#  {'Channel_Name': 'Guy in a Cube',
#   'Subscribers': 498000,
#   'Views': 41581524,
#   'Total_videos': 1119,
#   'Playlist_id': 'UUFp1vaKzpfvoGai0vE5VJ0w'},
#  {'Channel_Name': 'Vincent Codes Finance',
#   'Subscribers': 2320,
#   'Views': 162752,
#   'Total_videos': 28,
#   'Playlist_id': 'UUuNrwdpvF1LBGJ2cNL5b68w'},
#  {'Channel_Name': 'TechTrapture',
#   'Subscribers': 12800,
#   'Views': 1383351,
#   'Total_videos': 351,
#   'Playlist_id': 'UUMNZFAhQSB314E_MG3IbTXQ'},
#  {'Channel_Name': 'Leila Gharani',
#   'Subscribers': 2860000,
#   'Views': 285751298,
#   'Total_videos': 601,
#   'Playlist_id': 'UUJtUOos_MwJa_Ewii-R3cJA'},
#  {'Channel_Name': 'Sujay Nadkarni',
#   'Subscribers': 10500,
#   'Views': 638543,
#   'Total_videos': 226,
#   'Playlist_id': 'UUAhplpsDYvq0W1F4hcSrqnw'},
#  {'Channel_Name': 'StatQuest with Josh Starmer',
#   'Subscribers': 1420000,
#   'Views': 79901573,
#   'Total_videos': 291,
#   'Playlist_id': 'UUtYLUTtgS3k1Fg4y5tAhLbw'},
#  {'Channel_Name': 'Darshil Parmar',
#   'Subscribers': 182000,
#   'Views': 9202315,
#   'Total_videos': 162,
#   'Playlist_id': 'UUChmJrVa8kDg05JfCmxpLRw'},
#  {'Channel_Name': 'Streamlit',
#   'Subscribers': 24300,
#   'Views': 1149065,
#   'Total_videos': 100,
#   'Playlist_id': 'UU3LD42rjj-Owtxsa6PwGU5Q'},
#  {'Channel_Name': 'Ken Jee',
#   'Subscribers': 271000,
#   'Views': 9431993,
#   'Total_videos': 288,
#   'Playlist_id': 'UUiT9RITQ9PW6BhXK0y2jaeg'},
#  {'Channel_Name': 'Kevin Stratvert',
#   'Subscribers': 3650000,
#   'Views': 541241683,
#   'Total_videos': 1044,
#   'Playlist_id': 'UUfJT_eYDTmDE-ovKaxVE1ig'},
#  {'Channel_Name': 'Donut Gaming',
#   'Subscribers': 475,
#   'Views': 140842,
#   'Total_videos': 534,
#   'Playlist_id': 'UUe0TgrSOmVNu7vrwC4ZFWdg'},
#  {'Channel_Name': 'Rishabh Mishra',
#   'Subscribers': 422000,
#   'Views': 31499167,
#   'Total_videos': 127,
#   'Playlist_id': 'UU3rY5HOgbBvGmq7RnDfwF7A'},
#  {'Channel_Name': 'Keith Galli',
#   'Subscribers': 244000,
#   'Views': 16988782,
#   'Total_videos': 106,
#   'Playlist_id': 'UUq6XkhO5SZ66N04IcPbqNcw'},
#  {'Channel_Name': 'Socratica',
#   'Subscribers': 932000,
#   'Views': 63834370,
#   'Total_videos': 676,
#   'Playlist_id': 'UUW6TXMZ5Pq6yL6_k5NZ2e0Q'},
#  {'Channel_Name': 'Tableau Tim',
#   'Subscribers': 238000,
#   'Views': 5064129,
#   'Total_videos': 586,
#   'Playlist_id': 'UU7HYxRWmaNlJux-X7rNLZyw'},
#  {'Channel_Name': 'DeepLearningAI',
#   'Subscribers': 407000,
#   'Views': 22296190,
#   'Total_videos': 498,
#   'Playlist_id': 'UUcIXc5mJsHVYTZR1maL5l9w'},
#  {'Channel_Name': 'Ryan & Matt Data Science',
#   'Subscribers': 23900,
#   'Views': 1118249,
#   'Total_videos': 296,
#   'Playlist_id': 'UUKq-lHnyradGRmFClX_ACMw'},
#  {'Channel_Name': 'Alex The Analyst',
#   'Subscribers': 1070000,
#   'Views': 50400719,
#   'Total_videos': 364,
#   'Playlist_id': 'UU7cs8q-gJRlGwj4A8OmCmXg'},
#  {'Channel_Name': 'Zero Analyst',
#   'Subscribers': 27500,
#   'Views': 960761,
#   'Total_videos': 299,
#   'Playlist_id': 'UUD7FERT7OXNgLYkvEyy3qGQ'},
#  {'Channel_Name': 'Murtaza Hassan',
#   'Subscribers': 5520,
#   'Views': 81515,
#   'Total_videos': 62,
#   'Playlist_id': 'UUzv_k6lxolY4rzndB71AfUw'},
#  {'Channel_Name': 'codebasics',
#   'Subscribers': 1290000,
#   'Views': 131990353,
#   'Total_videos': 1061,
#   'Playlist_id': 'UUh9nVJoWXmFb7sLApWGcLPQ'},
#  {'Channel_Name': 'Kaggle',
#   'Subscribers': 198000,
#   'Views': 5147469,
#   'Total_videos': 506,
#   'Playlist_id': 'UUSNeZleDn9c74yQc-EKnVTA'},
#  {'Channel_Name': 'The Live Coders',
#   'Subscribers': 528,
#   'Views': 22306,
#   'Total_videos': 48,
#   'Playlist_id': 'UUz7iLJYRhzoSVIXZ2dESzuw'},
#  {'Channel_Name': 'WsCube Tech',
#   'Subscribers': 3970000,
#   'Views': 367321696,
#   'Total_videos': 5663,
#   'Playlist_id': 'UU0T6MVd3wQDB5ICAe45OxaQ'},
#  {'Channel_Name': 'Absent Data',
#   'Subscribers': 60000,
#   'Views': 4644341,
#   'Total_videos': 223,
#   'Playlist_id': 'UUSQvwTdavISOusGhJW6H0Vg'},
#  {'Channel_Name': 'excelisfun',
#   'Subscribers': 1210000,
#   'Views': 159973719,
#   'Total_videos': 3832,
#   'Playlist_id': 'UUkndrGoNpUDV-uia6a9jwVg'},
#  {'Channel_Name': 'NitMan Talks',
#   'Subscribers': 48500,
#   'Views': 6543374,
#   'Total_videos': 313,
#   'Playlist_id': 'UUSQnHL-F4wnMbg4BT-9pVSQ'},
#  {'Channel_Name': 'CampusX',
#   'Subscribers': 335000,
#   'Views': 40498648,
#   'Total_videos': 1249,
#   'Playlist_id': 'UUCWi3hpnq_Pe03nGxuS7isg'},
#  {'Channel_Name': 'The Code Tech',
#   'Subscribers': 1100,
#   'Views': 4169,
#   'Total_videos': 5,
#   'Playlist_id': 'UUoIfDjbbP3zpKtFm43nh1sQ'},
#  {'Channel_Name': 'Stacey Samoe',
#   'Subscribers': 2180,
#   'Views': 89405,
#   'Total_videos': 48,
#   'Playlist_id': 'UU_MWk7GdVDJcMexHiP4UTjw'},
#  {'Channel_Name': 'Krish Naik',
#   'Subscribers': 1190000,
#   'Views': 118008834,
#   'Total_videos': 2020,
#   'Playlist_id': 'UUNU_lfiiWBdtULKOw6X0Dig'},
#  {'Channel_Name': 'Rob Mulla',
#   'Subscribers': 205000,
#   'Views': 14262619,
#   'Total_videos': 162,
#   'Playlist_id': 'UUxladMszXan-jfgzyeIMyvw'},
#  {'Channel_Name': 'ThePrefectPM',
#   'Subscribers': 369,
#   'Views': 1647,
#   'Total_videos': 11,
#   'Playlist_id': 'UUi5CmpgqgeEzqVDumyEc9og'},
#  {'Channel_Name': 'freeCodeCamp.org',
#   'Subscribers': 10800000,
#   'Views': 868859439,
#   'Total_videos': 1865,
#   'Playlist_id': 'UU8butISFwT-Wl7EV0hUK0BQ'},
#  {'Channel_Name': 'Tina Huang',
#   'Subscribers': 881000,
#   'Views': 39037813,
#   'Total_videos': 252,
#   'Playlist_id': 'UU2UXDak6o7rBm23k3Vv5dww'},
#  {'Channel_Name': 'Thu Vu',
#   'Subscribers': 309000,
#   'Views': 10973405,
#   'Total_videos': 96,
#   'Playlist_id': 'UUJQJAI7IjbLcpsjWdSzYz0Q'},
#  {'Channel_Name': 'Chandoo',
#   'Subscribers': 764000,
#   'Views': 57723945,
#   'Total_videos': 525,
#   'Playlist_id': 'UU8uU_wruBMHeeRma49dtZKA'},
#  {'Channel_Name': 'Nicholas Renotte',
#   'Subscribers': 308000,
#   'Views': 21874348,
#   'Total_videos': 311,
#   'Playlist_id': 'UUHXa4OpASJEwrHrLeIzw7Yg'},
#  {'Channel_Name': 'MPrashant TECH',
#   'Subscribers': 23200,
#   'Views': 1522881,
#   'Total_videos': 94,
#   'Playlist_id': 'UUOwaE3fVOZSRujo2OPDKCHg'},
#  {'Channel_Name': 'Loves Data',
#   'Subscribers': 137000,
#   'Views': 10056291,
#   'Total_videos': 403,
#   'Playlist_id': 'UUDnJ7pVeZXFn7gcbcwcjUkA'},
#  {'Channel_Name': 'sentdex',
#   'Subscribers': 1410000,
#   'Views': 117983614,
#   'Total_videos': 1262,
#   'Playlist_id': 'UUfzlCWGWYyIQ0aLC5w48gBQ'},
#  {'Channel_Name': 'Piyush Garg',
#   'Subscribers': 260000,
#   'Views': 20392646,
#   'Total_videos': 429,
#   'Playlist_id': 'UUf9T51_FmMlfhiGpoes0yFA'},
#  {'Channel_Name': 'Mansi G.',
#   'Subscribers': 13600,
#   'Views': 603790,
#   'Total_videos': 32,
#   'Playlist_id': 'UUIB_kEcgT-lkTi14cqq4XqA'},
#  {'Channel_Name': 'Xamasco',
#   'Subscribers': 4590,
#   'Views': 790314,
#   'Total_videos': 262,
#   'Playlist_id': 'UUrzeNkbo0mEoANAHlxYP22A'},
#  {'Channel_Name': 'DATA SCIENCE LOVERS',
#   'Subscribers': 29100,
#   'Views': 1532540,
#   'Total_videos': 173,
#   'Playlist_id': 'UUwk47V1XafOrw83d_vwwGhg'},
#  {'Channel_Name': 'Learn Data Analytics',
#   'Subscribers': 2060,
#   'Views': 212788,
#   'Total_videos': 163,
#   'Playlist_id': 'UUdY9luYzi6V1-_pl2uezIHg'},
#  {'Channel_Name': 'Deep Charts',
#   'Subscribers': 10200,
#   'Views': 330290,
#   'Total_videos': 61,
#   'Playlist_id': 'UUUlCfM_fqQedxqGPqLVPuGw'},
#  {'Channel_Name': 'Data Wale Bhaiya',
#   'Subscribers': 6070,
#   'Views': 150962,
#   'Total_videos': 20,
#   'Playlist_id': 'UULXbBOFMlbD7l7ynTd80Ohw'},
#  {'Channel_Name': 'Coupler․io Academy',
#   'Subscribers': 60000,
#   'Views': 5547266,
#   'Total_videos': 281,
#   'Playlist_id': 'UUS0ZTW6ynY34OZodixxwb7w'},
#  {'Channel_Name': 'coder2j',
#   'Subscribers': 15600,
#   'Views': 1519864,
#   'Total_videos': 50,
#   'Playlist_id': 'UUHoLIMtg_OigNlJmjHX9J8Q'},
#  {'Channel_Name': 'Beyond Numberz',
#   'Subscribers': 4620,
#   'Views': 165004,
#   'Total_videos': 61,
#   'Playlist_id': 'UUBQGd1sTurl5fZ5foDZtN5A'},
#  {'Channel_Name': 'Sid Palas',
#   'Subscribers': 683,
#   'Views': 22371,
#   'Total_videos': 9,
#   'Playlist_id': 'UUKKpMJSgeZzyfKjyNtHtSsA'},
#  {'Channel_Name': 'Data Tutorials',
#   'Subscribers': 176000,
#   'Views': 10564882,
#   'Total_videos': 167,
#   'Playlist_id': 'UUBOs6624oqScw8PaU-Jzw9A'},
#  {'Channel_Name': 'Data Factory',
#   'Subscribers': 17500,
#   'Views': 1419595,
#   'Total_videos': 198,
#   'Playlist_id': 'UU2S0k7NeLcEm5_IhHUwpN0g'},
#  {'Channel_Name': 'DataScience RoadMap',
#   'Subscribers': 22300,
#   'Views': 1561442,
#   'Total_videos': 219,
#   'Playlist_id': 'UUAEgip72UcvYwjcqzcJ1I2g'},
#  {'Channel_Name': 'Data Engineering Simplified',
#   'Subscribers': 55400,
#   'Views': 3795546,
#   'Total_videos': 200,
#   'Playlist_id': 'UUnfZSN7A09wNwYiUoincXZg'}]

# %%
import json
with open('channel_stats.json', 'w') as f:
    json.dump(channel_data, f, indent=2)
